# %% [markdown]
# # Author Attribution of *Bush v. Gore*

# %% [markdown]
# ### LIN350 Project Code
# Aaron Coronado, Andrea Conde, Jada Li

# %% [markdown]
# First, we read in the data set and filter out unimportant columns.

# %%
import pandas as pd

opinions = pd.read_csv("opinions_since_1970.csv")[["author_name", "category", "case_name", "year_filed", "text"]]
opinions.head(10)
# Out:
#         author_name    category  \
# 0   Justice Roberts    majority
# 1    Justice Thomas  concurring
# 2    Justice Breyer  dissenting
# 3     Justice Kagan    majority
# 4   Justice Roberts  dissenting
# 5   Justice Kennedy    majority
# 6     Justice Kagan  concurring
# 7  Justice Ginsburg  dissenting
# 8     Justice White    majority
# 9   Justice Kennedy  dissenting
#
#                                            case_name  year_filed  \
# 0              McCutcheon v. Federal Election Comm'n        2014
# 1              McCutcheon v. Federal Election Comm'n        2014
# 2              McCutcheon v. Federal Election Comm'n        2014
# 3                             Kaley v. United States        2014
# 4                             Kaley v. United States        2014
# 5  Masterpiece Cakeshop, Ltd. v. Colorado Civil R...        2018
# 6  Masterpiece Cakeshop, Ltd. v. Colorado Civil R...        2018
# 7  Masterpiece Cakeshop, Ltd. v. Colorado Civil R...        2018
# 8                             Steelworkers v. Rawson        1990
# 9                             Steelworkers v. Rawson        1990
#
#                                                 text
# 0  There is no right more basic in our democracy ...
# 1  I adhere to the view that this Court’s decisio...
# 2  Nearly 40 years ago in Buckley v. Valeo, 424 U...
# 3  A federal statute, 21 U.S. C. §853(e), authori...
# 4  An individual facing serious criminal charges ...
# 5  In 2012 a same-sex couple visited Masterpiece\...
# 6  “[I]t is a general rule that [religious and ph...
# 7  There is much in the Court’s opinion with whic...
# 8  We granted certiorari in this case because the...
# 9  The Idaho Supreme Court held that summary judg...

# %% [markdown]
# Then we pick out the specific case that we are focusing on.

# %%
bvg = opinions[(opinions["case_name"] == "Bush v. Gore") & (opinions["category"] == "per_curiam")]

# %% [markdown]
# Then, we filter out all other justices that were not on the Supreme Court during *Bush v. Gore* and keep only the relevant justices.

# %%
rel_justices = opinions[
    (opinions["author_name"] == "Justice Rehnquist") |
    (opinions["author_name"] == "Justice Stevens") |
    (opinions["author_name"] == "Justice O'Connor") |
    (opinions["author_name"] == "Justice Scalia") |
    (opinions["author_name"] == "Justice Kennedy") |
    (opinions["author_name"] == "Justice Souter") |
    (opinions["author_name"] == "Justice Thomas") |
    (opinions["author_name"] == "Justice Ginsburg") |
    (opinions["author_name"] == "Justice Breyer")
]
# checks that there are nine unique justices in the new dataframe
rel_justices["author_name"].unique()
# Out:
# array(['Justice Thomas', 'Justice Breyer', 'Justice Kennedy',
#        'Justice Ginsburg', 'Justice Scalia', "Justice O'Connor",
#        'Justice Stevens', 'Justice Rehnquist', 'Justice Souter'],
#       dtype=object)

# %% [markdown]
# Then, we narrow down all the writing samples to be within a 10-year time frame. This is intended to account for changes in writing styles over time while still having a large enough number of past writing samples to use.

# %%
temp = rel_justices[(rel_justices["year_filed"] >= 1995) & (rel_justices["year_filed"] <= 2005)]
temp["author_name"].value_counts()
# Out:
# author_name
# Justice Stevens      292
# Justice Scalia       250
# Justice Thomas       192
# Justice Breyer       187
# Justice Souter       177
# Justice Ginsburg     177
# Justice Kennedy      163
# Justice O'Connor     160
# Justice Rehnquist    142
# Name: count, dtype: int64

# %%
# grouping the text by justice name
# justice_texts = temp.groupby("author_name")["text"].apply(list).to_dict()
# print("JUSTICE THOMAS' OPINIONS \n")
# for text in justice_texts.get("Justice Thomas", []):
#     print(text[:500]) # first 500 char of Justice Thomas' opinions
#     print("\nNEXT OPINION")

# %% [markdown]
# ### 2) Stopwords (we will not be removing stopwords)

# %%
import nltk
stopwords = nltk.corpus.stopwords.words("english")
stopwords[:100]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once']

# %% [markdown]
# ### 3) POS Tagging

# %%
import re
# get text of selected authors
selected_opinions_text = temp["text"]

# convert selected_opinions_text to string format
selected_opinions_string = selected_opinions_text.to_string()

# remove unneeded number headers
selected_opinions_string = re.sub(r'^\d+\s+', '', selected_opinions_string, flags=re.MULTILINE)

# %%
import nltk
words = nltk.word_tokenize(selected_opinions_string)
nltk.pos_tag(words)
# Out:
# [('This', 'DT'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('whether', 'IN'),
#  ('workpl', 'NN'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('concur', 'VBP'),
#  ('because', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ('stresses', 'VBZ'),
#  ('that', 'IN'),
#  ('in', 'IN'),
#  ('ev', 'NN'),
#  ('...', ':'),
#  ('Section', 'NN'),
#  ('102', 'CD'),
#  ('(', '('),
#  ('b', 'NN'),
#  (')', ')'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Patent', 'NNP'),
#  ('Act', 'NNP'),
#  ('of', 'IN'),
#  ('1952', 'CD'),
#  ('provi', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Administrative', 'JJ'),
#  ('Procedure', 'NNP'),
#  ('Act', 'NNP'),
#  ('(', '('),
#  ('APA', 'NNP'),
#  (')', ')'),
#  ('sets', 'VBZ'),
#  ('fo', 'JJ'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('issue', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  (',', ','),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Supreme', 'NNP'),
#  ('Court', 'NNP'),
#  ('of', 'IN'),
#  ('South', 'NNP'),
#  ('Carolina', 'NNP'),
#  ('dismissed', 'VBD'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('joining', 'VBG'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ('today', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('signal', 'VB'),
#  ('an', 'DT'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('State', 'NNP'),
#  ('of', 'IN'),
#  ('Michigan', 'NNP'),
#  (',', ','),
#  ('by', 'IN'),
#  ('regulation', 'NN'),
#  (',', ','),
#  ('places', 'NNS'),
#  ('c', 'VBP'),
#  ('...', ':'),
#  ('Our', 'PRP$'),
#  ('decision', 'NN'),
#  ('today', 'NN'),
#  ('is', 'VBZ'),
#  ('faithful', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('principl', 'NN'),
#  ('...', ':'),
#  ('Arizona', 'NNP'),
#  ('law', 'NN'),
#  ('authorizes', 'VBZ'),
#  ('income-tax', 'JJ'),
#  ('credits', 'NNS'),
#  ('for', 'IN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('Part', 'NNP'),
#  ('IV', 'NNP'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('dissent', 'NN'),
#  (',', ','),
#  ('JUSTICE', 'NNP'),
#  ('KENNEDY', 'NNP'),
#  ('obs', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ('shows', 'VBZ'),
#  ('great', 'JJ'),
#  ('skepticism', 'NN'),
#  ('...', ':'),
#  ('Federal', 'NNP'),
#  ('courts', 'NNS'),
#  ('lack', 'NN'),
#  ('competence', 'NN'),
#  ('to', 'TO'),
#  ('rule', 'VB'),
#  ('definit', 'NN'),
#  ('...', ':'),
#  ('A', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('growers', 'NNS'),
#  (',', ','),
#  ('handlers', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('processors', 'NNS'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Court', 'NNP'),
#  ('today', 'NN'),
#  ('finds', 'VBZ'),
#  ('no', 'DT'),
#  ('First', 'NNP'),
#  ('Amendment', 'NNP'),
#  ('right', 'NN'),
#  ('...', ':'),
#  ('I\\nI', 'NNP'),
#  ('join', 'NN'),
#  ('Justice', 'NNP'),
#  ('Souter', 'NNP'),
#  ("'s", 'POS'),
#  ('dissent', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('e', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Sierra', 'NNP'),
#  ('Club', 'NNP'),
#  ('challenges', 'VBZ'),
#  ('the', 'DT'),
#  ('lawfulness', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('...', ':'),
#  ('Section', 'NN'),
#  ('3', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Religious', 'NNP'),
#  ('Land', 'NNP'),
#  ('Use', 'NNP'),
#  ('and', 'CC'),
#  ('Instit', 'NNP'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('join', 'VBP'),
#  ('the', 'DT'),
#  ('opinion', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('agree', 'VBP'),
#  ('with', 'IN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('whether', 'IN'),
#  ('the', 'DT'),
#  ('At', 'IN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('involves', 'VBZ'),
#  ('an', 'DT'),
#  ('action', 'NN'),
#  ('for', 'IN'),
#  ('damages', 'NNS'),
#  ('again', 'RB'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('agree', 'VBP'),
#  ('with', 'IN'),
#  ('Justice', 'NNP'),
#  ('Ginsburg', 'NNP'),
#  ('that', 'IN'),
#  ('``', '``'),
#  ('common', 'JJ'),
#  ('sen', 'NN'),
#  ('...', ':'),
#  ('A', 'NNP'),
#  ('fatal', 'JJ'),
#  ('accident', 'NN'),
#  ('occurred', 'VBD'),
#  ('on', 'IN'),
#  ('October', 'NNP'),
#  ('3', 'CD'),
#  (',', ','),
#  ('1993', 'CD'),
#  (',', ','),
#  ('...', ':'),
#  ('Respondent', 'NNP'),
#  ('Hurley', 'NNP'),
#  ('Henson', 'NNP'),
#  ('filed', 'VBD'),
#  ('suit', 'NN'),
#  ('in', 'IN'),
#  ('state', 'NN'),
#  ('c', 'NNS'),
#  ('...', ':'),
#  ('As', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ('acknowledges', 'VBZ'),
#  (',', ','),
#  ('ante', 'NN'),
#  (',', ','),
#  ('at', 'IN'),
#  ('32', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('de', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('these', 'DT'),
#  ('consolidated', 'JJ'),
#  ('cases', 'NNS'),
#  (',', ','),
#  ('two', 'CD'),
#  ('individuals', 'NNS'),
#  ('s', 'VBP'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Court', 'NNP'),
#  ('today', 'NN'),
#  ('holds', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('claims', 'NNS'),
#  ('responde', 'VBP'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('question', 'NN'),
#  ('before', 'IN'),
#  ('us', 'PRP'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('join', 'VBP'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ("'s", 'POS'),
#  ('opinion', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('my', 'PRP$'),
#  ('view', 'NN'),
#  (',', ','),
#  ('prior', 'RB'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('question', 'NN'),
#  ('presented', 'VBN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('an', 'DT'),
#  ('injunctio', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('Ford', 'NNP'),
#  ('v.', 'NN'),
#  ('Wainwright', 'NNP'),
#  (',', ','),
#  ('477', 'CD'),
#  ('U.S.', 'NNP'),
#  ('399', 'CD'),
#  (',', ','),
#  ('410', 'CD'),
#  ('(', '('),
#  ('1986', 'CD'),
#  ('...', ':'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('axiomatic', 'JJ'),
#  ('that', 'IN'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('power', 'NN'),
#  ('to', 'TO'),
#  ('award', 'VB'),
#  ('the', 'DT'),
#  ('w', 'NN'),
#  ('...', ':'),
#  ('From', 'IN'),
#  ('1986', 'CD'),
#  ('to', 'TO'),
#  ('1991', 'CD'),
#  (',', ','),
#  ('respondent', 'NN'),
#  ('filed', 'VBD'),
#  ('three', 'CD'),
#  ('peti', 'NN'),
#  ('...', ':'),
#  ('We', 'PRP'),
#  ('address', 'VBP'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('whether', 'IN'),
#  ('23', 'CD'),
#  ('U.S.', 'NNP'),
#  ('C.', 'NNP'),
#  ('§', 'VBZ'),
#  ('4', 'CD'),
#  ('...', ':'),
#  ('An', 'DT'),
#  ('offender', 'NN'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('serving', 'VBG'),
#  ('time', 'NN'),
#  ('in', 'IN'),
#  ('federal', 'JJ'),
#  ('p', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('U.', 'NNP'),
#  ('S.', 'NNP'),
#  ('Term', 'NNP'),
#  ('Limits', 'NNP'),
#  (',', ','),
#  ('Inc.', 'NNP'),
#  ('v.', 'NNP'),
#  ('Thornton', 'NNP'),
#  (',', ','),
#  ('514', 'CD'),
#  ('U', 'NNP'),
#  ('....', 'NN'),
#  ('I', 'PRP'),
#  ('join', 'VBP'),
#  ('the', 'DT'),
#  ('opinion', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  (',', ','),
#  ('holding', 'VBG'),
#  ('§', 'JJ'),
#  ('15', 'CD'),
#  ('...', ':'),
#  ('Under', 'IN'),
#  ('the', 'DT'),
#  ('Truth', 'NNP'),
#  ('in', 'IN'),
#  ('Lending', 'NNP'),
#  ('Act', 'NNP'),
#  (',', ','),
#  ('82', 'CD'),
#  ('Stat', 'NNP'),
#  ('.', '.'),
#  ('146', 'CD'),
#  (',', ','),
#  ('...', ':'),
#  ('These', 'DT'),
#  ('consolidated', 'JJ'),
#  ('cases', 'NNS'),
#  ('raise', 'VBP'),
#  ('questions', 'NNS'),
#  ('conce', 'NN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('whether', 'IN'),
#  ('a', 'DT'),
#  ('comp', 'NN'),
#  ('...', ':'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('well', 'RB'),
#  ('established', 'VBN'),
#  ('that', 'IN'),
#  ('federal', 'JJ'),
#  (',', ','),
#  ('state', 'NN'),
#  (',', ','),
#  ('an', 'DT'),
#  ('...', ':'),
#  ('Petitioner', 'NN'),
#  ('Michael', 'NNP'),
#  ('A.', 'NNP'),
#  ('Haddle', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('at-will', 'JJ'),
#  ('emplo', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('State', 'NNP'),
#  ('of', 'IN'),
#  ('Washington', 'NNP'),
#  (',', ','),
#  ('like', 'IN'),
#  ('every', 'DT'),
#  ('other', 'JJ'),
#  ('Stat', 'NNP'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Court', 'NNP'),
#  ('today', 'NN'),
#  ('concludes', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('of', 'IN'),
#  ('Wa', 'NNP'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('principal', 'JJ'),
#  ('dissenting', 'JJ'),
#  ('opinion', 'NN'),
#  (',', ','),
#  ('authored', 'VBN'),
#  ('by', 'IN'),
#  ('...', ':'),
#  ('[', 'JJ'),
#  ('*', 'NNP'),
#  (']', 'NNP'),
#  ('\\nThe', 'NNP'),
#  ('question', 'NN'),
#  ('posed', 'VBD'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  (',', ','),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('...', ':'),
#  ('As', 'IN'),
#  ('the', 'DT'),
#  ('Government', 'NNP'),
#  ('reads', 'VBZ'),
#  ('the', 'DT'),
#  ('Americans', 'NNPS'),
#  ('with', 'IN'),
#  ('Dis', 'NNP'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('Wilson', 'NNP'),
#  ('v.', 'FW'),
#  ('Arkansas', 'NNP'),
#  (',', ','),
#  ('514', 'CD'),
#  ('U.S.', 'NNP'),
#  ('927', 'CD'),
#  ('(', '('),
#  ('1995', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('...', ':'),
#  ('A', 'DT'),
#  ('Washington', 'NNP'),
#  ('statute', 'NN'),
#  ('provides', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('designa', 'NN'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('join', 'VBP'),
#  ('the', 'DT'),
#  ('opinion', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  (',', ','),
#  ('since', 'IN'),
#  ('I', 'PRP'),
#  ('belie', 'VBP'),
#  ('...', ':'),
#  ('Like', 'IN'),
#  ('Justice', 'NNP'),
#  ('Scalia', 'NNP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('believe', 'VBP'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('should', 'MD'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('severability', 'NN'),
#  ('issue', 'NN'),
#  ('discussed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ("'", 'POS'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('Criminal', 'NNP'),
#  ('Code', 'NNP'),
#  ('makes', 'VBZ'),
#  ('it\\n', 'NN'),
#  ("''", "''"),
#  ('unl', 'NN'),
#  ('...', ':'),
#  ('Gary', 'NNP'),
#  ('Small', 'NNP'),
#  (',', ','),
#  ('having', 'VBG'),
#  ('recently', 'RB'),
#  ('emerged', 'VBN'),
#  ('from', 'IN'),
#  ('three', 'CD'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Americans', 'NNPS'),
#  ('with', 'IN'),
#  ('Disabilities', 'NNP'),
#  ('Act', 'NNP'),
#  ('of', 'IN'),
#  ('1990', 'CD'),
#  ('(', '('),
#  ('A', 'DT'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('Miranda', 'NNP'),
#  ('v.', 'NN'),
#  ('Arizona', 'NNP'),
#  (',', ','),
#  ('384', 'CD'),
#  ('U.S.', 'NNP'),
#  ('436', 'CD'),
#  ('(', '('),
#  ('1966', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('...', ':'),
#  ('Those', 'DT'),
#  ('to', 'TO'),
#  ('whom', 'WP'),
#  ('judicial', 'JJ'),
#  ('decisions', 'NNS'),
#  ('are', 'VBP'),
#  ('an', 'DT'),
#  ('unconn', 'JJ'),
#  ('...', ':'),
#  ('A', 'DT'),
#  ('regulation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Equal', 'JJ'),
#  ('Employment', 'NNP'),
#  ('Opportuni', 'NNP'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('simple', 'JJ'),
#  ('case', 'NN'),
#  ('and', 'CC'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('simply', 'RB'),
#  ('res', 'NNS'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('State', 'NNP'),
#  ('of', 'IN'),
#  ('Kansas', 'NNP'),
#  ('imposes', 'VBZ'),
#  ('a', 'DT'),
#  ('tax', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('recei', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Kansas', 'NNP'),
#  ('fuel', 'NN'),
#  ('tax', 'NN'),
#  ('at', 'IN'),
#  ('issue', 'NN'),
#  ('is', 'VBZ'),
#  ('imposed', 'VBN'),
#  ('on', 'IN'),
#  ('dis', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('petitioner', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  (',', ','),
#  ('Richard', 'NNP'),
#  ('Trest', 'NNP'),
#  (',', ','),
#  ('se', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Eleventh', 'NNP'),
#  ('Amendment', 'NNP'),
#  ('grants', 'VBZ'),
#  ('a', 'DT'),
#  ('State', 'NNP'),
#  ('immunity', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('Indian', 'JJ'),
#  ('Gaming', 'NNP'),
#  ('Regulatory', 'NNP'),
#  ('Act', 'NNP'),
#  ('provides', 'VBZ'),
#  ('that', 'IN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('is', 'VBZ'),
#  ('about', 'IN'),
#  ('power\x97the', 'JJ'),
#  ('power', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Cong', 'NNP'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('holding', 'VBG'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('of', 'IN'),
#  ('Florida', 'NNP'),
#  ('immune', 'NN'),
#  ('to', 'TO'),
#  ('suit', 'NN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('whether', 'IN'),
#  ('a', 'DT'),
#  ('fron', 'NN'),
#  ('...', ':'),
#  ('A', 'DT'),
#  ('State', 'NNP'),
#  ('may', 'MD'),
#  ('tax', 'NN'),
#  ('a', 'DT'),
#  ('proportionate', 'NN'),
#  ('share', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('i', 'NN'),
#  ('...', ':'),
#  ('1\\n', 'CD'),
#  ('Petitioner', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('nonprofit', 'JJ'),
#  ('trade', 'NN'),
#  ('associa', 'NN'),
#  ('...', ':'),
#  ('22\\n', 'CD'),
#  ('Petitioner', 'NNP'),
#  ('seeks', 'VBZ'),
#  ('this', 'DT'),
#  ('Court', 'NNP'),
#  ("'s", 'POS'),
#  ('resolu', 'NN'),
#  ('...', ':'),
#  ('35\\n', 'CD'),
#  ('Like', 'IN'),
#  ('the', 'DT'),
#  ('majority', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('believe', 'VBP'),
#  ('that', 'IN'),
#  ('pe', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('question', 'NN'),
#  ('presented', 'VBN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('an', 'DT'),
#  ('Ohio', 'NNP'),
#  ('stat', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('dissent', 'NN'),
#  ('is', 'VBZ'),
#  ('stirring', 'VBG'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('appreciation', 'NN'),
#  ('of', 'IN'),
#  ('...', ':'),
#  ('At', 'IN'),
#  ('a', 'DT'),
#  ('time', 'NN'),
#  ('when', 'WRB'),
#  ('both', 'DT'),
#  ('political', 'JJ'),
#  ('branches', 'NNS'),
#  ('of', 'IN'),
#  ('Gove', 'NNP'),
#  ('...', ':'),
#  ('To', 'TO'),
#  ('qualify', 'VB'),
#  ('for', 'IN'),
#  ('court', 'NN'),
#  ('approval', 'NN'),
#  ('under', 'IN'),
#  ('Chapter', 'NN'),
#  ('13', 'CD'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('the', 'DT'),
#  ('issue', 'NN'),
#  ('of', 'IN'),
#  ('what', 'WP'),
#  ('the', 'DT'),
#  ('prope', 'NN'),
#  ('...', ':'),
#  ('My', 'NNP'),
#  ('areas', 'NNS'),
#  ('of', 'IN'),
#  ('agreement', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('plurality', 'NN'),
#  ('are', 'VBP'),
#  ('s', 'NNS'),
#  ('...', ':'),
#  ('For', 'IN'),
#  ('reasons', 'NNS'),
#  ('previously', 'RB'),
#  ('stated', 'VBN'),
#  (',', ','),
#  ('see', 'VBP'),
#  ('Martin', 'NNP'),
#  ('v.', 'NN'),
#  ('D', 'NNP'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('concerns', 'VBZ'),
#  ('the', 'DT'),
#  ('fees', 'NNS'),
#  ('that', 'WDT'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('awarde', 'JJ'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('know', 'VB'),
#  ('what', 'WP'),
#  ('the', 'DT'),
#  ('judges', 'NNS'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('district', 'NN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('concerns', 'VBZ'),
#  ('the', 'DT'),
#  ('legitimacy', 'NN'),
#  ('under', 'IN'),
#  ('Rule', 'NNP'),
#  ('2', 'CD'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('copyright', 'JJ'),
#  ('case', 'NN'),
#  ('concerns', 'VBZ'),
#  ('the', 'DT'),
#  ('rights', 'NNS'),
#  ('of', 'IN'),
#  ('fre', 'NN'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('raises', 'VBZ'),
#  ('an', 'DT'),
#  ('issue', 'NN'),
#  ('of', 'IN'),
#  ('first', 'JJ'),
#  ('impression', 'NN'),
#  ('...', ':'),
#  ('We', 'PRP'),
#  ('consider', 'VBP'),
#  ('whether', 'IN'),
#  ('§', 'NN'),
#  ('7002', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Resource', 'NNP'),
#  ('Con', 'NNP'),
#  ('...', ':'),
#  ('We', 'PRP'),
#  ('granted', 'VBD'),
#  ('certiorari', 'NN'),
#  ('to', 'TO'),
#  ('determine', 'VB'),
#  ('whether', 'IN'),
#  ('the', 'DT'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('join', 'VBP'),
#  ('the', 'DT'),
#  ('Court', 'NNP'),
#  ("'s", 'POS'),
#  ('opinion', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('add', 'VBP'),
#  ('that', 'IN'),
#  ('even', 'RB'),
#  ('...', ':'),
#  ('We', 'PRP'),
#  ('granted', 'VBD'),
#  ('certiorari', 'NN'),
#  ('to', 'TO'),
#  ('consider', 'VB'),
#  ('the', 'DT'),
#  ('analysis', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('we', 'PRP'),
#  ('consider', 'VBP'),
#  ('two', 'CD'),
#  ('questions', 'NNS'),
#  ('about', 'IN'),
#  ('h', 'NN'),
#  ('...', ':'),
#  ('Two', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('ordered', 'VBD'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('certificate', 'NN'),
#  ('o', 'NN'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('Batson', 'NNP'),
#  ('v.', 'NN'),
#  ('Kentucky', 'NNP'),
#  (',', ','),
#  ('476', 'CD'),
#  ('U.S.', 'NNP'),
#  ('79', 'CD'),
#  ('(', '('),
#  ('1986', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('the', 'DT'),
#  ('...', ':'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('early', 'JJ'),
#  ('morning', 'NN'),
#  ('hours', 'NNS'),
#  ('of', 'IN'),
#  ('November', 'NNP'),
#  ('16', 'CD'),
#  (',', ','),
#  ('198', 'CD'),
#  ('...', ':'),
#  ('This', 'DT'),
#  ('case', 'NN'),
#  ('raises', 'VBZ'),
#  ('a', 'DT'),
#  ('constitutional', 'JJ'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('pruden', 'NN'),
#  ('...', ':'),
#  ('I', 'PRP'),
#  ('agree', 'VBP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('majority', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Constitutio', 'NNP'),
#  ('...', ':'),
#  ('[', 'VBP'),
#  ('\x86', 'JJ'),
#  (']', 'NNP'),
#  ('\\nThis', 'NNP'),
#  ('case', 'NN'),
#  ('presents', 'VBZ'),
#  ('two', 'CD'),
#  ('questions', 'NNS'),
#  ('affectin', 'VBP'),
#  ('...', ':'),
#  ('Congress', 'NNP'),
#  ('has', 'VBZ'),
#  ('provided', 'VBN'),
#  (',', ','),
#  ('in', 'IN'),
#  ('18', 'CD'),
#  ('U.S.', 'NNP'),
#  ('C.', 'NNP'),
#  ('§', 'NN'),
#  ('3621', 'CD'),
#  ('(', '('),
#  ('e', 'NN'),
#  (')', ')'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('question', 'NN'),
#  ('at', 'IN'),
#  ('issue', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('issue', 'NN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('the', 'DT'),
#  ('Burma', 'NNP'),
#  ('law', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Comm', 'NNP'),
#  ('...', ':'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('perfectly', 'RB'),
#  ('obvious', 'JJ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('face', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('st', 'NN'),
#  ('...', ':'),
#  ('The', 'DT'),
#  ('issue', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('case', 'NN'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('Massachusett', 'NNP'),
#  ...]

# %% [markdown]
# ### 4) Lemmatization

# %%
import spacy

spacy_obj = spacy.load("en_core_web_sm")

processed = spacy_obj(selected_opinions_string)
type(processed)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in processed:
    print("word:", token.text, "lemma:", token.lemma_, "POS:", token.pos_, "another POS:", token.tag_, "entity ID", token.ent_id_, "sentiment", token.sentiment)
# Out:
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: presents lemma: present POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: workpl lemma: workpl POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: concur lemma: concur POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: because lemma: because POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: stresses lemma: stress POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ev lemma: ev POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Section lemma: Section POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 102(b lemma: 102(b POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ) lemma: ) POS: PUNCT another POS: -RRB- entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Patent lemma: Patent POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Act lemma: Act POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: 1952 lemma: 1952 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: provi lemma: provi POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Administrative lemma: Administrative POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Procedure lemma: Procedure POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Act lemma: Act POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ( lemma: ( POS: PUNCT another POS: -LRB- entity ID  sentiment 0.0
# word: APA lemma: APA POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ) lemma: ) POS: PUNCT another POS: -RRB- entity ID  sentiment 0.0
# word: sets lemma: set POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: fo lemma: fo POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: issue lemma: issue POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: this lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: at lemma: at POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: time lemma: time POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Supreme lemma: Supreme POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: South lemma: South POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Carolina lemma: Carolina POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: dismissed lemma: dismiss POS: VERB another POS: VBD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: joining lemma: join POS: VERB another POS: VBG entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: today lemma: today POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: do lemma: do POS: AUX another POS: VBP entity ID  sentiment 0.0
# word: not lemma: not POS: PART another POS: RB entity ID  sentiment 0.0
# word: signal lemma: signal POS: VERB another POS: VB entity ID  sentiment 0.0
# word: an lemma: an POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: State lemma: State POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Michigan lemma: Michigan POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: by lemma: by POS: ADP another POS: IN entity ID  sentiment 0.0
# word: regulation lemma: regulation POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: places lemma: place POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: c lemma: c POS: X another POS: LS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Our lemma: our POS: PRON another POS: PRP$ entity ID  sentiment 0.0
# word: decision lemma: decision POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: today lemma: today POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: faithful lemma: faithful POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: to lemma: to POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: principl lemma: principl POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Arizona lemma: Arizona POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: law lemma: law POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: authorizes lemma: authorize POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: income lemma: income POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: - lemma: - POS: PUNCT another POS: HYPH entity ID  sentiment 0.0
# word: tax lemma: tax POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: credits lemma: credit POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: for lemma: for POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Part lemma: Part POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: IV lemma: iv POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: his lemma: his POS: PRON another POS: PRP$ entity ID  sentiment 0.0
# word: dissent lemma: dissent POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: JUSTICE lemma: JUSTICE POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: KENNEDY lemma: KENNEDY POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: obs lemma: ob POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: this lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: shows lemma: show POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: great lemma: great POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: skepticism lemma: skepticism POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Federal lemma: federal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: courts lemma: court POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: lack lemma: lack POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: competence lemma: competence POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: to lemma: to POS: PART another POS: TO entity ID  sentiment 0.0
# word: rule lemma: rule POS: VERB another POS: VB entity ID  sentiment 0.0
# word: definit lemma: definit POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: A lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: number lemma: number POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: growers lemma: grower POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: handlers lemma: handler POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: and lemma: and POS: CCONJ another POS: CC entity ID  sentiment 0.0
# word: processors lemma: processor POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: today lemma: today POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: finds lemma: find POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: no lemma: no POS: DET another POS: DT entity ID  sentiment 0.0
# word: First lemma: First POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Amendment lemma: Amendment POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: right lemma: right POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I\nI lemma: i\ni POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: join lemma: join POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: Justice lemma: Justice POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Souter lemma: Souter POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 's lemma: 's POS: PART another POS: POS entity ID  sentiment 0.0
# word: dissent lemma: dissent POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: with lemma: with POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: e lemma: e POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Sierra lemma: Sierra POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Club lemma: Club POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: challenges lemma: challenge POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: lawfulness lemma: lawfulness POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: a lemma: a POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Section lemma: section POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: 3 lemma: 3 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Religious lemma: Religious POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Land lemma: Land POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Use lemma: Use POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: and lemma: and POS: CCONJ another POS: CC entity ID  sentiment 0.0
# word: Instit lemma: Instit POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: agree lemma: agree POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: with lemma: with POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: presents lemma: present POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: At lemma: At POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: involves lemma: involve POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: an lemma: an POS: DET another POS: DT entity ID  sentiment 0.0
# word: action lemma: action POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: for lemma: for POS: ADP another POS: IN entity ID  sentiment 0.0
# word: damages lemma: damage POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: again lemma: again POS: ADV another POS: RB entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: agree lemma: agree POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: with lemma: with POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Justice lemma: Justice POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Ginsburg lemma: Ginsburg POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: " lemma: " POS: PUNCT another POS: `` entity ID  sentiment 0.0
# word: common lemma: common POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: sen lemma: sen POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: A lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: fatal lemma: fatal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: accident lemma: accident POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: occurred lemma: occur POS: VERB another POS: VBD entity ID  sentiment 0.0
# word: on lemma: on POS: ADP another POS: IN entity ID  sentiment 0.0
# word: October lemma: October POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 3 lemma: 3 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 1993 lemma: 1993 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Respondent lemma: Respondent POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Hurley lemma: Hurley POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Henson lemma: Henson POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: filed lemma: file POS: VERB another POS: VBD entity ID  sentiment 0.0
# word: suit lemma: suit POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: state lemma: state POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: c lemma: c POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: As lemma: as POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: acknowledges lemma: acknowledge POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: ante lemma: ante POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: at lemma: at POS: ADP another POS: IN entity ID  sentiment 0.0
# word: 32 lemma: 32 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: de lemma: de POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: X another POS: FW entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: these lemma: these POS: DET another POS: DT entity ID  sentiment 0.0
# word: consolidated lemma: consolidated POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: cases lemma: case POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: two lemma: two POS: NUM another POS: CD entity ID  sentiment 0.0
# word: individuals lemma: individual POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: s lemma: s POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: today lemma: today POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: holds lemma: hold POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: claims lemma: claim POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: responde lemma: responde POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: before lemma: before POS: ADP another POS: IN entity ID  sentiment 0.0
# word: us lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: this lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 's lemma: 's POS: PART another POS: POS entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: my lemma: my POS: PRON another POS: PRP$ entity ID  sentiment 0.0
# word: view lemma: view POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: prior lemma: prior POS: ADV another POS: RB entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: presented lemma: present POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: an lemma: an POS: DET another POS: DT entity ID  sentiment 0.0
# word: injunctio lemma: injunctio POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Ford lemma: Ford POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: v. lemma: v. POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Wainwright lemma: Wainwright POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 477 lemma: 477 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U.S. lemma: U.S. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 399 lemma: 399 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 410 lemma: 410 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ( lemma: ( POS: PUNCT another POS: -LRB- entity ID  sentiment 0.0
# word: 1986 lemma: 1986 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: It lemma: it POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: axiomatic lemma: axiomatic POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: " lemma: " POS: PUNCT another POS: `` entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: power lemma: power POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: to lemma: to POS: PART another POS: TO entity ID  sentiment 0.0
# word: award lemma: award POS: VERB another POS: VB entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: w lemma: w POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: From lemma: from POS: ADP another POS: IN entity ID  sentiment 0.0
# word: 1986 lemma: 1986 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: to lemma: to POS: ADP another POS: IN entity ID  sentiment 0.0
# word: 1991 lemma: 1991 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: respondent lemma: respondent POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: filed lemma: file POS: VERB another POS: VBD entity ID  sentiment 0.0
# word: three lemma: three POS: NUM another POS: CD entity ID  sentiment 0.0
# word: peti lemma: peti POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: We lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: address lemma: address POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: this lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: 23 lemma: 23 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U.S. lemma: U.S. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: C. lemma: C. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: § lemma: § POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 4 lemma: 4 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: An lemma: an POS: DET another POS: DT entity ID  sentiment 0.0
# word: offender lemma: offender POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: had lemma: have POS: AUX another POS: VBD entity ID  sentiment 0.0
# word: been lemma: be POS: AUX another POS: VBN entity ID  sentiment 0.0
# word: serving lemma: serve POS: VERB another POS: VBG entity ID  sentiment 0.0
# word: time lemma: time POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: federal lemma: federal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: p lemma: p POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: U. lemma: U. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: S. lemma: S. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Term lemma: Term POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Limits lemma: Limits POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: Inc. lemma: Inc. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: v. lemma: v. POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Thornton lemma: Thornton POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 514 lemma: 514 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U lemma: u POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: .... lemma: .... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: holding lemma: hold POS: VERB another POS: VBG entity ID  sentiment 0.0
# word: § lemma: § POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 15 lemma: 15 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Under lemma: under POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Truth lemma: truth POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Lending lemma: Lending POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Act lemma: Act POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 82 lemma: 82 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: Stat lemma: Stat POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: . lemma: . POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 146 lemma: 146 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: These lemma: these POS: DET another POS: DT entity ID  sentiment 0.0
# word: consolidated lemma: consolidated POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: cases lemma: case POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: raise lemma: raise POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: questions lemma: question POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: conce lemma: conce POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: presents lemma: present POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: a lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: comp lemma: comp POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: It lemma: it POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: well lemma: well POS: ADV another POS: RB entity ID  sentiment 0.0
# word: established lemma: establish POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: federal lemma: federal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: state lemma: state POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: an lemma: an POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Petitioner lemma: Petitioner POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Michael lemma: Michael POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: A. lemma: A. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Haddle lemma: Haddle POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: an lemma: an POS: DET another POS: DT entity ID  sentiment 0.0
# word: at lemma: at POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: - lemma: - POS: PUNCT another POS: HYPH entity ID  sentiment 0.0
# word: will lemma: will POS: AUX another POS: MD entity ID  sentiment 0.0
# word: emplo lemma: emplo POS: VERB another POS: VB entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: State lemma: State POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Washington lemma: Washington POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: like lemma: like POS: ADP another POS: IN entity ID  sentiment 0.0
# word: every lemma: every POS: DET another POS: DT entity ID  sentiment 0.0
# word: other lemma: other POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: Stat lemma: Stat POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: today lemma: today POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: concludes lemma: conclude POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: State lemma: State POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Wa lemma: Wa POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: principal lemma: principal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: dissenting lemma: dissent POS: VERB another POS: VBG entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: authored lemma: author POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: by lemma: by POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: [ lemma: [ POS: X another POS: XX entity ID  sentiment 0.0
# word: * lemma: * POS: X another POS: XX entity ID  sentiment 0.0
# word: ] lemma: ] POS: X another POS: XX entity ID  sentiment 0.0
# word: \nThe lemma: \nthe POS: NUM another POS: CD entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: posed lemma: pose POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: under lemma: under POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: As lemma: as POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Government lemma: government POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: reads lemma: read POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Americans lemma: Americans POS: PROPN another POS: NNPS entity ID  sentiment 0.0
# word: with lemma: with POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Dis lemma: Dis POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Wilson lemma: Wilson POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: v. lemma: v. POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Arkansas lemma: Arkansas POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 514 lemma: 514 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U.S. lemma: U.S. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 927 lemma: 927 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ( lemma: ( POS: PUNCT another POS: -LRB- entity ID  sentiment 0.0
# word: 1995 lemma: 1995 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ) lemma: ) POS: PUNCT another POS: -RRB- entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: we lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: A lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: Washington lemma: Washington POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: statute lemma: statute POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: provides lemma: provide POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: designa lemma: designa POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: since lemma: since POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: belie lemma: belie POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Like lemma: like POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Justice lemma: Justice POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Scalia lemma: Scalia POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: believe lemma: believe POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: we lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: should lemma: should POS: AUX another POS: MD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: severability lemma: severability POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: issue lemma: issue POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: discussed lemma: discuss POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ' lemma: ' POS: PUNCT another POS: '' entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: United lemma: United POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: States lemma: States POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Criminal lemma: Criminal POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Code lemma: Code POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: makes lemma: make POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: it\n"unl lemma: it\n"unl POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Gary lemma: Gary POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Small lemma: Small POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: having lemma: having POS: AUX another POS: VBG entity ID  sentiment 0.0
# word: recently lemma: recently POS: ADV another POS: RB entity ID  sentiment 0.0
# word: emerged lemma: emerge POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: from lemma: from POS: ADP another POS: IN entity ID  sentiment 0.0
# word: three lemma: three POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Americans lemma: Americans POS: PROPN another POS: NNPS entity ID  sentiment 0.0
# word: with lemma: with POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Disabilities lemma: Disabilities POS: PROPN another POS: NNPS entity ID  sentiment 0.0
# word: Act lemma: Act POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: 1990 lemma: 1990 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ( lemma: ( POS: PUNCT another POS: -LRB- entity ID  sentiment 0.0
# word: A lemma: a POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Miranda lemma: Miranda POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: v. lemma: v. POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Arizona lemma: Arizona POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 384 lemma: 384 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U.S. lemma: U.S. POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 436 lemma: 436 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ( lemma: ( POS: PUNCT another POS: -LRB- entity ID  sentiment 0.0
# word: 1966 lemma: 1966 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: ) lemma: ) POS: PUNCT another POS: -RRB- entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: we lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Those lemma: those POS: PRON another POS: DT entity ID  sentiment 0.0
# word: to lemma: to POS: PART another POS: TO entity ID  sentiment 0.0
# word: whom lemma: whom POS: PRON another POS: WP entity ID  sentiment 0.0
# word: judicial lemma: judicial POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: decisions lemma: decision POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: are lemma: be POS: AUX another POS: VBP entity ID  sentiment 0.0
# word: an lemma: an POS: DET another POS: DT entity ID  sentiment 0.0
# word: unconn lemma: unconn POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: A lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: regulation lemma: regulation POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Equal lemma: Equal POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Employment lemma: Employment POS: PROPN another POS: NNP entity ID  sentiment 0.0
# ...
# word: Florida lemma: Florida POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: police lemma: police POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: obta lemma: obta POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: this lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: we lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: decide lemma: decide POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Eighth lemma: Eighth POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Ame lemma: Ame POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: In lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: my lemma: my POS: PRON another POS: PRP$ entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Harmelin lemma: Harmelin POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: v. lemma: v. POS: ADP another POS: IN entity ID  sentiment 0.0
# word: Michigan lemma: Michigan POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: 501 lemma: 501 POS: NUM another POS: CD entity ID  sentiment 0.0
# word: U.S lemma: U.S POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: JUSTICE lemma: JUSTICE POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: BREYER lemma: BREYER POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: has lemma: have POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: cogently lemma: cogently POS: ADV another POS: RB entity ID  sentiment 0.0
# word: explained lemma: explain POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: why lemma: why POS: SCONJ another POS: WRB entity ID  sentiment 0.0
# word: the lemma: the POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: constitutional lemma: constitutional POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: " lemma: " POS: PUNCT another POS: `` entity ID  sentiment 0.0
# word: th lemma: th POS: X another POS: XX entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: presents lemma: present POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: question lemma: question POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: a lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: defe lemma: defe POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: petitioner lemma: petitioner POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: had lemma: have POS: VERB another POS: VBD entity ID  sentiment 0.0
# word: no lemma: no POS: DET another POS: DT entity ID  sentiment 0.0
# word: constitutional lemma: constitutional POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: right lemma: right POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: to lemma: to POS: ADP another POS: IN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Sixth lemma: Sixth POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Amendment lemma: Amendment POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: provides lemma: provide POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: that lemma: that POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: accused lemma: accuse POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: issue lemma: issue POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: is lemma: be POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: a lemma: a POS: DET another POS: DT entity ID  sentiment 0.0
# word: state lemma: state POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: wide lemma: wide POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: association lemma: association POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: We lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: have lemma: have POS: AUX another POS: VBP entity ID  sentiment 0.0
# word: never lemma: never POS: ADV another POS: RB entity ID  sentiment 0.0
# word: found lemma: find POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: state lemma: state POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: action lemma: action POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: based lemma: base POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: upon lemma: upon POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: me lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Petitioner lemma: Petitioner POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Bernadine lemma: Bernadine POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Suitum lemma: Suitum POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: owns lemma: own POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: land lemma: land POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: near lemma: near POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: . entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: concur lemma: concur POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: in lemma: in POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: judgment lemma: judgment POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: , lemma: , POS: PUNCT another POS: , entity ID  sentiment 0.0
# word: and lemma: and POS: CCONJ another POS: CC entity ID  sentiment 0.0
# word: joi lemma: joi POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: We lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: per lemma: per POS: ADP another POS: IN entity ID  sentiment 0.0
# word: curiam lemma: curiam POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: We lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: write lemma: write POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: separ lemma: separ POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Constitution lemma: Constitution POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: assigns lemma: assign POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: to lemma: to POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: States lemma: States POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: pri lemma: pri POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: The lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: should lemma: should POS: AUX another POS: MD entity ID  sentiment 0.0
# word: not lemma: not POS: PART another POS: RB entity ID  sentiment 0.0
# word: have lemma: have POS: AUX another POS: VB entity ID  sentiment 0.0
# word: reviewed lemma: review POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: either lemma: either POS: CCONJ another POS: CC entity ID  sentiment 0.0
# word: Bush lemma: Bush POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: " lemma: " POS: PUNCT another POS: `` entity ID  sentiment 0.0
# word: Opportunity lemma: opportunity POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: does lemma: do POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: n't lemma: not POS: PART another POS: RB entity ID  sentiment 0.0
# word: always lemma: always POS: ADV another POS: RB entity ID  sentiment 0.0
# word: knock lemma: knock POS: VERB another POS: VB entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: . lemma: . POS: PUNCT another POS: . entity ID  sentiment 0.0
# word: someti lemma: someti POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: This lemma: this POS: DET another POS: DT entity ID  sentiment 0.0
# word: case lemma: case POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: concerns lemma: concern POS: VERB another POS: VBZ entity ID  sentiment 0.0
# word: what lemma: what POS: PRON another POS: WP entity ID  sentiment 0.0
# word: has lemma: have POS: AUX another POS: VBZ entity ID  sentiment 0.0
# word: come lemma: come POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: to lemma: to POS: PART another POS: TO entity ID  sentiment 0.0
# word: be lemma: be POS: AUX another POS: VB entity ID  sentiment 0.0
# word: known lemma: know POS: VERB another POS: VBN entity ID  sentiment 0.0
# word: a lemma: a POS: PRON another POS: DT entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Rules lemma: rule POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: of lemma: of POS: ADP another POS: IN entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Florida lemma: Florida POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: Bar lemma: Bar POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: prohibit lemma: prohibit POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: personal lemma: personal POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: inj lemma: inj POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: Attorneys lemma: attorney POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: who lemma: who POS: PRON another POS: WP entity ID  sentiment 0.0
# word: communicate lemma: communicate POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: their lemma: their POS: PRON another POS: PRP$ entity ID  sentiment 0.0
# word: willingness lemma: willingness POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: to lemma: to POS: PART another POS: TO entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: NFP entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: We lemma: we POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: must lemma: must POS: AUX another POS: MD entity ID  sentiment 0.0
# word: decide lemma: decide POS: VERB another POS: VB entity ID  sentiment 0.0
# word: whether lemma: whether POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: punitive lemma: punitive POS: ADJ another POS: JJ entity ID  sentiment 0.0
# word: damages lemma: damage POS: NOUN another POS: NNS entity ID  sentiment 0.0
# word: may lemma: may POS: AUX another POS: MD entity ID  sentiment 0.0
# word: be lemma: be POS: AUX another POS: VB entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0
# word:
#  lemma:
#  POS: SPACE another POS: _SP entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: join lemma: join POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: the lemma: the POS: DET another POS: DT entity ID  sentiment 0.0
# word: Court lemma: Court POS: PROPN another POS: NNP entity ID  sentiment 0.0
# word: 's lemma: 's POS: PART another POS: POS entity ID  sentiment 0.0
# word: opinion lemma: opinion POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: because lemma: because POS: SCONJ another POS: IN entity ID  sentiment 0.0
# word: I lemma: I POS: PRON another POS: PRP entity ID  sentiment 0.0
# word: agree lemma: agree POS: VERB another POS: VBP entity ID  sentiment 0.0
# word: tha lemma: tha POS: NOUN another POS: NN entity ID  sentiment 0.0
# word: ... lemma: ... POS: PUNCT another POS: : entity ID  sentiment 0.0

# %%
textprocessed = spacy_obj(selected_opinions_string)
for sent in textprocessed.sents:
    for token in sent:
        print((token.text, token.pos_), end = " ")
    print()
# Out:
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('workpl', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('concur', 'VERB') ('because', 'SCONJ') ('the', 'DET') ('Court', 'PROPN') ('stresses', 'VERB') ('that', 'SCONJ') ('in', 'ADP') ('ev', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('Section', 'PROPN') ('102(b', 'PROPN') (')', 'PUNCT') ('of', 'ADP') ('the', 'DET') ('Patent', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1952', 'NUM') ('provi', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Administrative', 'PROPN') ('Procedure', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('APA', 'PROPN') (')', 'PUNCT') ('sets', 'VERB') ('fo', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') (',', 'PUNCT') ('at', 'ADP') ('the', 'DET') ('time', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Supreme', 'PROPN') ('Court', 'PROPN') ('of', 'ADP') ('South', 'PROPN') ('Carolina', 'PROPN') ('dismissed', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('joining', 'VERB') ('the', 'DET') ('Court', 'PROPN') ('today', 'NOUN') (',', 'PUNCT') ('I', 'PRON') ('do', 'AUX') ('not', 'PART') ('signal', 'VERB') ('an', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Michigan', 'PROPN') (',', 'PUNCT') ('by', 'ADP') ('regulation', 'NOUN') (',', 'PUNCT') ('places', 'NOUN') ('c', 'X') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Our', 'PRON') ('decision', 'NOUN') ('today', 'NOUN') ('is', 'AUX') ('faithful', 'ADJ') ('to', 'ADP') ('the', 'DET') ('principl', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Arizona', 'PROPN') ('law', 'NOUN') ('authorizes', 'VERB') ('income', 'NOUN') ('-', 'PUNCT') ('tax', 'NOUN') ('credits', 'NOUN') ('for', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Part', 'PROPN') ('IV', 'NOUN') ('of', 'ADP') ('his', 'PRON') ('dissent', 'NOUN') (',', 'PUNCT') ('JUSTICE', 'PROPN') ('KENNEDY', 'PROPN') ('obs', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('the', 'DET') ('Court', 'PROPN') ('shows', 'VERB') ('great', 'ADJ') ('skepticism', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('Federal', 'ADJ') ('courts', 'NOUN') ('lack', 'VERB') ('competence', 'NOUN') ('to', 'PART') ('rule', 'VERB') ('definit', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('A', 'DET') ('number', 'NOUN') ('of', 'ADP') ('growers', 'NOUN') (',', 'PUNCT') ('handlers', 'NOUN') (',', 'PUNCT') ('and', 'CCONJ') ('processors', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('finds', 'VERB') ('no', 'DET') ('First', 'PROPN') ('Amendment', 'PROPN') ('right', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I\\nI', 'NOUN') ('join', 'NOUN') ('Justice', 'PROPN') ('Souter', 'PROPN') ("'s", 'PART') ('dissent', 'NOUN') (',', 'PUNCT') ('with', 'ADP') ('the', 'DET') ('e', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Sierra', 'PROPN') ('Club', 'PROPN') ('challenges', 'VERB') ('the', 'DET') ('lawfulness', 'NOUN') ('of', 'ADP') ('a', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('Section', 'NOUN') ('3', 'NUM') ('of', 'ADP') ('the', 'DET') ('Religious', 'PROPN') ('Land', 'PROPN') ('Use', 'PROPN') ('and', 'CCONJ') ('Instit', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('.', 'PUNCT')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('the', 'DET') ('At', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('involves', 'VERB') ('an', 'DET') ('action', 'NOUN') ('for', 'ADP') ('damages', 'NOUN') ('again', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('Justice', 'PROPN') ('Ginsburg', 'PROPN') ('that', 'SCONJ') ('"', 'PUNCT') ('common', 'ADJ') ('sen', 'PROPN') ('...', 'PROPN') ('\n', 'SPACE') ('A', 'DET') ('fatal', 'ADJ') ('accident', 'NOUN') ('occurred', 'VERB') ('on', 'ADP') ('October', 'PROPN') ('3', 'NUM') (',', 'PUNCT') ('1993', 'NUM') (',', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Respondent', 'PROPN') ('Hurley', 'PROPN') ('Henson', 'PROPN') ('filed', 'VERB') ('suit', 'NOUN') ('in', 'ADP') ('state', 'NOUN') ('c', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('As', 'SCONJ') ('the', 'DET') ('Court', 'PROPN') ('acknowledges', 'VERB') (',', 'PUNCT') ('ante', 'NOUN') (',', 'PUNCT') ('at', 'ADP') ('32', 'NUM') (',', 'PUNCT') ('the', 'DET') ('de', 'NOUN') ('...', 'X') ('\n', 'SPACE')
# ('In', 'ADP') ('these', 'DET') ('consolidated', 'ADJ') ('cases', 'NOUN') (',', 'PUNCT') ('two', 'NUM') ('individuals', 'NOUN') ('s', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('holds', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('claims', 'NOUN') ('responde', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('before', 'ADP') ('us', 'PRON') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('.', 'PUNCT')
# ('In', 'ADP') ('my', 'PRON') ('view', 'NOUN') (',', 'PUNCT') ('prior', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('presented', 'VERB') ('is', 'AUX') ('whether', 'SCONJ') ('an', 'DET') ('injunctio', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Ford', 'PROPN') ('v.', 'ADP') ('Wainwright', 'PROPN') (',', 'PUNCT') ('477', 'NUM') ('U.S.', 'PROPN') ('399', 'NUM') (',', 'PUNCT') ('410', 'NUM') ('(', 'PUNCT') ('1986', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('It', 'PRON') ('is', 'AUX') ('axiomatic', 'ADJ') ('that', 'SCONJ') ('"', 'PUNCT') ('the', 'DET') ('power', 'NOUN') ('to', 'PART') ('award', 'VERB') ('the', 'DET') ('w', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('From', 'ADP') ('1986', 'NUM') ('to', 'ADP') ('1991', 'NUM') (',', 'PUNCT') ('respondent', 'NOUN') ('filed', 'VERB') ('three', 'NUM') ('peti', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('We', 'PRON') ('address', 'VERB') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('whether', 'SCONJ') ('23', 'NUM') ('U.S.', 'PROPN') ('C.', 'PROPN') ('§', 'PROPN') ('4', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('An', 'DET') ('offender', 'NOUN') ('had', 'AUX') ('been', 'AUX') ('serving', 'VERB') ('time', 'NOUN') ('in', 'ADP') ('federal', 'ADJ') ('p', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('U.', 'PROPN') ('S.', 'PROPN') ('Term', 'PROPN') ('Limits', 'PROPN') (',', 'PUNCT') ('Inc.', 'PROPN') ('v.', 'ADP') ('Thornton', 'PROPN') (',', 'PUNCT') ('514', 'NUM') ('U', 'NOUN') ('....', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') (',', 'PUNCT') ('holding', 'VERB') ('§', 'PROPN') ('15', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Under', 'ADP') ('the', 'DET') ('Truth', 'NOUN') ('in', 'ADP') ('Lending', 'PROPN') ('Act', 'PROPN') (',', 'PUNCT') ('82', 'NUM') ('Stat', 'PROPN') ('.', 'PROPN') ('146', 'NUM') (',', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE') ('These', 'DET') ('consolidated', 'ADJ') ('cases', 'NOUN') ('raise', 'VERB') ('questions', 'NOUN') ('conce', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('a', 'DET') ('comp', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('It', 'PRON') ('is', 'AUX') ('well', 'ADV') ('established', 'VERB') ('that', 'SCONJ') ('federal', 'ADJ') (',', 'PUNCT') ('state', 'PROPN') (',', 'PUNCT') ('an', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('Michael', 'PROPN') ('A.', 'PROPN') ('Haddle', 'PROPN') (',', 'PUNCT') ('an', 'DET') ('at', 'NOUN') ('-', 'PUNCT') ('will', 'AUX') ('emplo', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Washington', 'PROPN') (',', 'PUNCT') ('like', 'ADP') ('every', 'DET') ('other', 'ADJ') ('Stat', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('concludes', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Wa', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('principal', 'ADJ') ('dissenting', 'VERB') ('opinion', 'NOUN') (',', 'PUNCT') ('authored', 'VERB') ('by', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('[', 'X') ('*', 'X') (']', 'X') ('\\nThe', 'NUM') ('question', 'NOUN') ('posed', 'VERB') ('is', 'AUX') ('whether', 'SCONJ') (',', 'PUNCT') ('under', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('As', 'SCONJ') ('the', 'DET') ('Government', 'NOUN') ('reads', 'VERB') ('the', 'DET') ('Americans', 'PROPN') ('with', 'ADP') ('Dis', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Wilson', 'PROPN') ('v.', 'ADP') ('Arkansas', 'PROPN') (',', 'PUNCT') ('514', 'NUM') ('U.S.', 'PROPN') ('927', 'NUM') ('(', 'PUNCT') ('1995', 'NUM') (')', 'PUNCT') (',', 'PUNCT') ('we', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('A', 'DET') ('Washington', 'PROPN') ('statute', 'NOUN') ('provides', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('designa', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') (',', 'PUNCT') ('since', 'SCONJ') ('I', 'PRON') ('belie', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Like', 'ADP') ('Justice', 'PROPN') ('Scalia', 'PROPN') (',', 'PUNCT') ('I', 'PRON') ('believe', 'VERB') ('that', 'SCONJ') ('we', 'PRON') ('should', 'AUX') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('severability', 'NOUN') ('issue', 'NOUN') ('discussed', 'VERB') ('in', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'", 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('United', 'PROPN') ('States', 'PROPN') ('Criminal', 'PROPN') ('Code', 'PROPN') ('makes', 'VERB') ('it\\n"unl', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Gary', 'PROPN') ('Small', 'PROPN') (',', 'PUNCT') ('having', 'AUX') ('recently', 'ADV') ('emerged', 'VERB') ('from', 'ADP') ('three', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Americans', 'PROPN') ('with', 'ADP') ('Disabilities', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1990', 'NUM') ('(', 'PUNCT') ('A', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('In', 'ADP') ('Miranda', 'PROPN') ('v.', 'ADP') ('Arizona', 'PROPN') (',', 'PUNCT') ('384', 'NUM') ('U.S.', 'PROPN') ('436', 'NUM') ('(', 'PUNCT') ('1966', 'NUM') (')', 'PUNCT') (',', 'PUNCT') ('we', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Those', 'PRON') ('to', 'PART') ('whom', 'PRON') ('judicial', 'ADJ') ('decisions', 'NOUN') ('are', 'AUX') ('an', 'DET') ('unconn', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('A', 'DET') ('regulation', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Equal', 'PROPN') ('Employment', 'PROPN') ('Opportuni', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'PRON') ('is', 'AUX') ('a', 'DET') ('simple', 'ADJ') ('case', 'NOUN') ('and', 'CCONJ') ('should', 'AUX') ('be', 'AUX') ('simply', 'ADV') ('res', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Kansas', 'PROPN') ('imposes', 'VERB') ('a', 'DET') ('tax', 'NOUN') ('on', 'ADP') ('the', 'DET') ('recei', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Kansas', 'PROPN') ('fuel', 'NOUN') ('tax', 'NOUN') ('at', 'ADP') ('issue', 'NOUN') ('is', 'AUX') ('imposed', 'VERB') ('on', 'ADP') ('dis', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('petitioner', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('Richard', 'PROPN') ('Trest', 'PROPN') (',', 'PUNCT') ('se', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Eleventh', 'PROPN') ('Amendment', 'PROPN') ('grants', 'VERB') ('a', 'DET') ('State', 'PROPN') ('immunity', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Indian', 'PROPN') ('Gaming', 'PROPN') ('Regulatory', 'PROPN') ('Act', 'PROPN') ('provides', 'VERB') ('that', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('is', 'AUX') ('about', 'ADP') ('power\x97the', 'DET') ('power', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Cong', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('holding', 'VERB') ('the', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Florida', 'PROPN') ('immune', 'NOUN') ('to', 'ADP') ('suit', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('a', 'DET') ('fron', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('A', 'DET') ('State', 'PROPN') ('may', 'AUX') ('tax', 'VERB') ('a', 'DET') ('proportionate', 'ADJ') ('share', 'NOUN') ('of', 'ADP') ('the', 'DET') ('i', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('1\\n', 'PROPN') ('     ', 'SPACE') ('Petitioner', 'PROPN') (',', 'PUNCT') ('a', 'DET') ('nonprofit', 'ADJ') ('trade', 'NOUN') ('associa', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('22\\n', 'NUM') ('     ', 'SPACE') ('Petitioner', 'PROPN') ('seeks', 'VERB') ('this', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('resolu', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('35\\n', 'NUM') ('     ', 'SPACE') ('Like', 'ADP') ('the', 'DET') ('majority', 'NOUN') (',', 'PUNCT') ('I', 'PRON') ('believe', 'VERB') ('that', 'SCONJ') ('pe', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('presented', 'VERB') ('is', 'AUX') ('whether', 'SCONJ') ('an', 'DET') ('Ohio', 'PROPN') ('stat', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('dissent', 'NOUN') ('is', 'AUX') ('stirring', 'VERB') ('in', 'ADP') ('its', 'PRON') ('appreciation', 'NOUN') ('of', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('At', 'ADP') ('a', 'DET') ('time', 'NOUN') ('when', 'SCONJ') ('both', 'DET') ('political', 'ADJ') ('branches', 'NOUN') ('of', 'ADP') ('Gove', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('To', 'PART') ('qualify', 'VERB') ('for', 'ADP') ('court', 'NOUN') ('approval', 'NOUN') ('under', 'ADP') ('Chapter', 'NOUN') ('13', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('issue', 'NOUN') ('of', 'ADP') ('what', 'PRON') ('the', 'DET') ('prope', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('My', 'PRON') ('areas', 'NOUN') ('of', 'ADP') ('agreement', 'NOUN') ('with', 'ADP') ('the', 'DET') ('plurality', 'NOUN') ('are', 'AUX') ('s', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('For', 'ADP') ('reasons', 'NOUN') ('previously', 'ADV') ('stated', 'VERB') (',', 'PUNCT') ('see', 'VERB') ('Martin', 'PROPN') ('v.', 'ADP') ('D', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('fees', 'NOUN') ('that', 'PRON') ('may', 'AUX') ('be', 'AUX') ('awarde', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('do', 'AUX') ('not', 'PART') ('know', 'VERB') ('what', 'PRON') ('the', 'DET') ('judges', 'NOUN') ('of', 'ADP') ('our', 'PRON') ('district', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('legitimacy', 'NOUN') ('under', 'ADP') ('Rule', 'PROPN') ('2', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('copyright', 'NOUN') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('rights', 'NOUN') ('of', 'ADP') ('fre', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('raises', 'VERB') ('an', 'DET') ('issue', 'NOUN') ('of', 'ADP') ('first', 'ADJ') ('impression', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('We', 'PRON') ('consider', 'VERB') ('whether', 'SCONJ') ('§', 'PROPN') ('7002', 'NUM') ('of', 'ADP') ('the', 'DET') ('Resource', 'PROPN') ('Con', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') ('to', 'PART') ('determine', 'VERB') ('whether', 'SCONJ') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') (',', 'PUNCT') ('and', 'CCONJ') ('add', 'VERB') ('that', 'SCONJ') ('even', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') ('to', 'PART') ('consider', 'VERB') ('the', 'DET') ('analysis', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') ('we', 'PRON') ('consider', 'VERB') ('two', 'NUM') ('questions', 'NOUN') ('about', 'ADP') ('h', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Two', 'NUM') ('years', 'NOUN') ('ago', 'ADV') (',', 'PUNCT') ('we', 'PRON') ('ordered', 'VERB') ('that', 'SCONJ') ('a', 'DET') ('certificate', 'NOUN') ('o', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Batson', 'PROPN') ('v.', 'ADP') ('Kentucky', 'PROPN') (',', 'PUNCT') ('476', 'NUM') ('U.S.', 'PROPN') ('79', 'NUM') ('(', 'PUNCT') ('1986', 'NUM') (')', 'PUNCT') (',', 'PUNCT') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('the', 'DET') ('early', 'ADJ') ('morning', 'NOUN') ('hours', 'NOUN') ('of', 'ADP') ('November', 'PROPN') ('16', 'NUM') (',', 'PUNCT') ('198', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('raises', 'VERB') ('a', 'DET') ('constitutional', 'ADJ') ('and', 'CCONJ') ('a', 'DET') ('pruden', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('majority', 'NOUN') ('that', 'PRON') ('the', 'DET') ('Constitutio', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('[', 'X') ('\x86]\\nThis', 'PRON') ('case', 'NOUN') ('presents', 'VERB') ('two', 'NUM') ('questions', 'NOUN') ('affectin', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Congress', 'PROPN') ('has', 'AUX') ('provided', 'VERB') (',', 'PUNCT') ('in', 'ADP') ('18', 'NUM') ('U.S.', 'PROPN') ('C.', 'PROPN') ('§', 'PROPN') ('3621(e', 'NOUN') (')', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('at', 'ADP') ('issue', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('the', 'DET') ('Burma', 'PROPN') ('law', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Comm', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('It', 'PRON') ('is', 'AUX') ('perfectly', 'ADV') ('obvious', 'ADJ') ('on', 'ADP') ('the', 'DET') ('face', 'NOUN') ('of', 'ADP') ('this', 'DET') ('st', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('Massachusett', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioners', 'NOUN') ('contend', 'VERB') ('that', 'SCONJ') ('a', 'DET') ('village', 'NOUN') ('ordinance', 'NOUN') ('m', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('While', 'SCONJ') ('joining', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') (',', 'PUNCT') ('I', 'PRON') ('write', 'VERB') ('sep', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Stratton', 'PROPN') ('is', 'AUX') ('a', 'DET') ('village', 'NOUN') ('of', 'ADP') ('278', 'NUM') ('people', 'NOUN') ('located', 'VERB') ('al', 'PROPN') ('...', 'PROPN') ('\n', 'SPACE')
# ('Section', 'PROPN') ('404(a', 'NUM') (')', 'PUNCT') ('of', 'ADP') ('the', 'DET') ('Clean', 'PROPN') ('Water', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('CWA', 'PROPN') ('or', 'CCONJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('1969', 'NUM') (',', 'PUNCT') ('the', 'DET') ('Cuyahoga', 'PROPN') ('River', 'PROPN') ('in', 'ADP') ('Cleveland', 'PROPN') (',', 'PUNCT') ('Ohio', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Under', 'ADP') ('a', 'DET') ('longstanding', 'ADJ') ('practice', 'NOUN') (',', 'PUNCT') ('a', 'DET') ('court', 'NOUN') ('sometim', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('concur', 'VERB') ('in', 'ADP') ('Parts', 'PROPN') ('I', 'PROPN') ('and', 'CCONJ') ('II', 'PROPN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opin', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('here', 'ADV') ('is', 'AUX') ('when', 'SCONJ') ('the', 'DET') ('1', 'NUM') ('-', 'PUNCT') ('year', 'NOUN') ('statute', 'NOUN') ('o', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('took', 'VERB') ('this', 'DET') ('case', 'NOUN') ('to', 'PART') ('determine', 'VERB') ('whether', 'SCONJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('claiman', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Margaret', 'PROPN') ('Whitecotton', 'PROPN') ('was', 'AUX') ('born', 'VERB') ('in', 'ADP') ('1975', 'NUM') ('with', 'ADP') ('a', 'DET') ('c', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('Since', 'SCONJ') ('the', 'DET') ('inception', 'NOUN') ('of', 'ADP') ('cable', 'NOUN') ('television', 'NOUN') (',', 'PUNCT') ('cab', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('One', 'NUM') ('century', 'NOUN') ('ago', 'ADV') (',', 'PUNCT') ('the', 'DET') ('first', 'ADJ') ('Justice', 'PROPN') ('Harlan', 'PROPN') ('admo', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('has', 'AUX') ('mistaken', 'VERB') ('a', 'DET') ('Kulturkampf', 'PROPN') ('for', 'ADP') ('a', 'DET') ('fit', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('presented', 'VERB') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('moratorium', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('For', 'ADP') ('over', 'ADP') ('half', 'DET') ('a', 'DET') ('decade', 'NOUN') ('petitioners', 'NOUN') ('were', 'AUX') ('prohib', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('The', 'DET') ('Chief', 'PROPN') ('Justice', 'PROPN') ("'s", 'PART') ('dissent', 'NOUN') ('.', 'PUNCT')
# ('I', 'PRON') ('write', 'VERB') ('se', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') (',', 'PUNCT') ('520', 'NUM') ('U.S.', 'PROPN') ('1239', 'NUM') ('(', 'PUNCT') ('1997', 'NUM') (')', 'PUNCT') (',', 'PUNCT') ('t', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('case', 'NOUN') ('was', 'AUX') ('submitted', 'VERB') ('to', 'ADP') ('a', 'DET') ('jury', 'NOUN') ('prior', 'ADV') ('to', 'ADP') ('our', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Since', 'SCONJ') ('1945', 'NUM') (',', 'PUNCT') ('a', 'DET') ('decree', 'NOUN') ('of', 'ADP') ('this', 'DET') ('Court', 'PROPN') ('has', 'VERB') ('ratione', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Student', 'PROPN') ('Activities', 'PROPN') ('Drug', 'PROPN') ('Testing', 'PROPN') ('Policy', 'PROPN') ('imp', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('that', 'SCONJ') ('Vernonia', 'PROPN') ('School', 'PROPN') ('Di', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('dissented', 'VERB') ('in', 'ADP') ('Vernonia', 'PROPN') ('School', 'PROPN') ('Dist', 'PROPN') ('.', 'PUNCT')
# ('47J', 'PROPN') ('v.', 'PROPN') ('Ac', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Seven', 'NUM') ('years', 'NOUN') ('ago', 'ADV') (',', 'PUNCT') ('in', 'ADP') ('Vernonia', 'PROPN') ('School', 'PROPN') ('Dist', 'PROPN') ('.', 'PUNCT')
# ('47J', 'X') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Before', 'ADP') ('seeking', 'VERB') ('a', 'DET') ('federal', 'ADJ') ('writ', 'NOUN') ('of', 'ADP') ('habeas', 'X') ('corpus', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('It', 'PRON') ('is', 'AUX') ('appropriate', 'ADJ') ('to', 'PART') ('disregard', 'VERB') ('this', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('Ru', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('focuses', 'VERB') ('upon', 'SCONJ') ('an', 'DET') ('arbitration', 'NOUN') ('rule', 'NOUN') ('of', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('As', 'SCONJ') ('our', 'PRON') ('precedents', 'NOUN') ('make', 'VERB') ('clear', 'ADJ') ('and', 'CCONJ') ('as', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('are', 'AUX') ('called', 'VERB') ('upon', 'SCONJ') ('to', 'PART') ('resolve', 'VERB') ('a', 'DET') ('series', 'NOUN') ('of', 'ADP') ('issu', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('With', 'ADP') ('respect', 'NOUN') ('to', 'ADP') ('the', 'DET') ('issue', 'NOUN') ('resolved', 'VERB') ('in', 'ADP') ('Part', 'PROPN') ('II', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Internal', 'PROPN') ('Revenue', 'PROPN') ('Code', 'PROPN') ('§', 'PROPN') ('104(a)(2', 'PROPN') (')', 'PUNCT') (',', 'PUNCT') ('as', 'SCONJ') ('it', 'PRON') ('read', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('Section', 'PROPN') ('104(a)(2', 'PROPN') (')', 'PUNCT') (',', 'PUNCT') ('as', 'SCONJ') ('it', 'PRON') ('stood', 'VERB') ('at', 'ADP') ('the', 'DET') ('time', 'NOUN') ('rel', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('1\\n', 'PROPN') ('     ', 'SPACE') ('Under', 'ADP') ('our', 'PRON') ('decision', 'NOUN') ('in', 'ADP') ('Turner', 'PROPN') ('v.', 'PROPN') ('Safle', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('that', 'SCONJ') ('the', 'DET') ('Ninth', 'PROPN') ('Circuit', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('an', 'DET') ('arr', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Antiterrorism', 'PROPN') ('and', 'CCONJ') ('Effective', 'ADJ') ('Death', 'PROPN') ('Penalty', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Court', 'PROPN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('conducts', 'VERB') ('a', 'DET') ('truncated', 'VERB') ('in', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('requires', 'VERB') ('us', 'PRON') ('to', 'PART') ('consider', 'VERB') ('whether', 'SCONJ') ('the', 'DET') ('...', 'PUNCT') ('\n', 'SPACE') ('Plaintiffs', 'NOUN') ('-', 'PUNCT') ('appellants', 'NOUN') ('Richard', 'PROPN') ('Vieth', 'PROPN') (',', 'PUNCT') ('Norma', 'PROPN') ('Jea', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('A', 'DET') ('decision', 'NOUN') ('ordering', 'VERB') ('the', 'DET') ('correction', 'NOUN') ('of', 'ADP') ('all', 'DET') ('elec', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('central', 'ADJ') ('question', 'NOUN') ('presented', 'VERB') ('by', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Constitution', 'PROPN') ('guarantees', 'VERB') ('both', 'CCONJ') ('formal', 'ADJ') ('and', 'CCONJ') ('su', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('1\\n', 'PROPN') ('     ', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') ('we', 'PRON') ('consider', 'VERB') ('whether', 'SCONJ') ('it', 'PRON') ('w', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('32\\n', 'NUM') ('     ', 'SPACE') ('While', 'SCONJ') ('I', 'PRON') ('am', 'AUX') ('not', 'PART') ('persuaded', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('pr', 'X') ('...', 'PUNCT') ('\n', 'SPACE') ('37\\n', 'NUM') ('     ', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('transforms', 'VERB') ('a', 'DET') ('defenda', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('taxing', 'VERB') ('authority', 'NOUN') ('of', 'ADP') ('the', 'DET') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('Josue', 'PROPN') ('Leocal', 'PROPN') (',', 'PUNCT') ('a', 'DET') ('Haitian', 'ADJ') ('citizen', 'NOUN') ('who', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('Dale', 'PROPN') ('G.', 'PROPN') ('Becker', 'PROPN') (',', 'PUNCT') ('an', 'DET') ('Ohio', 'PROPN') ('prisoner', 'NOUN') (',', 'PUNCT') ('i', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('are', 'AUX') ('here', 'ADV') ('presented', 'VERB') ('with', 'ADP') ('the', 'DET') ('question', 'NOUN') ('whethe', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE') ('Robert', 'PROPN') ('Robinette', 'PROPN') ("'s", 'PART') ('traffic', 'NOUN') ('stop', 'NOUN') ('for', 'ADP') ('a', 'DET') ('speeding', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('holding', 'NOUN') ('today', 'NOUN') ('is', 'AUX') ('narrow', 'ADJ') (':', 'PUNCT')
# ('The', 'DET') ('Feder', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Fair', 'PROPN') ('Labor', 'PROPN') ('Standards', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1938', 'NUM') ('(', 'PUNCT') ('FLSA', 'PROPN') (')', 'PUNCT') (',', 'PUNCT') ('5', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('William', 'PROPN') ('Bracy', 'PROPN') ('was', 'AUX') ('tried', 'VERB') (',', 'PUNCT') ('convicted', 'VERB') (',', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('1992', 'NUM') (',', 'PUNCT') ('petitioners', 'NOUN') (',', 'PUNCT') ('a', 'DET') ('group', 'NOUN') ('of', 'ADP') ('probation', 'NOUN') ('off', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Seminole', 'PROPN') ('Tribe', 'PROPN') ('of', 'ADP') ('Fla.', 'PROPN') ('v.', 'CCONJ') ('Florida', 'PROPN') (',', 'PUNCT') ('517', 'NUM') ('U.S', 'PROPN') ('....', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') ('we', 'PRON') ('consider', 'VERB')
# ('whether', 'SCONJ') ('the', 'DET') ('Commonwea', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Cross', 'VERB') ('burning', 'VERB') ('with', 'ADP') ('"', 'PUNCT') ('an', 'DET') ('intent', 'NOUN') ('to', 'PART') ('intimidate', 'VERB') (',', 'PUNCT') ('"', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('every', 'DET') ('culture', 'NOUN') (',', 'PUNCT') ('certain', 'ADJ') ('things', 'NOUN') ('acquire', 'VERB') ('meani', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('we', 'PRON') ('consider', 'VERB') ('whether', 'SCONJ') ('an', 'DET') ('abstentio', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('.', 'PUNCT')
# ('I', 'PRON') ('write', 'VERB') ('separ', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('these', 'DET') ('cases', 'NOUN') ('we', 'PRON') ('consider', 'VERB') ('the', 'DET') ('constitutionali', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('majority', 'NOUN') ('opinion', 'NOUN') ('correctly', 'ADV') ('applies', 'VERB') ('our', 'PRON') ('dec', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('says', 'VERB') ('both', 'PRON') ('that', 'SCONJ') ('it', 'PRON') ('leaves', 'VERB') ('Commerce', 'PROPN') ('Cl', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('No', 'DET') ('one', 'NOUN') ('denies', 'VERB') ('the', 'DET') ('importance', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Constituti', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'PRON') ('is', 'AUX') ('a', 'DET') ('private', 'ADJ') ('enforcement', 'NOUN') ('action', 'NOUN') ('under', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('.', 'PUNCT')
# ('I', 'PRON') ('agree', 'VERB') ('that', 'SCONJ') ('our', 'PRON') ('p', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Texas', 'PROPN') (',', 'PUNCT') ('like', 'ADP') ('48', 'NUM') ('other', 'ADJ') ('States', 'PROPN') ('and', 'CCONJ') ('the', 'DET') ('District', 'PROPN') ('o', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('holds', 'VERB') ('that', 'SCONJ') ('"', 'PUNCT') ('interest', 'NOUN') ('income', 'NOUN') ('generate', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('presented', 'VERB') ('is', 'AUX') ('whether', 'SCONJ') ('"', 'PUNCT') ('interest', 'NOUN') ('ea', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('pre', 'NOUN') ('-', 'NOUN') ('emption', 'NOUN') ('.', 'PUNCT')
# ('A', 'DET') ('Michigan', 'PROPN') ('law', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Michigan', 'PROPN') ('Court', 'PROPN') ('of', 'ADP') ('Appeals', 'PROPN') (',', 'PUNCT') ('in', 'ADP') ('my', 'PRON') ('view', 'NOUN') (',', 'PUNCT') ('err', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('These', 'DET') ('cases', 'NOUN') ('present', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('§', 'PROPN') ('5', 'NUM') ('o', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Bossier', 'PROPN') ('Parish', 'PROPN') ('School', 'PROPN') ('Board', 'PROPN') ('first', 'ADV') ('sought', 'VERB') ('p', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('its', 'PRON') ('administration', 'NOUN') ('of', 'ADP') ('the', 'DET') ('voting', 'NOUN') ('rights', 'NOUN') ('sta', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('Justice', 'PROPN') ('Souter', 'PROPN') (',', 'PUNCT') ('with', 'ADP') ('one', 'NUM') ('qualific', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Daubert', 'PROPN') ('v.', 'ADP') ('Merrell', 'PROPN') ('Dow', 'PROPN') ('Pharmaceuticals', 'PROPN') (',', 'PUNCT') ('Inc', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') (',', 'PUNCT') ('which', 'PRON') ('makes', 'VERB') ('c', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('city', 'NOUN') ('of', 'ADP') ('Chicago', 'PROPN') (',', 'PUNCT') ('like', 'ADP') ('municipalities', 'NOUN') ('throu', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('now', 'ADV') ('-', 'PUNCT') ('federal', 'ADJ') ('case', 'NOUN') ('originated', 'VERB') ('as', 'ADP') ('an', 'DET') ('appeal', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('authority', 'NOUN') ('of', 'ADP') ('the', 'DET') ('federa', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('respective', 'ADJ') ('provinces', 'NOUN') ('of', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('raises', 'VERB') ('the', 'DET') ('issue', 'NOUN') ('whether', 'SCONJ') ('the', 'DET') ('United', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('application', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Eighth', 'PROPN') ('Amendment', 'PROPN') ('prohib', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('California', 'PROPN') ('is', 'AUX') ('one', 'NUM') ('of', 'ADP') ('at', 'ADV') ('least', 'ADV') ('nine', 'NUM') ('States', 'NOUN') ('that', 'SCONJ') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('holding', 'NOUN') ('that', 'SCONJ') ('the', 'DET') ('Cont', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('We', 'PRON') ('enforce', 'VERB') ('the', 'DET') ('"', 'PUNCT') ('outer', 'ADJ') ('limits', 'NOUN') ('"', 'PUNCT') ('of', 'ADP') ('Congress', 'PROPN') ("'", 'PART') ('Com', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Respondents', 'PROPN') ('Diane', 'PROPN') ('Monson', 'PROPN') ('and', 'CCONJ') ('Angel', 'PROPN') ('Raich', 'PROPN') ('use', 'VERB') ('m', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('These', 'DET') ('consolidated', 'ADJ') ('cases', 'NOUN') ('present', 'VERB') ('the', 'DET') ('question', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('United', 'PROPN') ('States', 'PROPN') ('v.', 'ADP') ('New', 'PROPN') ('Mexico', 'PROPN') (',', 'PUNCT') ('455', 'NUM') ('U.S.', 'PROPN') ('720', 'NUM') ('(', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Racketeer', 'PROPN') ('Influenced', 'PROPN') ('and', 'CCONJ') ('Corrupt', 'PROPN') ('Organizat', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('California', 'PROPN') ('Department', 'PROPN') ('of', 'ADP') ('Corrections', 'PROPN') ('(', 'PUNCT') ('CDC', 'PROPN') (')', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') (',', 'PUNCT') ('subject', 'ADJ') ('to', 'ADP') ('the', 'DET') ('res', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('my', 'PRON') ('judgment', 'NOUN') ('a', 'DET') ('state', 'NOUN') ('policy', 'NOUN') ('of', 'ADP') ('segregating', 'VERB') ('p', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('questions', 'NOUN') ('presented', 'VERB') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('require', 'VERB') ('u', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Section', 'PROPN') ('406(a', 'PROPN') (')', 'PUNCT') ('of', 'ADP') ('the', 'DET') ('Employee', 'PROPN') ('Retirement', 'PROPN') ('Inco', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('Indian', 'PROPN') ('Mineral', 'PROPN') ('Leasing', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('the', 'DET') ('Indian', 'PROPN') ('M', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') ('to', 'PART') ('determine', 'VERB') ('whether', 'SCONJ') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('would', 'AUX') ('be', 'AUX') ('content', 'ADJ') ('to', 'PART') ('decide', 'VERB') ('this', 'DET') ('case', 'NOUN') ('on', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Today', 'NOUN') ("'s", 'PART') ('opinion', 'NOUN') ('permits', 'VERB') ('review', 'NOUN') ('where', 'SCONJ') ('Congress', 'PROPN') (',', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'PRON') ('is', 'AUX') ('another', 'DET') ('Employee', 'PROPN') ('Retirement', 'PROPN') ('Income', 'PROPN') ('Sec', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('"', 'PUNCT') ('[', 'PUNCT') ('I]t', 'PROPN') ('is', 'AUX') ('the', 'DET') ('duty', 'NOUN') ('of', 'ADP') ('this', 'DET') ('court', 'NOUN') ('to', 'PART') ('see', 'VERB') ('to', 'ADP') ('it', 'PRON') ('t', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Petitioner', 'PROPN') ('sued', 'VERB') ('Monroe', 'PROPN') ('County', 'PROPN') (',', 'PUNCT') ('Alabama', 'PROPN') (',', 'PUNCT') ('under', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('Walter', 'PROPN') ('McMillian', 'PROPN') (',', 'PUNCT') ('convicted', 'VERB') ('of', 'ADP') ('capi', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('During', 'ADP') ('a', 'DET') ('two', 'NUM') ('-', 'PUNCT') ('hour', 'NOUN') (',', 'PUNCT') ('tape', 'NOUN') ('-', 'PUNCT') ('recorded', 'VERB') ('session', 'NOUN') ('at', 'ADP') ('Al', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Carl', 'PROPN') ('Thompson', 'PROPN') ('murdered', 'VERB') ('his', 'PRON') ('ex', 'NOUN') ('-', 'NOUN') ('wife', 'NOUN') (',', 'PUNCT') ('stabbing', 'VERB') ('h', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Petitioner', 'PROPN') ('received', 'VERB') ('a', 'DET') ('death', 'NOUN') ('sentence', 'NOUN') ('in', 'ADP') ('the', 'DET') ('Co', 'PROPN') ('...', 'NOUN') ('\n', 'SPACE')
# ('In', 'ADP') ('Simmons', 'PROPN') ('v.', 'CCONJ') ('South', 'PROPN') ('Carolina', 'PROPN') (',', 'PUNCT') ('512', 'NUM') ('U.S.', 'PROPN') ('154', 'NUM') ('(', 'PUNCT') ('19', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('There', 'PRON') ('is', 'VERB') ('an', 'DET') ('acute', 'ADJ') ('unfairness', 'NOUN') ('in', 'ADP') ('permitting', 'VERB') ('a', 'DET') ('S', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('A', 'DET') ('motion', 'NOUN') ('by', 'ADP') ('a', 'DET') ('federal', 'ADJ') ('prisoner', 'NOUN') ('for', 'ADP') ('postconvict', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('Social', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('requires', 'VERB') ('us', 'PRON') ('to', 'PART') ('address', 'VERB') (',', 'PUNCT') ('for', 'ADP') ('the', 'DET') ('seco', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Perhaps', 'ADV') ('even', 'ADV') ('more', 'ADV') ('important', 'ADJ') ('than', 'ADP') ('our', 'PRON') ('specific', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('decision', 'NOUN') ('today', 'NOUN') ('establishes', 'VERB') ('a', 'DET') ('categ', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('urging', 'VERB') ('approval', 'NOUN') ('of', 'ADP') ('a', 'DET') ('constitution', 'NOUN') ('that', 'PRON') ('gave', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('While', 'SCONJ') ('executing', 'VERB') ('an', 'DET') ('arrest', 'NOUN') ('warrant', 'NOUN') ('in', 'ADP') ('a', 'DET') ('private', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Age', 'PROPN') ('Discrimination', 'PROPN') ('in', 'ADP') ('Employment', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('19', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Alaska', 'PROPN') ('Sex', 'PROPN') ('Offender', 'PROPN') ('Registration', 'PROPN') ('Act', 'PROPN') ('requi', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('upholding', 'VERB') ('the', 'DET') ('Alask', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('As', 'SCONJ') ('JUSTICE', 'NOUN') ('SOUTER', 'AUX') ('carefully', 'ADV') ('explains', 'VERB') (',', 'PUNCT') ('it', 'PRON') ('is', 'AUX') ('un', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('is', 'AUX') ('under', 'ADP') ('what', 'PRON') ('circumstances', 'VERB') ('the', 'DET') ('d', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('concur', 'VERB') ('in', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('decision', 'NOUN') (',', 'PUNCT') ('which', 'PRON') ('vacate', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Airline', 'PROPN') ('Deregulation', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1978', 'NUM') ('prohibits', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'PROPN') ('to', 'PART') ('resolve', 'VERB') ('a', 'DET') ('Circuit', 'PROPN') ('con', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Tennessee', 'PROPN') ('Court', 'PROPN') ('of', 'ADP') ('Appeals', 'PROPN') ('rejected', 'VERB') ('respon', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('my', 'PRON') ('judgment', 'NOUN') (',', 'PUNCT') ('the', 'DET') ('Court', 'PROPN') ('of', 'ADP') ('Appeals', 'PROPN') ('correctly', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Multiemployer', 'PROPN') ('Pension', 'PROPN') ('Plan', 'PROPN') ('Amendments', 'PROPN') ('Act', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('we', 'PRON') ('consider', 'VERB') ('whether', 'SCONJ') ('a', 'DET') ('flat', 'ADJ') ('$', 'SYM') ('100', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Michigan', 'PROPN') ('imposes', 'VERB') ('a', 'DET') ('flat', 'ADJ') ('fee', 'NOUN') ('on', 'ADP') ('trucks', 'NOUN') ('that', 'PRON') ('eng', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('principal', 'ADJ') ('issues', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('are', 'AUX') ('whether', 'SCONJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Justice', 'PROPN') ('Kennedy', 'PROPN') ('suggests', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('misuse', 'NOUN') ('of', 'ADP') ('so', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('decision', 'NOUN') ('has', 'VERB') ('lasting', 'VERB') ('consequences', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('the', 'DET') ('process', 'NOUN') ('of', 'ADP') ('ratifying', 'VERB') ('Missouri', 'PROPN') ("'s", 'PART') ('sweepin', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Federal', 'PROPN') ('Service', 'PROPN') ('Labor', 'PROPN') ('-', 'PUNCT') ('Management', 'PROPN') ('Relations', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Though', 'SCONJ') ('recent', 'ADJ') ('Acts', 'NOUN') ('of', 'ADP') ('Congress', 'PROPN') ('have', 'AUX') ('made', 'VERB') ('subst', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Under', 'ADP') ('the', 'DET') ('Fair', 'PROPN') ('Labor', 'PROPN') ('Standards', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1938', 'NUM') ('(', 'PUNCT') ('FL', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('opinion', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('on', 'ADP') ('the', 'DET') ('assumpt', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Because', 'SCONJ') ('the', 'DET') ('disagreement', 'NOUN') ('between', 'ADP') ('the', 'DET') ('parties', 'NOUN') ('c', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Justice', 'PROPN') ('Scalia', 'PROPN') ('may', 'AUX') ('well', 'ADV') ('be', 'AUX') ('right', 'ADJ') ('that', 'SCONJ') ('the', 'DET') ('posi', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('policy', 'NOUN') ('of', 'ADP') ('sentencing', 'VERB') ('drug', 'NOUN') ('offenders', 'NOUN') ('based', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioner', 'PROPN') ('was', 'AUX') ('convicted', 'VERB') ('of', 'ADP') ('"', 'PUNCT') ('willfully', 'ADV') ('"', 'PUNCT') ('dealin', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('in', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('with', 'ADP') ('the', 'DET') ('caveat', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Petitioner', 'PROPN') ('Sillasse', 'PROPN') ('Bryan', 'PROPN') ('was', 'AUX') ('convicted', 'VERB') ('of', 'ADP') ('"', 'PUNCT') ('wi', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioners', 'NOUN') ('each', 'PRON') ('pleaded', 'VERB') ('guilty', 'ADJ') ('to', 'ADP') ('possession', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('decides', 'VERB') ('that', 'SCONJ') ('a', 'DET') ('district', 'NOUN') ('court', 'NOUN') ("'", 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Under', 'ADP') ('Cage', 'PROPN') ('v.', 'ADP') ('Louisiana', 'PROPN') (',', 'PUNCT') ('498', 'NUM') ('U.S.', 'PROPN') ('39', 'NUM') ('(', 'PUNCT') ('1990', 'NUM') (')', 'PUNCT') ('(', 'PUNCT') ('p', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('and', 'CCONJ') ('write', 'VERB') ('separatel', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Cage', 'PROPN') ('v.', 'ADP') ('Louisiana', 'PROPN') (',', 'PUNCT') ('498', 'NUM') ('U.S.', 'PROPN') ('39', 'NUM') ('(', 'PUNCT') ('1990', 'NUM') (')', 'PUNCT') ('(', 'PUNCT') ('per', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('we', 'PRON') ('must', 'AUX') ('decide', 'VERB') ('whether', 'SCONJ') ('approxima', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('On', 'ADP') ('April', 'PROPN') ('13', 'NUM') (',', 'PUNCT') ('1992', 'NUM') (',', 'PUNCT') ('water', 'NOUN') ('from', 'ADP') ('the', 'DET') ('Chicago', 'PROPN') ('Rive', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('concur', 'VERB') ('in', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('judgment', 'NOUN') ('and', 'CCONJ') ('opinion', 'NOUN') ('.', 'PUNCT')
# ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('turns', 'VERB') ('on', 'ADP') ('the', 'DET') ('conditions', 'NOUN') ('for', 'ADP') ('certifyi', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Justice', 'PROPN') ('Breyer', 'PROPN') ("'s", 'PART') ('dissenting', 'VERB') ('opinion', 'NOUN') ('highlights', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('involves', 'VERB') ('a', 'DET') ('settlement', 'NOUN') ('of', 'ADP') ('an', 'DET') ('estimate', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('we', 'PRON') ('are', 'AUX') ('asked', 'VERB') ('to', 'PART') ('decide', 'VERB') ('whether', 'SCONJ') ('r', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ...
# ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('holding', 'NOUN') ('today', 'NOUN') ('rests', 'VERB') ('largely', 'ADV') ('on', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('dissent', 'VERB') ('essentially', 'ADV') ('for', 'ADP') ('the', 'DET') ('reasons', 'NOUN') ('stated', 'VERB') ('b', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Petitioner', 'PROPN') ('pleaded', 'VERB') ('guilty', 'ADJ') ('to', 'ADP') ('"', 'PUNCT') ('using', 'VERB') ('"', 'PUNCT') ('a', 'DET') ('firearm', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('that', 'PRON') ('petitioner', 'NOUN') ('has', 'VERB') ('not', 'PART') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('requires', 'VERB') ('us', 'PRON') ('to', 'PART') ('interpret', 'VERB') ('the', 'DET') ('Carriag', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('what', 'PRON') ('I', 'PRON') ('understand', 'VERB') ('to', 'PART') ('be', 'AUX') ('the', 'DET') ('two', 'NUM') ('b', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Carriage', 'PROPN') ('of', 'ADP') ('Goods', 'PROPN') ('by', 'ADP') ('Sea', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('COGSA),[1', 'NUM') (']', 'X') ('e', 'X') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('State', 'PROPN') ('of', 'ADP') ('Ohio', 'PROPN') ('has', 'AUX') ('established', 'VERB') ('a', 'DET') ('pilot', 'NOUN') ('prog', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('holds', 'VERB') ('that', 'SCONJ') ('Ohio', 'PROPN') ("'s", 'PART') ('Pilot', 'PROPN') ('Project', 'PROPN') ('Scho', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Is', 'AUX') ('a', 'DET') ('law', 'NOUN') ('that', 'PRON') ('authorizes', 'VERB') ('the', 'DET') ('use', 'NOUN') ('of', 'ADP') ('public', 'ADJ') ('fun', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('majority', 'NOUN') ('holds', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('Establishm', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('requires', 'VERB') ('interpretation', 'NOUN') ('of', 'ADP') ('the', 'DET') ('"', 'PUNCT') ('spou', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Medicare', 'PROPN') ('Catastrophic', 'PROPN') ('Coverage', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1988', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('the', 'DET') ('cl', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Court', 'PROPN') ('of', 'ADP') ('Appeals', 'PROPN') ("'", 'PART') ('decision', 'NOUN') ('denying', 'VERB') ('petitio', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('my', 'PRON') ('view', 'NOUN') (',', 'PUNCT') ('several', 'ADJ') ('of', 'ADP') ('the', 'DET') ('issues', 'NOUN') ('raised', 'VERB') ('here', 'ADV') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Trademark', 'PROPN') ('Remedy', 'PROPN') ('Clarification', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('TRCA', 'PROPN') (')', 'PUNCT') (',', 'PUNCT') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('has', 'AUX') ('been', 'AUX') ('argued', 'VERB') ('and', 'CCONJ') ('decided', 'VERB') ('on', 'ADP') ('the', 'DET') ('b', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Court', 'PROPN') ('holds', 'VERB') ('that', 'SCONJ') ('Congress', 'PROPN') (',', 'PUNCT') ('in', 'ADP') ('the', 'DET') ('exercise', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('Kentucky', 'PROPN') ('law', 'NOUN') ('provides', 'VERB') ('that', 'SCONJ') ('"', 'PUNCT') ('[', 'X') ('a', 'X') (']', 'X') ('health', 'NOUN') ('insurer', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') ('we', 'PRON') ('ask', 'VERB') ('whether', 'SCONJ') ('the', 'DET') ('antitrust', 'ADJ') ('rule', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Section', 'NOUN') ('1', 'NUM') ('of', 'ADP') ('the', 'DET') ('Federal', 'PROPN') ('Arbitration', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('FAA', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Justice', 'PROPN') ('Souter', 'PROPN') ('has', 'AUX') ('cogently', 'ADV') ('explained', 'VERB') ('why', 'SCONJ') ('the', 'DET') ('...', 'PUNCT') ('\n', 'SPACE') ('Section', 'PROPN') ('2', 'NUM') ('of', 'ADP') ('the', 'DET') ('Federal', 'PROPN') ('Arbitration', 'PROPN') ('Act', 'PROPN') ('(', 'PUNCT') ('FAA', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('here', 'ADV') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('Government', 'PROPN') ('motion', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('agree', 'VERB') ('with', 'ADP') ('the', 'DET') ('conclusion', 'NOUN') ('that', 'SCONJ') ('18', 'NUM') ('U.S.', 'PROPN') ('C.', 'PROPN') ('§', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Fourth', 'PROPN') ('Amendment', 'PROPN') ('requires', 'VERB') ('government', 'NOUN') ('to', 'PART') ('re', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('fear', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('novelty', 'NOUN') ('of', 'ADP') ('this', 'DET') ('Georgia', 'PROPN') ('law', 'NOUN') ('ha', 'INTJ') ('...', 'PUNCT') ('\n', 'SPACE') ('These', 'DET') ('consolidated', 'ADJ') ('cases', 'NOUN') ('present', 'ADJ') ('challenges', 'NOUN') ('to', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE') ('Congress', 'PROPN') ("'", 'PART') ('power', 'NOUN') ('to', 'PART') ('regulate', 'VERB') ('commerce', 'NOUN') ('among', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('A', 'DET') ('century', 'NOUN') ('ago', 'ADV') (',', 'PUNCT') ('this', 'DET') ('Court', 'PROPN') ('repeatedly', 'ADV') ('invalidat', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Respondent', 'PROPN') ('Central', 'PROPN') ('Office', 'PROPN') ('Telephone', 'PROPN') (',', 'PUNCT') ('Inc.', 'PROPN') ('(', 'PUNCT') ('COT', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('concludes', 'VERB') ('that', 'SCONJ') ('respondent', 'NOUN') ("'s", 'PART') ('tortious', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Everyone', 'PRON') ('agrees', 'VERB') ('that', 'SCONJ') ('respondent', 'NOUN') ("'s", 'PART') ('tortious', 'ADJ') ('int', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Two', 'NUM') ('oil', 'NOUN') ('companies', 'NOUN') (',', 'PUNCT') ('petitioners', 'NOUN') ('here', 'ADV') (',', 'PUNCT') ('seek', 'VERB') ('rest', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Since', 'SCONJ') ('the', 'DET') ('1953', 'NUM') ('passage', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Outer', 'PROPN') ('Continenta', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Arkansas', 'PROPN') ('River', 'PROPN') ('rises', 'VERB') ('in', 'ADP') ('the', 'DET') ('mountains', 'NOUN') ('of', 'ADP') ('C', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('to', 'ADP') ('determin', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') (',', 'PUNCT') ('which', 'PRON') ('I', 'PRON') ('join', 'VERB') (',', 'PUNCT') ('emphasizes', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('the', 'DET') ('Sixth', 'PROPN') ('Amendment', 'PROPN') ('right', 'NOUN') ('o', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('Argersinger', 'PROPN') ('v.', 'ADP') ('Hamlin', 'PROPN') (',', 'PUNCT') ('407', 'NUM') ('U.S.', 'PROPN') ('25', 'NUM') (',', 'PUNCT') ('37', 'NUM') ('(', 'PUNCT') ('197', 'NUM') ('...', 'PUNCT') ('\n', 'SPACE') ('Article', 'NOUN') ('I', 'NOUN') (',', 'PUNCT') ('§', 'PROPN') ('8', 'NUM') (',', 'PUNCT') ('cl', 'NOUN') ('.', 'PUNCT') ('4', 'X') (',', 'PUNCT') ('of', 'ADP') ('the', 'DET') ('Constitution', 'PROPN') ('pro', 'NOUN') ('...', 'PRON') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('in', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') (',', 'PUNCT') ('save', 'VERB') ('for', 'ADP') ('any', 'PRON') ('i', 'PRON') ('m', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('granted', 'VERB') ('certiorari', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('to', 'PART') ('decide', 'VERB') ('w', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('consider', 'VERB') ('whether', 'SCONJ') ('the', 'DET') ('filing', 'NOUN') ('of', 'ADP') ('a', 'DET') ('timely', 'ADJ') ('mot', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('majority', 'NOUN') ('reads', 'VERB') ('§', 'PROPN') ('106(a', 'PROPN') (')', 'PUNCT') ('of', 'ADP') ('the', 'DET') ('Immigration', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Plant', 'PROPN') ('Variety', 'PROPN') ('Protection', 'PROPN') ('Act', 'PROPN') ('of', 'ADP') ('1970', 'NUM') (',', 'PUNCT') ('7', 'NUM') ('U', 'NOUN') ('....', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('key', 'NOUN') ('to', 'ADP') ('this', 'DET') ('statutory', 'ADJ') ('puzzle', 'NOUN') ('is', 'AUX') ('the', 'DET') ('meanin', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('a', 'DET') ('trib', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('agree', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('Fallon', 'PROPN') ('Paiute', 'PROPN') ('-', 'PUNCT') ('Shoshone', 'PROPN') ('Tribal', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('Petitioners', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('incurred', 'VERB') ('substantial', 'ADJ') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('petitioners', 'NOUN') (',', 'PUNCT') ('two', 'NUM') ('chemical', 'NOUN') ('companies', 'NOUN') (',', 'PUNCT') ('have', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('question', 'NOUN') ('in', 'ADP') ('this', 'DET') ('case', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('dredge', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('As', 'SCONJ') ('I', 'PRON') ('have', 'AUX') ('suggested', 'VERB') ('in', 'ADP') ('the', 'DET') ('past', 'NOUN') (',', 'PUNCT') ('the', 'DET') ('Court', 'PROPN') ('use', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('state', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Justice', 'PROPN') ('Breyer', 'PROPN') ('has', 'AUX') ('explained', 'VERB') ('why', 'SCONJ') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('r', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('holds', 'VERB') ('that', 'SCONJ') ('a', 'DET') ('private', 'ADJ') ('person', 'NOUN') ('can', 'AUX') ('not', 'PART') ('b', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Appellant', 'PROPN') ('was', 'AUX') ('one', 'NUM') ('of', 'ADP') ('several', 'ADJ') ('plaintiffs', 'NOUN') ('in', 'ADP') ('thi', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('today', 'NOUN') ('affirms', 'VERB') ('a', 'DET') ('Federal', 'PROPN') ('District', 'PROPN') ('Cou', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('involves', 'VERB') ('the', 'DET') ('process', 'NOUN') ('by', 'ADP') ('which', 'PRON') ('Ohio', 'PROPN') ('c', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('In', 'ADP') ('my', 'PRON') ('opinion', 'NOUN') ('it', 'PRON') ('is', 'AUX') ('unwise', 'ADJ') ('for', 'ADP') ('the', 'DET') ('Court', 'PROPN') ('to', 'ADP') ('an', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('[', 'X') ('\x86]\\nPennsylvania', 'PROPN') ('provides', 'VERB') ('in', 'ADP') ('its', 'PRON') ('workers', 'NOUN') ("'", 'PART') ('com', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('I', 'PRON') ('join', 'VERB') ('Part', 'PROPN') ('III', 'PROPN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('on', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('Florida', 'PROPN') ('Contraband', 'PROPN') ('Forfeiture', 'PROPN') ('Act', 'PROPN') ('provides', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('subject', 'NOUN') ('to', 'ADP') ('a', 'DET') ('qualif', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('During', 'ADP') ('the', 'DET') ('summer', 'NOUN') ('of', 'ADP') ('1993', 'NUM') (',', 'PUNCT') ('Florida', 'PROPN') ('police', 'NOUN') ('obta', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('In', 'ADP') ('this', 'DET') ('case', 'NOUN') (',', 'PUNCT') ('we', 'PRON') ('decide', 'VERB') ('whether', 'SCONJ') ('the', 'DET') ('Eighth', 'PROPN') ('Ame', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('In', 'ADP') ('my', 'PRON') ('opinion', 'NOUN') ('in', 'ADP') ('Harmelin', 'PROPN') ('v.', 'ADP') ('Michigan', 'PROPN') (',', 'PUNCT') ('501', 'NUM') ('U.S', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE') ('JUSTICE', 'PROPN') ('BREYER', 'PROPN') ('has', 'AUX') ('cogently', 'ADV') ('explained', 'VERB') ('why', 'SCONJ') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('The', 'DET') ('constitutional', 'ADJ') ('question', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('the', 'DET') ('"', 'PUNCT') ('th', 'X') ('...', 'PUNCT') ('\n', 'SPACE') ('This', 'DET') ('case', 'NOUN') ('presents', 'VERB') ('the', 'DET') ('question', 'NOUN') ('whether', 'SCONJ') ('a', 'DET') ('defe', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('petitioner', 'NOUN') ('had', 'VERB') ('no', 'DET') ('constitutional', 'ADJ') ('right', 'NOUN') ('to', 'ADP') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Sixth', 'PROPN') ('Amendment', 'PROPN') ('provides', 'VERB') ('that', 'SCONJ') ('the', 'DET') ('accused', 'VERB') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('issue', 'NOUN') ('is', 'AUX') ('whether', 'SCONJ') ('a', 'DET') ('state', 'NOUN') ('wide', 'ADJ') ('association', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('have', 'AUX') ('never', 'ADV') ('found', 'VERB') ('state', 'NOUN') ('action', 'NOUN') ('based', 'VERB') ('upon', 'SCONJ') ('me', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('Petitioner', 'PROPN') ('Bernadine', 'PROPN') ('Suitum', 'PROPN') ('owns', 'VERB') ('land', 'NOUN') ('near', 'ADP') ('the', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('concur', 'VERB') ('in', 'ADP') ('the', 'DET') ('judgment', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Court', 'PROPN') (',', 'PUNCT') ('and', 'CCONJ') ('joi', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('join', 'VERB') ('the', 'DET') ('per', 'ADP') ('curiam', 'PROPN') ('opinion', 'NOUN') ('.', 'PUNCT')
# ('We', 'PRON') ('write', 'VERB') ('separ', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Constitution', 'PROPN') ('assigns', 'VERB') ('to', 'ADP') ('the', 'DET') ('States', 'PROPN') ('the', 'DET') ('pri', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('The', 'DET') ('Court', 'PROPN') ('should', 'AUX') ('not', 'PART') ('have', 'AUX') ('reviewed', 'VERB') ('either', 'CCONJ') ('Bush', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('"', 'PUNCT') ('Opportunity', 'NOUN') ('does', 'AUX') ("n't", 'PART') ('always', 'ADV') ('knock', 'VERB') ('.', 'PUNCT') ('.', 'PUNCT') ('.', 'PUNCT')
# ('someti', 'PROPN') ('...', 'PUNCT') ('\n', 'SPACE')
# ('This', 'DET') ('case', 'NOUN') ('concerns', 'VERB') ('what', 'PRON') ('has', 'AUX') ('come', 'VERB') ('to', 'PART') ('be', 'AUX') ('known', 'VERB') ('a', 'PRON') ('...', 'PUNCT') ('\n', 'SPACE') ('Rules', 'NOUN') ('of', 'ADP') ('the', 'DET') ('Florida', 'PROPN') ('Bar', 'PROPN') ('prohibit', 'NOUN') ('personal', 'ADJ') ('inj', 'NOUN') ('...', 'PUNCT') ('\n', 'SPACE') ('Attorneys', 'NOUN') ('who', 'PRON') ('communicate', 'VERB') ('their', 'PRON') ('willingness', 'NOUN') ('to', 'PART') ('...', 'PUNCT') ('\n', 'SPACE')
# ('We', 'PRON') ('must', 'AUX') ('decide', 'VERB') ('whether', 'SCONJ') ('punitive', 'ADJ') ('damages', 'NOUN') ('may', 'AUX') ('be', 'AUX') ('...', 'PUNCT') ('\n', 'SPACE')
# ('I', 'PRON') ('join', 'VERB') ('the', 'DET') ('Court', 'PROPN') ("'s", 'PART') ('opinion', 'NOUN') ('because', 'SCONJ') ('I', 'PRON') ('agree', 'VERB') ('tha', 'NOUN') ('...', 'PUNCT')

# %%
for token in spacy_obj(selected_opinions_string):
    print(token.idx, token.text, "dep:", token.dep_, "head:", token.head, token.head.idx)
# Out:
# 0 This dep: det head: case 5
# 5 case dep: nsubj head: presents 10
# 10 presents dep: ROOT head: presents 10
# 19 the dep: det head: question 23
# 23 question dep: dobj head: presents 10
# 32 whether dep: mark head: workpl 40
# 40 workpl dep: dobj head: concur 52
# 46 ... dep: punct head: workpl 40
# 49
#  dep: dep head: ... 46
# 50 I dep: nsubj head: concur 52
# 52 concur dep: acl head: question 23
# 59 because dep: mark head: stresses 77
# 67 the dep: det head: Court 71
# 71 Court dep: nsubj head: stresses 77
# 77 stresses dep: advcl head: concur 52
# 86 that dep: dobj head: stresses 77
# 91 in dep: prep head: stresses 77
# 94 ev dep: pobj head: in 91
# 96 ... dep: punct head: ev 94
# 99
#  dep: dep head: ... 96
# 100 Section dep: compound head: 102(b 108
# 108 102(b dep: pobj head: in 91
# 113 ) dep: punct head: 102(b 108
# 115 of dep: prep head: 102(b 108
# 118 the dep: det head: Act 129
# 122 Patent dep: compound head: Act 129
# 129 Act dep: pobj head: of 115
# 133 of dep: prep head: Act 129
# 136 1952 dep: nummod head: provi 141
# 141 provi dep: pobj head: of 133
# 146 ... dep: punct head: 102(b 108
# 149
#  dep: dep head: ... 146
# 150 The dep: det head: Act 179
# 154 Administrative dep: compound head: Procedure 169
# 169 Procedure dep: compound head: Act 179
# 179 Act dep: nsubj head: sets 189
# 183 ( dep: punct head: Act 179
# 184 APA dep: appos head: Act 179
# 187 ) dep: punct head: Act 179
# 189 sets dep: ROOT head: sets 189
# 194 fo dep: advmod head: sets 189
# 196 ... dep: punct head: sets 189
# 199
#  dep: dep head: ... 196
# 200 The dep: det head: issue 204
# 204 issue dep: nsubj head: is 223
# 210 in dep: prep head: issue 204
# 213 this dep: det head: case 218
# 218 case dep: pobj head: in 210
# 223 is dep: ROOT head: is 223
# 226 whether dep: mark head: at 235
# 233 , dep: punct head: at 235
# 235 at dep: prep head: is 223
# 238 the dep: det head: time 242
# 242 time dep: pobj head: at 235
# 246 ... dep: punct head: is 223
# 249
#  dep: dep head: ... 246
# 250 The dep: det head: Court 262
# 254 Supreme dep: compound head: Court 262
# 262 Court dep: nsubj head: dismissed 286
# 268 of dep: prep head: Court 262
# 271 South dep: compound head: Carolina 277
# 277 Carolina dep: pobj head: of 268
# 286 dismissed dep: ROOT head: dismissed 286
# 296 ... dep: punct head: dismissed 286
# 299
#  dep: dep head: ... 296
# 300 In dep: prep head: signal 337
# 303 joining dep: pcomp head: In 300
# 311 the dep: det head: Court 315
# 315 Court dep: dobj head: joining 303
# 321 today dep: npadvmod head: joining 303
# 326 , dep: punct head: signal 337
# 328 I dep: nsubj head: signal 337
# 330 do dep: aux head: signal 337
# 333 not dep: neg head: signal 337
# 337 signal dep: ROOT head: signal 337
# 344 an dep: dobj head: signal 337
# 346 ... dep: punct head: an 344
# 349
#  dep: dep head: ... 346
# 350 The dep: det head: State 354
# 354 State dep: nsubj head: places 388
# 360 of dep: prep head: State 354
# 363 Michigan dep: pobj head: of 360
# 371 , dep: punct head: State 354
# 373 by dep: prep head: State 354
# 376 regulation dep: pobj head: by 373
# 386 , dep: punct head: places 388
# 388 places dep: ROOT head: places 388
# 395 c dep: intj head: places 388
# 396 ... dep: punct head: places 388
# 399
#  dep: dep head: ... 396
# 400 Our dep: poss head: decision 404
# 404 decision dep: nsubj head: is 419
# 413 today dep: npadvmod head: decision 404
# 419 is dep: ROOT head: is 419
# 422 faithful dep: acomp head: is 419
# 431 to dep: prep head: faithful 422
# 434 the dep: det head: principl 438
# 438 principl dep: pobj head: to 431
# 446 ... dep: punct head: is 419
# 449
#  dep: dep head: ... 446
# 450 Arizona dep: compound head: law 458
# 458 law dep: nsubj head: authorizes 462
# 462 authorizes dep: ROOT head: authorizes 462
# 473 income dep: compound head: tax 480
# 479 - dep: punct head: tax 480
# 480 tax dep: compound head: credits 484
# 484 credits dep: dobj head: authorizes 462
# 492 for dep: prep head: authorizes 462
# 496 ... dep: punct head: for 492
# 499
#  dep: dep head: ... 496
# 500 In dep: prep head: obs 543
# 503 Part dep: compound head: IV 508
# 508 IV dep: pobj head: In 500
# 511 of dep: prep head: IV 508
# 514 his dep: poss head: dissent 518
# 518 dissent dep: pobj head: of 511
# 525 , dep: punct head: obs 543
# 527 JUSTICE dep: compound head: obs 543
# 535 KENNEDY dep: compound head: obs 543
# 543 obs dep: ROOT head: obs 543
# 546 ... dep: punct head: obs 543
# 549
#  dep: dep head: ... 546
# 550 In dep: prep head: shows 574
# 553 this dep: det head: case 558
# 558 case dep: pobj head: In 550
# 562 , dep: punct head: shows 574
# 564 the dep: det head: Court 568
# 568 Court dep: nsubj head: shows 574
# 574 shows dep: ccomp head: lack 615
# 580 great dep: amod head: skepticism 586
# 586 skepticism dep: dobj head: shows 574
# 596 ... dep: punct head: lack 615
# 599
#  dep: dep head: ... 596
# 600 Federal dep: amod head: courts 608
# 608 courts dep: nsubj head: lack 615
# 615 lack dep: ROOT head: lack 615
# 620 competence dep: dobj head: lack 615
# 631 to dep: aux head: rule 634
# 634 rule dep: acl head: competence 620
# 639 definit dep: dobj head: rule 634
# 646 ... dep: punct head: lack 615
# 649
#  dep: dep head: ... 646
# 650 A dep: det head: number 652
# 652 number dep: ROOT head: number 652
# 659 of dep: prep head: number 652
# 662 growers dep: pobj head: of 659
# 669 , dep: punct head: growers 662
# 671 handlers dep: conj head: growers 662
# 679 , dep: punct head: handlers 671
# 681 and dep: cc head: handlers 671
# 685 processors dep: conj head: handlers 671
# 696 ... dep: punct head: number 652
# 699
#  dep: dep head: ... 696
# 700 The dep: det head: Court 704
# 704 Court dep: nsubj head: finds 716
# 710 today dep: npadvmod head: finds 716
# 716 finds dep: ROOT head: finds 716
# 722 no dep: det head: right 741
# 725 First dep: compound head: Amendment 731
# 731 Amendment dep: compound head: right 741
# 741 right dep: dobj head: finds 716
# 746 ... dep: punct head: right 741
# 749
#  dep: dep head: ... 746
# 750 I\nI dep: compound head: join 755
# 755 join dep: compound head: Souter 768
# 760 Justice dep: compound head: Souter 768
# 768 Souter dep: poss head: dissent 777
# 774 's dep: case head: Souter 768
# 777 dissent dep: ROOT head: dissent 777
# 784 , dep: punct head: dissent 777
# 786 with dep: prep head: dissent 777
# 791 the dep: det head: e 795
# 795 e dep: pobj head: with 786
# 796 ... dep: punct head: dissent 777
# 799
#  dep: dep head: ... 796
# 800 The dep: det head: Club 811
# 804 Sierra dep: compound head: Club 811
# 811 Club dep: nsubj head: challenges 816
# 816 challenges dep: ROOT head: challenges 816
# 827 the dep: det head: lawfulness 831
# 831 lawfulness dep: dobj head: challenges 816
# 842 of dep: prep head: lawfulness 831
# 845 a dep: pobj head: of 842
# 846 ... dep: punct head: a 845
# 849
#  dep: dep head: ... 846
# 850 Section dep: pobj head: of 842
# 858 3 dep: nummod head: Section 850
# 860 of dep: prep head: Section 850
# 863 the dep: det head: Use 882
# 867 Religious dep: compound head: Land 877
# 877 Land dep: compound head: Use 882
# 882 Use dep: pobj head: of 860
# 886 and dep: cc head: Use 882
# 890 Instit dep: conj head: Use 882
# 896 ... dep: punct head: challenges 816
# 899
#  dep: dep head: ... 896
# 900 I dep: nsubj head: join 902
# 902 join dep: ROOT head: join 902
# 907 the dep: det head: opinion 911
# 911 opinion dep: dobj head: join 902
# 919 of dep: prep head: opinion 911
# 922 the dep: det head: Court 926
# 926 Court dep: pobj head: of 919
# 931 . dep: punct head: join 902
# 933 I dep: nsubj head: agree 935
# 935 agree dep: ROOT head: agree 935
# 941 with dep: prep head: agree 935
# 946 ... dep: punct head: agree 935
# 949
#  dep: dep head: ... 946
# 950 This dep: det head: case 955
# 955 case dep: nsubj head: presents 960
# 960 presents dep: ROOT head: presents 960
# 969 the dep: det head: question 973
# 973 question dep: dobj head: presents 960
# 982 whether dep: mark head: involves 1010
# 990 the dep: det head: At 994
# 994 At dep: nsubj head: involves 1010
# 996 ... dep: punct head: At 994
# 999
#  dep: dep head: ... 996
# 1000 This dep: det head: case 1005
# 1005 case dep: nsubj head: involves 1010
# 1010 involves dep: acl head: question 973
# 1019 an dep: det head: action 1022
# 1022 action dep: dobj head: involves 1010
# 1029 for dep: prep head: action 1022
# 1033 damages dep: pobj head: for 1029
# 1041 again dep: advmod head: involves 1010
# 1046 ... dep: punct head: presents 960
# 1049
#  dep: dep head: ... 1046
# 1050 I dep: nsubj head: agree 1052
# 1052 agree dep: ROOT head: agree 1052
# 1058 with dep: prep head: agree 1052
# 1063 Justice dep: compound head: Ginsburg 1071
# 1071 Ginsburg dep: pobj head: with 1058
# 1080 that dep: mark head: occurred 1117
# 1085 " dep: punct head: occurred 1117
# 1086 common dep: amod head: sen 1093
# 1093 sen dep: nmod head: accident 1108
# 1096 ... dep: punct head: sen 1093
# 1099
#  dep: dep head: ... 1096
# 1100 A dep: det head: accident 1108
# 1102 fatal dep: amod head: accident 1108
# 1108 accident dep: nsubj head: occurred 1117
# 1117 occurred dep: ccomp head: agree 1052
# 1126 on dep: prep head: occurred 1117
# 1129 October dep: pobj head: on 1126
# 1137 3 dep: nummod head: October 1129
# 1138 , dep: punct head: October 1129
# 1140 1993 dep: nummod head: October 1129
# 1144 , dep: punct head: occurred 1117
# 1146 ... dep: punct head: agree 1052
# 1149
#  dep: dep head: ... 1146
# 1150 Respondent dep: compound head: Henson 1168
# 1161 Hurley dep: compound head: Henson 1168
# 1168 Henson dep: nsubj head: filed 1175
# 1175 filed dep: ROOT head: filed 1175
# 1181 suit dep: dobj head: filed 1175
# 1186 in dep: prep head: filed 1175
# 1189 state dep: compound head: c 1195
# 1195 c dep: pobj head: in 1186
# 1196 ... dep: punct head: filed 1175
# 1199
#  dep: dep head: ... 1196
# 1200 As dep: mark head: acknowledges 1213
# 1203 the dep: det head: Court 1207
# 1207 Court dep: nsubj head: acknowledges 1213
# 1213 acknowledges dep: ROOT head: acknowledges 1213
# 1225 , dep: punct head: acknowledges 1213
# 1227 ante dep: dep head: acknowledges 1213
# 1231 , dep: punct head: acknowledges 1213
# 1233 at dep: prep head: acknowledges 1213
# 1236 32 dep: pobj head: at 1233
# 1238 , dep: punct head: acknowledges 1213
# 1240 the dep: det head: de 1244
# 1244 de dep: dobj head: acknowledges 1213
# 1246 ... dep: dobj head: acknowledges 1213
# 1249
#  dep: dep head: ... 1246
# 1250 In dep: prep head: s 1295
# 1253 these dep: det head: cases 1272
# 1259 consolidated dep: amod head: cases 1272
# 1272 cases dep: pobj head: In 1250
# 1277 , dep: punct head: s 1295
# 1279 two dep: nummod head: individuals 1283
# 1283 individuals dep: nsubj head: s 1295
# 1295 s dep: ROOT head: s 1295
# 1296 ... dep: punct head: s 1295
# 1299
#  dep: dep head: ... 1296
# 1300 The dep: det head: Court 1304
# 1304 Court dep: nsubj head: holds 1316
# 1310 today dep: npadvmod head: holds 1316
# 1316 holds dep: ROOT head: holds 1316
# 1322 that dep: mark head: responde 1338
# 1327 the dep: det head: claims 1331
# 1331 claims dep: nsubj head: responde 1338
# 1338 responde dep: ccomp head: holds 1316
# 1346 ... dep: punct head: responde 1338
# 1349
#  dep: dep head: ... 1346
# 1350 The dep: det head: question 1354
# 1354 question dep: nsubj head: is 1386
# 1363 before dep: prep head: question 1354
# 1370 us dep: pobj head: before 1363
# 1373 in dep: prep head: is 1386
# 1376 this dep: det head: case 1381
# 1381 case dep: pobj head: in 1373
# 1386 is dep: ccomp head: join 1402
# 1389 whether dep: attr head: is 1386
# 1396 ... dep: punct head: join 1402
# 1399
#  dep: dep head: ... 1396
# 1400 I dep: nsubj head: join 1402
# 1402 join dep: ROOT head: join 1402
# 1407 the dep: det head: Court 1411
# 1411 Court dep: poss head: opinion 1419
# 1416 's dep: case head: Court 1411
# 1419 opinion dep: dobj head: join 1402
# 1426 . dep: punct head: join 1402
# 1428 In dep: prep head: prior 1440
# 1431 my dep: poss head: view 1434
# 1434 view dep: pobj head: In 1428
# 1438 , dep: punct head: prior 1440
# 1440 prior dep: ROOT head: prior 1440
# 1446 ... dep: punct head: prior 1440
# 1449
#  dep: dep head: ... 1446
# 1450 The dep: det head: question 1454
# 1454 question dep: nsubj head: is 1473
# 1463 presented dep: acl head: question 1454
# 1473 is dep: ROOT head: is 1473
# 1476 whether dep: mark head: injunctio 1487
# 1484 an dep: det head: injunctio 1487
# 1487 injunctio dep: attr head: is 1473
# 1496 ... dep: punct head: is 1473
# 1499
#  dep: dep head: ... 1496
# 1500 In dep: prep head: is 1553
# 1503 Ford dep: pobj head: In 1500
# 1508 v. dep: prep head: Ford 1503
# 1511 Wainwright dep: pobj head: v. 1508
# 1521 , dep: punct head: Wainwright 1511
# 1523 477 dep: nummod head: U.S. 1527
# 1527 U.S. dep: appos head: Wainwright 1511
# 1532 399 dep: nummod head: U.S. 1527
# 1535 , dep: punct head: U.S. 1527
# 1537 410 dep: nummod head: U.S. 1527
# 1541 ( dep: punct head: U.S. 1527
# 1542 1986 dep: appos head: U.S. 1527
# 1546 ... dep: punct head: In 1500
# 1549
#  dep: dep head: ... 1546
# 1550 It dep: nsubj head: is 1553
# 1553 is dep: ccomp head: address 1653
# 1556 axiomatic dep: acomp head: is 1553
# 1566 that dep: mark head: filed 1630
# 1571 " dep: punct head: filed 1630
# 1572 the dep: det head: power 1576
# 1576 power dep: prep head: " 1571
# 1582 to dep: aux head: award 1585
# 1585 award dep: acl head: power 1576
# 1591 the dep: det head: w 1595
# 1595 w dep: dobj head: award 1585
# 1596 ... dep: punct head: power 1576
# 1599
#  dep: dep head: ... 1596
# 1600 From dep: prep head: filed 1630
# 1605 1986 dep: pobj head: From 1600
# 1610 to dep: prep head: From 1600
# 1613 1991 dep: pobj head: to 1610
# 1617 , dep: punct head: filed 1630
# 1619 respondent dep: nsubj head: filed 1630
# 1630 filed dep: ccomp head: is 1553
# 1636 three dep: nummod head: peti 1642
# 1642 peti dep: dobj head: filed 1630
# 1646 ... dep: punct head: address 1653
# 1649
#  dep: dep head: ... 1646
# 1650 We dep: nsubj head: address 1653
# 1653 address dep: ROOT head: address 1653
# 1661 in dep: prep head: address 1653
# 1664 this dep: det head: case 1669
# 1669 case dep: pobj head: in 1661
# 1674 whether dep: mark head: serving 1721
# 1682 23 dep: nummod head: § 1693
# 1685 U.S. dep: compound head: § 1693
# 1690 C. dep: nmod head: § 1693
# 1693 § dep: nsubj head: serving 1721
# 1695 4 dep: nummod head: § 1693
# 1696 ... dep: punct head: § 1693
# 1699
#  dep: dep head: ... 1696
# 1700 An dep: det head: offender 1703
# 1703 offender dep: appos head: § 1693
# 1712 had dep: aux head: serving 1721
# 1716 been dep: aux head: serving 1721
# 1721 serving dep: ccomp head: address 1653
# 1729 time dep: dobj head: serving 1721
# 1734 in dep: prep head: serving 1721
# 1737 federal dep: amod head: p 1745
# 1745 p dep: pobj head: in 1734
# 1746 ... dep: punct head: serving 1721
# 1749
#  dep: dep head: ... 1746
# 1750 In dep: prep head: join 1802
# 1753 U. dep: compound head: S. 1756
# 1756 S. dep: compound head: Limits 1764
# 1759 Term dep: compound head: Limits 1764
# 1764 Limits dep: pobj head: In 1750
# 1770 , dep: punct head: Limits 1764
# 1772 Inc. dep: appos head: Limits 1764
# 1777 v. dep: prep head: Inc. 1772
# 1780 Thornton dep: pobj head: v. 1777
# 1788 , dep: punct head: Limits 1764
# 1790 514 dep: nummod head: U 1794
# 1794 U dep: appos head: Limits 1764
# 1795 .... dep: punct head: Limits 1764
# 1799
#  dep: dep head: .... 1795
# 1800 I dep: nsubj head: join 1802
# 1802 join dep: ROOT head: join 1802
# 1807 the dep: det head: opinion 1811
# 1811 opinion dep: dobj head: join 1802
# 1819 of dep: prep head: opinion 1811
# 1822 the dep: det head: Court 1826
# 1826 Court dep: pobj head: of 1819
# 1831 , dep: punct head: join 1802
# 1833 holding dep: advcl head: join 1802
# 1841 § dep: dobj head: holding 1833
# 1843 15 dep: appos head: § 1841
# 1846 ... dep: punct head: § 1841
# 1849
#  dep: dep head: ... 1846
# 1850 Under dep: prep head: raise 1925
# 1856 the dep: det head: Truth 1860
# 1860 Truth dep: pobj head: Under 1850
# 1866 in dep: prep head: Truth 1860
# 1869 Lending dep: compound head: Act 1877
# 1877 Act dep: pobj head: in 1866
# 1880 , dep: punct head: Act 1877
# 1882 82 dep: nummod head: Stat 1885
# 1885 Stat dep: pobj head: Under 1850
# 1889 . dep: pobj head: Under 1850
# 1891 146 dep: pobj head: Under 1850
# 1894 , dep: pobj head: Under 1850
# 1896 ... dep: punct head: Under 1850
# 1899
#  dep: dep head: ... 1896
# 1900 These dep: det head: cases 1919
# 1906 consolidated dep: amod head: cases 1919
# 1919 cases dep: nsubj head: raise 1925
# 1925 raise dep: ROOT head: raise 1925
# 1931 questions dep: compound head: conce 1941
# 1941 conce dep: dobj head: raise 1925
# 1946 ... dep: punct head: raise 1925
# 1949
#  dep: dep head: ... 1946
# 1950 This dep: det head: case 1955
# 1955 case dep: nsubj head: presents 1960
# 1960 presents dep: ROOT head: presents 1960
# 1969 the dep: det head: question 1973
# 1973 question dep: dobj head: presents 1960
# 1982 whether dep: mark head: comp 1992
# 1990 a dep: det head: comp 1992
# 1992 comp dep: punct head: presents 1960
# 1996 ... dep: punct head: comp 1992
# 1999
#  dep: dep head: ... 1996
# 2000 It dep: nsubjpass head: established 2011
# 2003 is dep: auxpass head: established 2011
# 2006 well dep: advmod head: established 2011
# 2011 established dep: ROOT head: established 2011
# 2023 that dep: det head: Haddle 2072
# 2028 federal dep: amod head: state 2037
# 2035 , dep: punct head: state 2037
# 2037 state dep: pobj head: that 2023
# 2042 , dep: punct head: state 2037
# 2044 an dep: appos head: state 2037
# 2046 ... dep: punct head: an 2044
# 2049
#  dep: dep head: ... 2046
# 2050 Petitioner dep: compound head: Haddle 2072
# 2061 Michael dep: compound head: Haddle 2072
# 2069 A. dep: compound head: Haddle 2072
# 2072 Haddle dep: dobj head: established 2011
# 2078 , dep: punct head: Haddle 2072
# 2080 an dep: det head: emplo 2091
# 2083 at dep: nmod head: emplo 2091
# 2085 - dep: punct head: emplo 2091
# 2086 will dep: compound head: emplo 2091
# 2091 emplo dep: appos head: Haddle 2072
# 2096 ... dep: punct head: Haddle 2072
# 2099
#  dep: dep head: ... 2096
# 2100 The dep: det head: State 2104
# 2104 State dep: appos head: Haddle 2072
# 2110 of dep: prep head: State 2104
# 2113 Washington dep: pobj head: of 2110
# 2123 , dep: punct head: Haddle 2072
# 2125 like dep: prep head: Haddle 2072
# 2130 every dep: det head: Stat 2142
# 2136 other dep: amod head: Stat 2142
# 2142 Stat dep: pobj head: like 2125
# 2146 ... dep: punct head: Stat 2142
# 2149
#  dep: dep head: ... 2146
# 2150 The dep: det head: Court 2154
# 2154 Court dep: nsubj head: concludes 2166
# 2160 today dep: npadvmod head: concludes 2166
# 2166 concludes dep: ROOT head: concludes 2166
# 2176 that dep: mark head: is 2274
# 2181 the dep: det head: State 2185
# 2185 State dep: nmod head: question 2259
# 2191 of dep: prep head: State 2185
# 2194 Wa dep: pobj head: of 2191
# 2196 ... dep: punct head: State 2185
# 2199
#  dep: dep head: ... 2196
# 2200 The dep: det head: opinion 2225
# 2204 principal dep: amod head: opinion 2225
# 2214 dissenting dep: amod head: opinion 2225
# 2225 opinion dep: appos head: State 2185
# 2232 , dep: punct head: opinion 2225
# 2234 authored dep: acl head: opinion 2225
# 2243 by dep: agent head: authored 2234
# 2246 ... dep: punct head: State 2185
# 2249
#  dep: dep head: ... 2246
# 2250 [ dep: nmod head: question 2259
# 2251 * dep: nmod head: question 2259
# 2252 ] dep: nmod head: question 2259
# 2253 \nThe dep: amod head: question 2259
# 2259 question dep: nsubj head: is 2274
# 2268 posed dep: acl head: question 2259
# 2274 is dep: ccomp head: concludes 2166
# 2277 whether dep: mark head: under 2286
# 2284 , dep: punct head: under 2286
# 2286 under dep: prep head: is 2274
# 2292 the dep: pobj head: under 2286
# 2296 ... dep: punct head: under 2286
# 2299
#  dep: dep head: ... 2296
# 2300 As dep: mark head: reads 2318
# 2303 the dep: det head: Government 2307
# 2307 Government dep: nsubj head: reads 2318
# 2318 reads dep: ROOT head: reads 2318
# 2324 the dep: det head: Americans 2328
# 2328 Americans dep: dobj head: reads 2318
# 2338 with dep: prep head: reads 2318
# 2343 Dis dep: pobj head: with 2338
# 2346 ... dep: punct head: reads 2318
# 2349
#  dep: dep head: ... 2346
# 2350 In dep: prep head: provides 2421
# 2353 Wilson dep: pobj head: In 2350
# 2360 v. dep: prep head: Wilson 2353
# 2363 Arkansas dep: pobj head: v. 2360
# 2371 , dep: punct head: Wilson 2353
# 2373 514 dep: nummod head: 1995 2387
# 2377 U.S. dep: nmod head: 1995 2387
# 2382 927 dep: nummod head: U.S. 2377
# 2386 ( dep: punct head: 1995 2387
# 2387 1995 dep: appos head: Wilson 2353
# 2391 ) dep: punct head: Wilson 2353
# 2392 , dep: punct head: provides 2421
# 2394 we dep: nsubj head: provides 2421
# 2396 ... dep: punct head: we 2394
# 2399
#  dep: dep head: ... 2396
# 2400 A dep: det head: statute 2413
# 2402 Washington dep: compound head: statute 2413
# 2413 statute dep: nsubj head: provides 2421
# 2421 provides dep: ROOT head: provides 2421
# 2430 that dep: mark head: join 2452
# 2435 the dep: det head: designa 2439
# 2439 designa dep: prep head: that 2430
# 2446 ... dep: punct head: designa 2439
# 2449
#  dep: dep head: ... 2446
# 2450 I dep: nsubj head: join 2452
# 2452 join dep: ccomp head: provides 2421
# 2457 the dep: det head: opinion 2461
# 2461 opinion dep: dobj head: join 2452
# 2469 of dep: prep head: opinion 2461
# 2472 the dep: det head: Court 2476
# 2476 Court dep: pobj head: of 2469
# 2481 , dep: punct head: join 2452
# 2483 since dep: mark head: belie 2491
# 2489 I dep: nsubj head: belie 2491
# 2491 belie dep: advcl head: join 2452
# 2496 ... dep: punct head: belie 2491
# 2499
#  dep: dep head: ... 2496
# 2500 Like dep: prep head: believe 2523
# 2505 Justice dep: compound head: Scalia 2513
# 2513 Scalia dep: pobj head: Like 2500
# 2519 , dep: punct head: believe 2523
# 2521 I dep: nsubj head: believe 2523
# 2523 believe dep: ROOT head: believe 2523
# 2531 that dep: mark head: should 2539
# 2536 we dep: nsubj head: should 2539
# 2539 should dep: ccomp head: believe 2523
# 2546 ... dep: punct head: believe 2523
# 2549
#  dep: dep head: ... 2546
# 2550 The dep: det head: issue 2567
# 2554 severability dep: compound head: issue 2567
# 2567 issue dep: nsubj head: discussed 2573
# 2573 discussed dep: ROOT head: discussed 2573
# 2583 in dep: prep head: discussed 2573
# 2586 the dep: det head: Court 2590
# 2590 Court dep: pobj head: in 2583
# 2595 ' dep: punct head: discussed 2573
# 2596 ... dep: punct head: discussed 2573
# 2599
#  dep: dep head: ... 2596
# 2600 The dep: det head: Code 2627
# 2604 United dep: compound head: States 2611
# 2611 States dep: compound head: Code 2627
# 2618 Criminal dep: compound head: Code 2627
# 2627 Code dep: nsubj head: makes 2632
# 2632 makes dep: ROOT head: makes 2632
# 2638 it\n"unl dep: dobj head: makes 2632
# 2646 ... dep: punct head: makes 2632
# 2649
#  dep: dep head: ... 2646
# 2650 Gary dep: compound head: Small 2655
# 2655 Small dep: nsubj head: emerged 2678
# 2660 , dep: punct head: emerged 2678
# 2662 having dep: aux head: emerged 2678
# 2669 recently dep: advmod head: emerged 2678
# 2678 emerged dep: ROOT head: emerged 2678
# 2686 from dep: prep head: emerged 2678
# 2691 three dep: pobj head: from 2686
# 2696 ... dep: punct head: emerged 2678
# 2699
#  dep: dep head: ... 2696
# 2700 The dep: det head: Americans 2704
# 2704 Americans dep: ROOT head: Americans 2704
# 2714 with dep: prep head: Americans 2704
# 2719 Disabilities dep: compound head: Act 2732
# 2732 Act dep: pobj head: with 2714
# 2736 of dep: prep head: Act 2732
# 2739 1990 dep: pobj head: of 2736
# 2744 ( dep: punct head: A 2745
# 2745 A dep: appos head: Americans 2704
# 2746 ... dep: punct head: A 2745
# 2749
#  dep: dep head: ... 2746
# 2750 In dep: prep head: A 2745
# 2753 Miranda dep: pobj head: In 2750
# 2761 v. dep: prep head: Miranda 2753
# 2764 Arizona dep: pobj head: v. 2761
# 2771 , dep: punct head: A 2745
# 2773 384 dep: nummod head: 1966 2787
# 2777 U.S. dep: nmod head: 1966 2787
# 2782 436 dep: nummod head: U.S. 2777
# 2786 ( dep: punct head: 1966 2787
# 2787 1966 dep: npadvmod head: A 2745
# 2791 ) dep: punct head: A 2745
# 2792 , dep: punct head: we 2794
# 2794 we dep: appos head: Americans 2704
# 2796 ... dep: punct head: we 2794
# 2799
#  dep: dep head: ... 2796
# 2800 Those dep: ROOT head: Those 2800
# 2806 to dep: prep head: are 2833
# 2809 whom dep: pobj head: to 2806
# 2814 judicial dep: amod head: decisions 2823
# 2823 decisions dep: nsubj head: are 2833
# 2833 are dep: relcl head: Those 2800
# 2837 an dep: det head: unconn 2840
# 2840 unconn dep: attr head: are 2833
# 2846 ... dep: punct head: Those 2800
# 2849
#  dep: dep head: ... 2846
# 2850 A dep: det head: regulation 2852
# 2852 regulation dep: appos head: Those 2800
# 2863 of dep: prep head: regulation 2852
# 2866 the dep: det head: Opportuni 2887
# 2870 Equal dep: compound head: Employment 2876
# 2876 Employment dep: compound head: Opportuni 2887
# 2887 Opportuni dep: pobj head: of 2863
# 2896 ... dep: punct head: Those 2800
# 2899
#  dep: dep head: ... 2896
# 2900 This dep: nsubj head: is 2905
# 2905 is dep: ROOT head: is 2905
# 2908 a dep: det head: case 2917
# 2910 simple dep: amod head: case 2917
# 2917 case dep: attr head: is 2905
# 2922 and dep: cc head: is 2905
# 2926 should dep: aux head: be 2933
# 2933 be dep: conj head: is 2905
# 2936 simply dep: advmod head: res 2943
# 2943 res dep: attr head: be 2933
# 2946 ... dep: punct head: res 2943
# 2949
#  dep: dep head: ... 2946
# 2950 The dep: det head: State 2954
# 2954 State dep: nsubj head: imposes 2970
# 2960 of dep: prep head: State 2954
# 2963 Kansas dep: pobj head: of 2960
# 2970 imposes dep: ccomp head: imposed 3032
# 2978 a dep: det head: tax 2980
# 2980 tax dep: dobj head: imposes 2970
# 2984 on dep: prep head: tax 2980
# 2987 the dep: det head: recei 2991
# 2991 recei dep: pobj head: on 2984
# 2996 ... dep: punct head: imposed 3032
# 2999
#  dep: dep head: ... 2996
# 3000 The dep: det head: tax 3016
# 3004 Kansas dep: compound head: tax 3016
# 3011 fuel dep: compound head: tax 3016
# 3016 tax dep: nsubjpass head: imposed 3032
# 3020 at dep: prep head: tax 3016
# 3023 issue dep: pobj head: at 3020
# 3029 is dep: auxpass head: imposed 3032
# 3032 imposed dep: ROOT head: imposed 3032
# 3040 on dep: prep head: imposed 3032
# 3043 dis dep: pobj head: on 3040
# 3046 ... dep: punct head: imposed 3032
# 3049
#  dep: dep head: ... 3046
# 3050 The dep: det head: petitioner 3054
# 3054 petitioner dep: nsubj head: grants 3123
# 3065 in dep: prep head: petitioner 3054
# 3068 this dep: det head: case 3073
# 3073 case dep: pobj head: in 3065
# 3077 , dep: punct head: grants 3123
# 3079 Richard dep: compound head: Trest 3087
# 3087 Trest dep: nsubj head: grants 3123
# 3092 , dep: punct head: Trest 3087
# 3094 se dep: appos head: Trest 3087
# 3096 ... dep: punct head: Trest 3087
# 3099
#  dep: dep head: ... 3096
# 3100 The dep: det head: Amendment 3113
# 3104 Eleventh dep: compound head: Amendment 3113
# 3113 Amendment dep: nsubj head: grants 3123
# 3123 grants dep: ROOT head: grants 3123
# 3130 a dep: det head: immunity 3138
# 3132 State dep: compound head: immunity 3138
# 3138 immunity dep: dobj head: grants 3123
# 3146 ... dep: punct head: grants 3123
# 3149
#  dep: dep head: ... 3146
# 3150 The dep: det head: Act 3179
# 3154 Indian dep: compound head: Act 3179
# 3161 Gaming dep: compound head: Act 3179
# 3168 Regulatory dep: compound head: Act 3179
# 3179 Act dep: nsubj head: provides 3183
# 3183 provides dep: ROOT head: provides 3183
# 3192 that dep: dobj head: provides 3183
# 3196 ... dep: punct head: provides 3183
# 3199
#  dep: dep head: ... 3196
# 3200 This dep: det head: case 3205
# 3205 case dep: nsubj head: is 3210
# 3210 is dep: ROOT head: is 3210
# 3213 about dep: prep head: is 3210
# 3219 powerthe dep: det head: power 3229
# 3229 power dep: pobj head: about 3213
# 3235 of dep: prep head: power 3229
# 3238 the dep: det head: Cong 3242
# 3242 Cong dep: pobj head: of 3235
# 3246 ... dep: punct head: is 3210
# 3249
#  dep: dep head: ... 3246
# 3250 In dep: prep head: presents 3310
# 3253 holding dep: pcomp head: In 3250
# 3261 the dep: det head: State 3265
# 3265 State dep: nmod head: immune 3282
# 3271 of dep: prep head: State 3265
# 3274 Florida dep: pobj head: of 3271
# 3282 immune dep: dobj head: holding 3253
# 3289 to dep: prep head: immune 3282
# 3292 suit dep: pobj head: to 3289
# 3296 ... dep: punct head: In 3250
# 3299
#  dep: dep head: ... 3296
# 3300 This dep: det head: case 3305
# 3305 case dep: nsubj head: presents 3310
# 3310 presents dep: ROOT head: presents 3310
# 3319 the dep: det head: question 3323
# 3323 question dep: dobj head: presents 3310
# 3332 whether dep: mark head: fron 3342
# 3340 a dep: det head: fron 3342
# 3342 fron dep: advcl head: presents 3310
# 3346 ... dep: punct head: fron 3342
# 3349
#  dep: dep head: ... 3346
# 3350 A dep: det head: State 3352
# 3352 State dep: nsubj head: tax 3362
# 3358 may dep: aux head: tax 3362
# 3362 tax dep: ccomp head: believe 3531
# 3366 a dep: det head: share 3382
# 3368 proportionate dep: amod head: share 3382
# 3382 share dep: dobj head: tax 3362
# 3388 of dep: prep head: share 3382
# 3391 the dep: det head: i 3395
# 3395 i dep: pobj head: of 3388
# 3396 ... dep: punct head: tax 3362
# 3399
#  dep: dep head: ... 3396
# 3400 1\n dep: compound head: Petitioner 3409
# 3404       dep: dep head: 1\n 3400
# 3409 Petitioner dep: dobj head: tax 3362
# 3419 , dep: punct head: Petitioner 3409
# 3421 a dep: det head: associa 3439
# 3423 nonprofit dep: amod head: trade 3433
# 3433 trade dep: compound head: associa 3439
# 3439 associa dep: appos head: Petitioner 3409
# 3446 ... dep: punct head: Petitioner 3409
# 3449
#  dep: dep head: ... 3446
# 3450 22\n dep: nummod head: Petitioner 3460
# 3455       dep: dep head: 22\n 3450
# 3460 Petitioner dep: nsubj head: seeks 3471
# 3471 seeks dep: relcl head: Petitioner 3409
# 3477 this dep: det head: Court 3482
# 3482 Court dep: poss head: resolu 3490
# 3487 's dep: case head: Court 3482
# 3490 resolu dep: dobj head: seeks 3471
# 3496 ... dep: punct head: resolu 3490
# 3499
#  dep: dep head: ... 3496
# 3500 35\n dep: appos head: Petitioner 3409
# 3505       dep: dep head: 35\n 3500
# 3510 Like dep: prep head: 35\n 3500
# 3515 the dep: det head: majority 3519
# 3519 majority dep: pobj head: Like 3510
# 3527 , dep: punct head: believe 3531
# 3529 I dep: nsubj head: believe 3531
# 3531 believe dep: ROOT head: believe 3531
# 3539 that dep: dobj head: believe 3531
# 3544 pe dep: punct head: believe 3531
# 3546 ... dep: punct head: pe 3544
# 3549
#  dep: dep head: ... 3546
# 3550 The dep: det head: question 3554
# 3554 question dep: nsubj head: is 3573
# 3563 presented dep: acl head: question 3554
# 3573 is dep: ROOT head: is 3573
# 3576 whether dep: mark head: stat 3592
# 3584 an dep: det head: stat 3592
# 3587 Ohio dep: compound head: stat 3592
# 3592 stat dep: punct head: is 3573
# 3596 ... dep: punct head: stat 3592
# 3599
#  dep: dep head: ... 3596
# 3600 The dep: det head: dissent 3604
# 3604 dissent dep: nsubj head: stirring 3615
# 3612 is dep: aux head: stirring 3615
# 3615 stirring dep: ROOT head: stirring 3615
# 3624 in dep: prep head: stirring 3615
# 3627 its dep: poss head: appreciation 3631
# 3631 appreciation dep: pobj head: in 3624
# 3644 of dep: prep head: appreciation 3631
# 3646 ... dep: punct head: of 3644
# 3649
#  dep: dep head: ... 3646
# 3650 At dep: prep head: presents 3760
# 3653 a dep: det head: time 3655
# 3655 time dep: pobj head: At 3650
# 3660 when dep: advmod head: qualify 3703
# 3665 both dep: det head: branches 3680
# 3670 political dep: amod head: branches 3680
# 3680 branches dep: nsubj head: qualify 3703
# 3689 of dep: prep head: branches 3680
# 3692 Gove dep: pobj head: of 3689
# 3696 ... dep: punct head: branches 3680
# 3699
#  dep: dep head: ... 3696
# 3700 To dep: aux head: qualify 3703
# 3703 qualify dep: relcl head: time 3655
# 3711 for dep: prep head: qualify 3703
# 3715 court dep: compound head: approval 3721
# 3721 approval dep: pobj head: for 3711
# 3730 under dep: prep head: approval 3721
# 3736 Chapter dep: pobj head: under 3730
# 3744 13 dep: nummod head: Chapter 3736
# 3746 ... dep: punct head: At 3650
# 3749
#  dep: dep head: ... 3746
# 3750 This dep: det head: case 3755
# 3755 case dep: nsubj head: presents 3760
# 3760 presents dep: ROOT head: presents 3760
# 3769 the dep: det head: issue 3773
# 3773 issue dep: dobj head: presents 3760
# 3779 of dep: prep head: issue 3773
# 3782 what dep: dobj head: prope 3791
# 3787 the dep: det head: prope 3791
# 3791 prope dep: pcomp head: of 3779
# 3796 ... dep: punct head: presents 3760
# 3799
#  dep: dep head: ... 3796
# 3800 My dep: poss head: areas 3803
# 3803 areas dep: nsubj head: are 3841
# 3809 of dep: prep head: areas 3803
# 3812 agreement dep: pobj head: of 3809
# 3822 with dep: prep head: agreement 3812
# 3827 the dep: det head: plurality 3831
# 3831 plurality dep: pobj head: with 3822
# 3841 are dep: ROOT head: are 3841
# 3845 s dep: acomp head: are 3841
# 3846 ... dep: punct head: are 3841
# 3849
#  dep: dep head: ... 3846
# 3850 For dep: prep head: see 3881
# 3854 reasons dep: pobj head: For 3850
# 3862 previously dep: advmod head: stated 3873
# 3873 stated dep: acl head: reasons 3854
# 3879 , dep: punct head: see 3881
# 3881 see dep: ROOT head: see 3881
# 3885 Martin dep: dobj head: see 3881
# 3892 v. dep: prep head: see 3881
# 3895 D dep: pobj head: v. 3892
# 3896 ... dep: punct head: see 3881
# 3899
#  dep: dep head: ... 3896
# 3900 This dep: det head: case 3905
# 3905 case dep: nsubj head: concerns 3910
# 3910 concerns dep: ROOT head: concerns 3910
# 3919 the dep: det head: fees 3923
# 3923 fees dep: dobj head: concerns 3910
# 3928 that dep: nsubj head: be 3937
# 3933 may dep: aux head: be 3937
# 3937 be dep: relcl head: fees 3923
# 3940 awarde dep: acomp head: be 3937
# 3946 ... dep: punct head: concerns 3910
# 3949
#  dep: dep head: ... 3946
# 3950 I dep: nsubj head: know 3959
# 3952 do dep: aux head: know 3959
# 3955 not dep: neg head: know 3959
# 3959 know dep: ROOT head: know 3959
# 3964 what dep: ccomp head: know 3959
# 3969 the dep: det head: judges 3973
# 3973 judges dep: nsubj head: what 3964
# 3980 of dep: prep head: judges 3973
# 3983 our dep: poss head: district 3987
# 3987 district dep: pobj head: of 3980
# 3996 ... dep: punct head: know 3959
# 3999
#  dep: dep head: ... 3996
# 4000 This dep: det head: case 4005
# 4005 case dep: nsubj head: concerns 4010
# 4010 concerns dep: ROOT head: concerns 4010
# 4019 the dep: det head: legitimacy 4023
# 4023 legitimacy dep: dobj head: concerns 4010
# 4034 under dep: prep head: legitimacy 4023
# 4040 Rule dep: pobj head: under 4034
# 4045 2 dep: nummod head: Rule 4040
# 4046 ... dep: punct head: concerns 4010
# 4049
#  dep: dep head: ... 4046
# 4050 This dep: det head: case 4065
# 4055 copyright dep: compound head: case 4065
# 4065 case dep: nsubj head: concerns 4070
# 4070 concerns dep: ROOT head: concerns 4070
# 4079 the dep: det head: rights 4083
# 4083 rights dep: dobj head: concerns 4070
# 4090 of dep: prep head: rights 4083
# 4093 fre dep: pobj head: of 4090
# 4096 ... dep: punct head: concerns 4070
# 4099
#  dep: dep head: ... 4096
# 4100 This dep: det head: case 4105
# 4105 case dep: nsubj head: raises 4110
# 4110 raises dep: ccomp head: consider 4153
# 4117 an dep: det head: issue 4120
# 4120 issue dep: dobj head: raises 4110
# 4126 of dep: prep head: issue 4120
# 4129 first dep: amod head: impression 4135
# 4135 impression dep: pobj head: of 4126
# 4146 ... dep: punct head: consider 4153
# 4149
#  dep: dep head: ... 4146
# 4150 We dep: nsubj head: consider 4153
# 4153 consider dep: ROOT head: consider 4153
# 4162 whether dep: mark head: § 4170
# 4170 § dep: ccomp head: consider 4153
# 4172 7002 dep: appos head: § 4170
# 4177 of dep: prep head: 7002 4172
# 4180 the dep: det head: Con 4193
# 4184 Resource dep: compound head: Con 4193
# 4193 Con dep: pobj head: of 4177
# 4196 ... dep: punct head: consider 4153
# 4199
#  dep: dep head: ... 4196
# 4200 We dep: nsubj head: granted 4203
# 4203 granted dep: ROOT head: granted 4203
# 4211 certiorari dep: dobj head: granted 4203
# 4222 to dep: aux head: determine 4225
# 4225 determine dep: advcl head: granted 4203
# 4235 whether dep: mark head: join 4252
# 4243 the dep: nsubj head: join 4252
# 4246 ... dep: punct head: join 4252
# 4249
#  dep: dep head: ... 4246
# 4250 I dep: nsubj head: join 4252
# 4252 join dep: ccomp head: determine 4225
# 4257 the dep: det head: Court 4261
# 4261 Court dep: poss head: opinion 4269
# 4266 's dep: case head: Court 4261
# 4269 opinion dep: dobj head: join 4252
# 4276 , dep: punct head: join 4252
# 4278 and dep: cc head: join 4252
# 4282 add dep: conj head: join 4252
# 4286 that dep: dobj head: add 4282
# 4291 even dep: advmod head: add 4282
# 4296 ... dep: punct head: granted 4203
# 4299
#  dep: dep head: ... 4296
# 4300 We dep: nsubj head: granted 4303
# 4303 granted dep: ROOT head: granted 4303
# 4311 certiorari dep: dobj head: granted 4303
# 4322 to dep: aux head: consider 4325
# 4325 consider dep: advcl head: granted 4303
# 4334 the dep: det head: analysis 4338
# 4338 analysis dep: dobj head: consider 4325
# 4346 ... dep: punct head: granted 4303
# 4349
#  dep: dep head: ... 4346
# 4350 In dep: prep head: consider 4366
# 4353 this dep: det head: case 4358
# 4358 case dep: pobj head: In 4350
# 4363 we dep: nsubj head: consider 4366
# 4366 consider dep: ROOT head: consider 4366
# 4375 two dep: nummod head: questions 4379
# 4379 questions dep: dobj head: consider 4366
# 4389 about dep: prep head: questions 4379
# 4395 h dep: pobj head: about 4389
# 4396 ... dep: punct head: consider 4366
# 4399
#  dep: dep head: ... 4396
# 4400 Two dep: nummod head: years 4404
# 4404 years dep: npadvmod head: ago 4410
# 4410 ago dep: advmod head: ordered 4418
# 4413 , dep: punct head: ordered 4418
# 4415 we dep: nsubj head: ordered 4418
# 4418 ordered dep: ROOT head: ordered 4418
# 4426 that dep: dobj head: ordered 4418
# 4431 a dep: det head: certificate 4433
# 4433 certificate dep: compound head: o 4445
# 4445 o dep: dobj head: ordered 4418
# 4446 ... dep: punct head: ordered 4418
# 4449
#  dep: dep head: ... 4446
# 4450 In dep: ROOT head: In 4450
# 4453 Batson dep: pobj head: In 4450
# 4460 v. dep: prep head: Batson 4453
# 4463 Kentucky dep: pobj head: v. 4460
# 4471 , dep: punct head: In 4450
# 4473 476 dep: nummod head: 1986 4486
# 4477 U.S. dep: nmod head: 1986 4486
# 4482 79 dep: nummod head: U.S. 4477
# 4485 ( dep: punct head: 1986 4486
# 4486 1986 dep: pobj head: In 4450
# 4490 ) dep: punct head: In 4450
# 4491 , dep: punct head: In 4450
# 4493 the dep: pobj head: In 4450
# 4496 ... dep: punct head: the 4493
# 4499
#  dep: dep head: ... 4496
# 4500 In dep: prep head: raises 4560
# 4503 the dep: det head: hours 4521
# 4507 early dep: amod head: morning 4513
# 4513 morning dep: compound head: hours 4521
# 4521 hours dep: pobj head: In 4500
# 4527 of dep: prep head: hours 4521
# 4530 November dep: pobj head: of 4527
# 4539 16 dep: nummod head: November 4530
# 4541 , dep: punct head: November 4530
# 4543 198 dep: nummod head: November 4530
# 4546 ... dep: punct head: In 4500
# 4549
#  dep: dep head: ... 4546
# 4550 This dep: det head: case 4555
# 4555 case dep: nsubj head: raises 4560
# 4560 raises dep: ROOT head: raises 4560
# 4567 a dep: det head: constitutional 4569
# 4569 constitutional dep: dobj head: raises 4560
# 4584 and dep: cc head: constitutional 4569
# 4588 a dep: det head: pruden 4590
# 4590 pruden dep: conj head: constitutional 4569
# 4596 ... dep: punct head: raises 4560
# 4599
#  dep: dep head: ... 4596
# 4600 I dep: nsubj head: agree 4602
# 4602 agree dep: ROOT head: agree 4602
# 4608 with dep: prep head: agree 4602
# 4613 the dep: det head: majority 4617
# 4617 majority dep: pobj head: with 4608
# 4626 that dep: punct head: agree 4602
# 4631 the dep: det head: Constitutio 4635
# 4635 Constitutio dep: nsubj head: that 4626
# 4646 ... dep: punct head: Constitutio 4635
# 4649
#  dep: dep head: ... 4646
# 4650 [ dep: dep head: presents 4665
# 4651 ]\nThis dep: det head: case 4660
# 4660 case dep: nsubj head: presents 4665
# 4665 presents dep: ROOT head: presents 4665
# 4674 two dep: nummod head: questions 4678
# 4678 questions dep: compound head: affectin 4688
# 4688 affectin dep: dobj head: presents 4665
# 4696 ... dep: punct head: presents 4665
# 4699
#  dep: dep head: ... 4696
# 4700 Congress dep: nsubj head: provided 4713
# 4709 has dep: aux head: provided 4713
# 4713 provided dep: ROOT head: provided 4713
# 4721 , dep: punct head: provided 4713
# 4723 in dep: prep head: provided 4713
# 4726 18 dep: nummod head: § 4737
# 4729 U.S. dep: compound head: § 4737
# 4734 C. dep: compound head: § 4737
# 4737 § dep: pobj head: in 4723
# 4739 3621(e dep: appos head: § 4737
# 4745 ) dep: punct head: provided 4713
# 4746 ... dep: punct head: provided 4713
# 4749
#  dep: dep head: ... 4746
# 4750 The dep: det head: question 4754
# 4754 question dep: nsubj head: is 4785
# 4763 at dep: prep head: question 4754
# 4766 issue dep: pobj head: at 4763
# 4772 in dep: prep head: question 4754
# 4775 this dep: det head: case 4780
# 4780 case dep: pobj head: in 4772
# 4785 is dep: ROOT head: is 4785
# 4788 whether dep: attr head: is 4785
# 4796 ... dep: punct head: is 4785
# 4799
#  dep: dep head: ... 4796
# 4800 The dep: det head: issue 4804
# 4804 issue dep: nsubj head: is 4810
# 4810 is dep: ROOT head: is 4810
# 4813 whether dep: mark head: is 4810
# 4821 the dep: det head: law 4831
# 4825 Burma dep: compound head: law 4831
# 4831 law dep: prep head: whether 4813
# 4835 of dep: prep head: law 4831
# 4838 the dep: det head: Comm 4842
# 4842 Comm dep: pobj head: of 4835
# 4846 ... dep: punct head: is 4810
# 4849
#  dep: dep head: ... 4846
# 4850 It dep: nsubj head: is 4853
# 4853 is dep: ROOT head: is 4853
# 4856 perfectly dep: advmod head: obvious 4866
# 4866 obvious dep: acomp head: is 4853
# 4874 on dep: prep head: is 4853
# 4877 the dep: det head: face 4881
# 4881 face dep: pobj head: on 4874
# 4886 of dep: prep head: face 4881
# 4889 this dep: det head: st 4894
# 4894 st dep: pobj head: of 4886
# 4896 ... dep: punct head: st 4894
# 4899
#  dep: dep head: ... 4896
# 4900 The dep: det head: issue 4904
# 4904 issue dep: nsubj head: is 4923
# 4910 in dep: prep head: issue 4904
# 4913 this dep: det head: case 4918
# 4918 case dep: pobj head: in 4910
# 4923 is dep: ROOT head: is 4923
# 4926 whether dep: mark head: Massachusett 4934
# 4934 Massachusett dep: nsubj head: contend 4962
# 4946 ... dep: punct head: Massachusett 4934
# 4949
#  dep: dep head: ... 4946
# 4950 Petitioners dep: nsubj head: contend 4962
# 4962 contend dep: ccomp head: is 4923
# 4970 that dep: prep head: contend 4962
# 4975 a dep: det head: ordinance 4985
# 4977 village dep: compound head: ordinance 4985
# 4985 ordinance dep: dobj head: contend 4962
# 4995 m dep: appos head: ordinance 4985
# 4996 ... dep: punct head: ordinance 4985
# 4999
#  dep: dep head: ... 4996
# 5000 While dep: mark head: joining 5006
# 5006 joining dep: advcl head: write 5037
# 5014 the dep: det head: Court 5018
# 5018 Court dep: poss head: opinion 5026
# 5023 's dep: case head: Court 5018
# 5026 opinion dep: dobj head: joining 5006
# 5033 , dep: punct head: write 5037
# 5035 I dep: nsubj head: write 5037
# 5037 write dep: ROOT head: write 5037
# 5043 sep dep: dobj head: write 5037
# 5046 ... dep: punct head: write 5037
# 5049
#  dep: dep head: ... 5046
# 5050 Stratton dep: nsubj head: is 5059
# 5059 is dep: ROOT head: is 5059
# 5062 a dep: det head: village 5064
# 5064 village dep: attr head: is 5059
# 5072 of dep: prep head: village 5064
# 5075 278 dep: nummod head: people 5079
# 5079 people dep: pobj head: of 5072
# 5086 located dep: acl head: people 5079
# 5094 al dep: npadvmod head: located 5086
# 5096 ... dep: punct head: al 5094
# 5099
#  dep: dep head: ... 5096
# 5100 Section dep: compound head: 404(a 5108
# 5108 404(a dep: ROOT head: 404(a 5108
# 5113 ) dep: punct head: 404(a 5108
# 5115 of dep: prep head: 404(a 5108
# 5118 the dep: det head: Act 5134
# 5122 Clean dep: compound head: Water 5128
# 5128 Water dep: compound head: Act 5134
# 5134 Act dep: pobj head: of 5115
# 5138 ( dep: punct head: Act 5134
# 5139 CWA dep: appos head: Act 5134
# 5143 or dep: cc head: CWA 5139
# 5146 ... dep: punct head: 404(a 5108
# 5149
#  dep: dep head: ... 5146
# 5150 In dep: prep head: River 5172
# 5153 1969 dep: pobj head: In 5150
# 5157 , dep: punct head: River 5172
# 5159 the dep: det head: River 5172
# 5163 Cuyahoga dep: compound head: River 5172
# 5172 River dep: ROOT head: River 5172
# 5178 in dep: prep head: River 5172
# 5181 Cleveland dep: pobj head: in 5178
# 5190 , dep: punct head: Cleveland 5181
# 5192 Ohio dep: appos head: Cleveland 5181
# 5196 ... dep: punct head: River 5172
# 5199
#  dep: dep head: ... 5196
# 5200 Under dep: prep head: sometim 5239
# 5206 a dep: det head: practice 5221
# 5208 longstanding dep: amod head: practice 5221
# 5221 practice dep: pobj head: Under 5200
# 5229 , dep: punct head: sometim 5239
# 5231 a dep: det head: court 5233
# 5233 court dep: nsubj head: sometim 5239
# 5239 sometim dep: ROOT head: sometim 5239
# 5246 ... dep: punct head: sometim 5239
# 5249
#  dep: dep head: ... 5246
# 5250 I dep: nsubj head: concur 5252
# 5252 concur dep: ROOT head: concur 5252
# 5259 in dep: prep head: concur 5252
# 5262 Parts dep: compound head: I 5268
# 5268 I dep: pobj head: in 5259
# 5270 and dep: cc head: I 5268
# 5274 II dep: conj head: I 5268
# 5277 of dep: prep head: I 5268
# 5280 the dep: det head: Court 5284
# 5284 Court dep: poss head: opin 5292
# 5289 's dep: case head: Court 5284
# 5292 opin dep: pobj head: of 5277
# 5296 ... dep: punct head: concur 5252
# 5299
#  dep: dep head: ... 5296
# 5300 The dep: det head: question 5304
# 5304 question dep: nsubj head: is 5318
# 5313 here dep: advmod head: question 5304
# 5318 is dep: ROOT head: is 5318
# 5321 when dep: advmod head: o 5345
# 5326 the dep: det head: o 5345
# 5330 1 dep: nummod head: year 5332
# 5331 - dep: punct head: year 5332
# 5332 year dep: compound head: statute 5337
# 5337 statute dep: compound head: o 5345
# 5345 o dep: punct head: is 5318
# 5346 ... dep: punct head: o 5345
# 5349
#  dep: dep head: ... 5346
# 5350 The dep: det head: Court 5354
# 5354 Court dep: nsubj head: took 5360
# 5360 took dep: ROOT head: took 5360
# 5365 this dep: det head: case 5370
# 5370 case dep: dobj head: took 5360
# 5375 to dep: aux head: determine 5378
# 5378 determine dep: advcl head: took 5360
# 5388 whether dep: dobj head: determine 5378
# 5396 ... dep: punct head: took 5360
# 5399
#  dep: dep head: ... 5396
# 5400 The dep: det head: question 5404
# 5404 question dep: nsubj head: is 5426
# 5413 in dep: prep head: question 5404
# 5416 this dep: det head: case 5421
# 5421 case dep: pobj head: in 5413
# 5426 is dep: ROOT head: is 5426
# 5429 whether dep: mark head: claiman 5439
# 5437 a dep: det head: claiman 5439
# 5439 claiman dep: attr head: is 5426
# 5446 ... dep: punct head: claiman 5439
# 5449
#  dep: dep head: ... 5446
# 5450 Margaret dep: compound head: Whitecotton 5459
# 5459 Whitecotton dep: nsubjpass head: born 5475
# 5471 was dep: auxpass head: born 5475
# 5475 born dep: ROOT head: born 5475
# 5480 in dep: prep head: born 5475
# 5483 1975 dep: pobj head: in 5480
# 5488 with dep: prep head: born 5475
# 5493 a dep: det head: c 5495
# 5495 c dep: pobj head: with 5488
# 5496 ... dep: punct head: c 5495
# 5499
#  dep: dep head: ... 5496
# 5500 I dep: ROOT head: I 5500
# 5502 Since dep: prep head: I 5500
# 5508 the dep: det head: inception 5512
# 5512 inception dep: pobj head: Since 5502
# 5522 of dep: prep head: inception 5512
# 5525 cable dep: compound head: television 5531
# 5531 television dep: pobj head: of 5522
# 5541 , dep: punct head: television 5531
# 5543 cab dep: conj head: television 5531
# 5546 ... dep: punct head: cab 5543
# 5549
#  dep: dep head: ... 5546
# 5550 One dep: nummod head: century 5554
# 5554 century dep: npadvmod head: ago 5562
# 5562 ago dep: advmod head: admo 5592
# 5565 , dep: punct head: ago 5562
# 5567 the dep: det head: admo 5592
# 5571 first dep: amod head: admo 5592
# 5577 Justice dep: compound head: Harlan 5585
# 5585 Harlan dep: compound head: admo 5592
# 5592 admo dep: ROOT head: admo 5592
# 5596 ... dep: punct head: admo 5592
# 5599
#  dep: dep head: ... 5596
# 5600 The dep: det head: Court 5604
# 5604 Court dep: nsubj head: mistaken 5614
# 5610 has dep: aux head: mistaken 5614
# 5614 mistaken dep: ROOT head: mistaken 5614
# 5623 a dep: det head: Kulturkampf 5625
# 5625 Kulturkampf dep: dobj head: mistaken 5614
# 5637 for dep: prep head: mistaken 5614
# 5641 a dep: det head: fit 5643
# 5643 fit dep: pobj head: for 5637
# 5646 ... dep: punct head: mistaken 5614
# 5649
#  dep: dep head: ... 5646
# 5650 The dep: det head: question 5654
# 5654 question dep: nsubj head: is 5673
# 5663 presented dep: acl head: question 5654
# 5673 is dep: ROOT head: is 5673
# 5676 whether dep: mark head: moratorium 5686
# 5684 a dep: det head: moratorium 5686
# 5686 moratorium dep: punct head: is 5673
# 5696 ... dep: punct head: moratorium 5686
# 5699
#  dep: dep head: ... 5696
# 5700 For dep: prep head: were 5735
# 5704 over dep: quantmod head: half 5709
# 5709 half dep: nummod head: decade 5716
# 5714 a dep: det head: decade 5716
# 5716 decade dep: pobj head: For 5700
# 5723 petitioners dep: nsubj head: were 5735
# 5735 were dep: ccomp head: join 5752
# 5740 prohib dep: attr head: were 5735
# 5746 ... dep: punct head: join 5752
# 5749
#  dep: dep head: ... 5746
# 5750 I dep: nsubj head: join 5752
# 5752 join dep: ROOT head: join 5752
# 5757 The dep: det head: Justice 5767
# 5761 Chief dep: compound head: Justice 5767
# 5767 Justice dep: poss head: dissent 5777
# 5774 's dep: case head: Justice 5767
# 5777 dissent dep: dobj head: join 5752
# 5784 . dep: punct head: join 5752
# 5786 I dep: nsubj head: write 5788
# 5788 write dep: ROOT head: write 5788
# 5794 se dep: advmod head: write 5788
# 5796 ... dep: punct head: write 5788
# 5799
#  dep: dep head: ... 5796
# 5800 We dep: nsubj head: granted 5803
# 5803 granted dep: ROOT head: granted 5803
# 5811 certiorari dep: dobj head: granted 5803
# 5821 , dep: punct head: certiorari 5811
# 5823 520 dep: nummod head: U.S. 5827
# 5827 U.S. dep: appos head: certiorari 5811
# 5832 1239 dep: nummod head: U.S. 5827
# 5837 ( dep: punct head: U.S. 5827
# 5838 1997 dep: appos head: U.S. 5827
# 5842 ) dep: punct head: U.S. 5827
# ...
# 85096 ... dep: punct head: is 85083
# 85099
#  dep: dep head: ... 85096
# 85100 This dep: det head: case 85105
# 85105 case dep: nsubj head: presents 85110
# 85110 presents dep: ROOT head: presents 85110
# 85119 the dep: det head: question 85123
# 85123 question dep: dobj head: presents 85110
# 85132 whether dep: mark head: agree 85152
# 85140 a dep: det head: trib 85142
# 85142 trib dep: prep head: whether 85132
# 85146 ... dep: punct head: trib 85142
# 85149
#  dep: dep head: ... 85146
# 85150 I dep: nsubj head: agree 85152
# 85152 agree dep: ccomp head: presents 85110
# 85158 that dep: mark head: incurred 85225
# 85163 the dep: det head: Tribal 85190
# 85167 Fallon dep: compound head: Shoshone 85181
# 85174 Paiute dep: compound head: Shoshone 85181
# 85180 - dep: punct head: Shoshone 85181
# 85181 Shoshone dep: compound head: Tribal 85190
# 85190 Tribal dep: nsubj head: incurred 85225
# 85196 ... dep: punct head: Tribal 85190
# 85199
#  dep: dep head: ... 85196
# 85200 Petitioners dep: appos head: Tribal 85190
# 85212 in dep: prep head: Tribal 85190
# 85215 this dep: det head: case 85220
# 85220 case dep: pobj head: in 85212
# 85225 incurred dep: ccomp head: agree 85152
# 85234 substantial dep: acomp head: incurred 85225
# 85246 ... dep: punct head: presents 85110
# 85249
#  dep: dep head: ... 85246
# 85250 The dep: det head: petitioners 85254
# 85254 petitioners dep: nsubj head: have 85291
# 85265 , dep: punct head: petitioners 85254
# 85267 two dep: nummod head: companies 85280
# 85271 chemical dep: compound head: companies 85280
# 85280 companies dep: appos head: petitioners 85254
# 85289 , dep: punct head: petitioners 85254
# 85291 have dep: ROOT head: have 85291
# 85296 ... dep: punct head: have 85291
# 85299
#  dep: dep head: ... 85296
# 85300 The dep: det head: question 85304
# 85304 question dep: nsubj head: is 85326
# 85313 in dep: prep head: question 85304
# 85316 this dep: det head: case 85321
# 85321 case dep: pobj head: in 85313
# 85326 is dep: ROOT head: is 85326
# 85329 whether dep: mark head: dredge 85339
# 85337 a dep: det head: dredge 85339
# 85339 dredge dep: attr head: is 85326
# 85346 ... dep: punct head: dredge 85339
# 85349
#  dep: dep head: ... 85346
# 85350 As dep: mark head: suggested 85360
# 85353 I dep: nsubj head: suggested 85360
# 85355 have dep: aux head: suggested 85360
# 85360 suggested dep: ROOT head: suggested 85360
# 85370 in dep: prep head: suggested 85360
# 85373 the dep: det head: past 85377
# 85377 past dep: pobj head: in 85370
# 85381 , dep: punct head: suggested 85360
# 85383 the dep: det head: use 85393
# 85387 Court dep: compound head: use 85393
# 85393 use dep: dobj head: suggested 85360
# 85396 ... dep: punct head: use 85393
# 85399
#  dep: dep head: ... 85396
# 85400 This dep: det head: case 85405
# 85405 case dep: nsubj head: presents 85410
# 85410 presents dep: ROOT head: presents 85410
# 85419 the dep: det head: question 85423
# 85423 question dep: dobj head: presents 85410
# 85432 whether dep: det head: state 85440
# 85440 state dep: dep head: presents 85410
# 85446 ... dep: punct head: presents 85410
# 85449
#  dep: dep head: ... 85446
# 85450 Justice dep: compound head: Breyer 85458
# 85458 Breyer dep: nsubj head: explained 85469
# 85465 has dep: aux head: explained 85469
# 85469 explained dep: ROOT head: explained 85469
# 85479 why dep: advmod head: r 85495
# 85483 the dep: det head: Court 85487
# 85487 Court dep: poss head: r 85495
# 85492 's dep: case head: Court 85487
# 85495 r dep: punct head: explained 85469
# 85496 ... dep: punct head: r 85495
# 85499
#  dep: dep head: ... 85496
# 85500 The dep: det head: Court 85504
# 85504 Court dep: nsubj head: holds 85510
# 85510 holds dep: ROOT head: holds 85510
# 85516 that dep: mark head: b 85545
# 85521 a dep: det head: person 85531
# 85523 private dep: amod head: person 85531
# 85531 person dep: nsubj head: b 85545
# 85538 can dep: aux head: b 85545
# 85541 not dep: neg head: b 85545
# 85545 b dep: ccomp head: holds 85510
# 85546 ... dep: punct head: b 85545
# 85549
#  dep: dep head: ... 85546
# 85550 Appellant dep: nsubj head: was 85560
# 85560 was dep: ROOT head: was 85560
# 85564 one dep: attr head: was 85560
# 85568 of dep: prep head: one 85564
# 85571 several dep: amod head: plaintiffs 85579
# 85579 plaintiffs dep: pobj head: of 85568
# 85590 in dep: prep head: plaintiffs 85579
# 85593 thi dep: pobj head: in 85590
# 85596 ... dep: punct head: was 85560
# 85599
#  dep: dep head: ... 85596
# 85600 The dep: det head: Court 85604
# 85604 Court dep: nsubj head: affirms 85616
# 85610 today dep: npadvmod head: affirms 85616
# 85616 affirms dep: ROOT head: affirms 85616
# 85624 a dep: det head: Cou 85643
# 85626 Federal dep: compound head: Cou 85643
# 85634 District dep: compound head: Cou 85643
# 85643 Cou dep: dobj head: affirms 85616
# 85646 ... dep: punct head: Cou 85643
# 85649
#  dep: dep head: ... 85646
# 85650 This dep: det head: case 85655
# 85655 case dep: nsubj head: involves 85660
# 85660 involves dep: ROOT head: involves 85660
# 85669 the dep: det head: process 85673
# 85673 process dep: dobj head: involves 85660
# 85681 by dep: prep head: Ohio 85690
# 85684 which dep: pobj head: by 85681
# 85690 Ohio dep: dep head: is 85717
# 85695 c dep: nummod head: Ohio 85690
# 85696 ... dep: punct head: Ohio 85690
# 85699
#  dep: dep head: ... 85696
# 85700 In dep: prep head: is 85717
# 85703 my dep: poss head: opinion 85706
# 85706 opinion dep: pobj head: In 85700
# 85714 it dep: nsubj head: is 85717
# 85717 is dep: ccomp head: involves 85660
# 85720 unwise dep: acomp head: is 85717
# 85727 for dep: prep head: unwise 85720
# 85731 the dep: det head: Court 85735
# 85735 Court dep: pobj head: for 85727
# 85741 to dep: prep head: is 85717
# 85744 an dep: pobj head: to 85741
# 85746 ... dep: punct head: is 85717
# 85749
#  dep: dep head: ... 85746
# 85750 [ dep: dep head: provides 85768
# 85751 ]\nPennsylvania dep: nsubj head: provides 85768
# 85768 provides dep: ccomp head: join 85802
# 85777 in dep: prep head: provides 85768
# 85780 its dep: poss head: workers 85784
# 85784 workers dep: poss head: com 85793
# 85791 ' dep: case head: workers 85784
# 85793 com dep: pobj head: in 85777
# 85796 ... dep: punct head: join 85802
# 85799
#  dep: dep head: ... 85796
# 85800 I dep: nsubj head: join 85802
# 85802 join dep: ROOT head: join 85802
# 85807 Part dep: compound head: III 85812
# 85812 III dep: dobj head: join 85802
# 85816 of dep: prep head: III 85812
# 85819 the dep: det head: Court 85823
# 85823 Court dep: poss head: opinion 85831
# 85828 's dep: case head: Court 85823
# 85831 opinion dep: pobj head: of 85816
# 85839 on dep: prep head: opinion 85831
# 85842 the dep: pobj head: on 85839
# 85846 ... dep: punct head: the 85842
# 85849
#  dep: dep head: ... 85846
# 85850 The dep: det head: Act 85884
# 85854 Florida dep: compound head: Forfeiture 85873
# 85862 Contraband dep: compound head: Forfeiture 85873
# 85873 Forfeiture dep: compound head: Act 85884
# 85884 Act dep: nsubj head: provides 85888
# 85888 provides dep: conj head: join 85802
# 85896 ... dep: punct head: join 85802
# 85899
#  dep: dep head: ... 85896
# 85900 I dep: nsubj head: join 85902
# 85902 join dep: ROOT head: join 85902
# 85907 the dep: det head: Court 85911
# 85911 Court dep: poss head: subject 85927
# 85916 's dep: case head: Court 85911
# 85919 opinion dep: compound head: subject 85927
# 85927 subject dep: dobj head: join 85902
# 85935 to dep: prep head: subject 85927
# 85938 a dep: det head: qualif 85940
# 85940 qualif dep: pobj head: to 85935
# 85946 ... dep: punct head: join 85902
# 85949
#  dep: dep head: ... 85946
# 85950 During dep: prep head: obta 85992
# 85957 the dep: det head: summer 85961
# 85961 summer dep: pobj head: During 85950
# 85968 of dep: prep head: summer 85961
# 85971 1993 dep: pobj head: of 85968
# 85975 , dep: punct head: obta 85992
# 85977 Florida dep: compound head: obta 85992
# 85985 police dep: compound head: obta 85992
# 85992 obta dep: ROOT head: obta 85992
# 85996 ... dep: punct head: obta 85992
# 85999
#  dep: dep head: ... 85996
# 86000 In dep: prep head: decide 86017
# 86003 this dep: det head: case 86008
# 86008 case dep: pobj head: In 86000
# 86012 , dep: punct head: decide 86017
# 86014 we dep: nsubj head: decide 86017
# 86017 decide dep: ROOT head: decide 86017
# 86024 whether dep: mark head: explained 86128
# 86032 the dep: det head: Ame 86043
# 86036 Eighth dep: compound head: Ame 86043
# 86043 Ame dep: nsubj head: whether 86024
# 86046 ... dep: punct head: Ame 86043
# 86049
#  dep: dep head: ... 86046
# 86050 In dep: prep head: explained 86128
# 86053 my dep: poss head: opinion 86056
# 86056 opinion dep: pobj head: In 86050
# 86064 in dep: prep head: opinion 86056
# 86067 Harmelin dep: pobj head: in 86064
# 86076 v. dep: prep head: Harmelin 86067
# 86079 Michigan dep: pobj head: v. 86076
# 86087 , dep: punct head: Harmelin 86067
# 86089 501 dep: nummod head: U.S 86093
# 86093 U.S dep: appos head: Harmelin 86067
# 86096 ... dep: punct head: U.S 86093
# 86099
#  dep: dep head: ... 86096
# 86100 JUSTICE dep: compound head: BREYER 86108
# 86108 BREYER dep: nsubj head: explained 86128
# 86115 has dep: aux head: explained 86128
# 86119 cogently dep: advmod head: explained 86128
# 86128 explained dep: ccomp head: decide 86017
# 86138 why dep: advmod head: is 86178
# 86142 the dep: nsubj head: is 86178
# 86146 ... dep: punct head: the 86142
# 86149
#  dep: dep head: ... 86146
# 86150 The dep: det head: question 86169
# 86154 constitutional dep: amod head: question 86169
# 86169 question dep: nsubj head: is 86178
# 86178 is dep: ccomp head: explained 86128
# 86181 whether dep: mark head: presents 86210
# 86189 the dep: det head: th 86194
# 86193 " dep: punct head: th 86194
# 86194 th dep: nsubj head: presents 86210
# 86196 ... dep: punct head: th 86194
# 86199
#  dep: dep head: ... 86196
# 86200 This dep: det head: case 86205
# 86205 case dep: nsubj head: presents 86210
# 86210 presents dep: ccomp head: is 86178
# 86219 the dep: det head: question 86223
# 86223 question dep: dobj head: presents 86210
# 86232 whether dep: mark head: defe 86242
# 86240 a dep: det head: defe 86242
# 86242 defe dep: advcl head: presents 86210
# 86246 ... dep: punct head: decide 86017
# 86249
#  dep: dep head: ... 86246
# 86250 This dep: det head: petitioner 86255
# 86255 petitioner dep: nsubj head: had 86266
# 86266 had dep: ROOT head: had 86266
# 86270 no dep: det head: right 86288
# 86273 constitutional dep: amod head: right 86288
# 86288 right dep: dobj head: had 86266
# 86294 to dep: prep head: right 86288
# 86296 ... dep: punct head: had 86266
# 86299
#  dep: dep head: ... 86296
# 86300 The dep: det head: Amendment 86310
# 86304 Sixth dep: compound head: Amendment 86310
# 86310 Amendment dep: nsubj head: provides 86320
# 86320 provides dep: ROOT head: provides 86320
# 86329 that dep: mark head: accused 86338
# 86334 the dep: det head: accused 86338
# 86338 accused dep: ccomp head: provides 86320
# 86346 ... dep: punct head: accused 86338
# 86349
#  dep: dep head: ... 86346
# 86350 The dep: det head: issue 86354
# 86354 issue dep: nsubj head: is 86360
# 86360 is dep: ROOT head: is 86360
# 86363 whether dep: mark head: association 86384
# 86371 a dep: det head: association 86384
# 86373 state dep: npadvmod head: wide 86379
# 86379 wide dep: amod head: association 86384
# 86384 association dep: punct head: is 86360
# 86396 ... dep: punct head: association 86384
# 86399
#  dep: dep head: ... 86396
# 86400 We dep: nsubj head: found 86414
# 86403 have dep: aux head: found 86414
# 86408 never dep: neg head: found 86414
# 86414 found dep: ROOT head: found 86414
# 86420 state dep: compound head: action 86426
# 86426 action dep: dobj head: found 86414
# 86433 based dep: acl head: action 86426
# 86439 upon dep: prep head: based 86433
# 86444 me dep: pobj head: upon 86439
# 86446 ... dep: punct head: found 86414
# 86449
#  dep: dep head: ... 86446
# 86450 Petitioner dep: compound head: Suitum 86471
# 86461 Bernadine dep: compound head: Suitum 86471
# 86471 Suitum dep: nsubj head: owns 86478
# 86478 owns dep: ROOT head: owns 86478
# 86483 land dep: dobj head: owns 86478
# 86488 near dep: prep head: owns 86478
# 86493 the dep: pobj head: near 86488
# 86496 ... dep: punct head: owns 86478
# 86499
#  dep: dep head: ... 86496
# 86500 I dep: nsubj head: concur 86502
# 86502 concur dep: ROOT head: concur 86502
# 86509 in dep: prep head: concur 86502
# 86512 the dep: det head: judgment 86516
# 86516 judgment dep: pobj head: in 86509
# 86525 of dep: prep head: judgment 86516
# 86528 the dep: det head: Court 86532
# 86532 Court dep: pobj head: of 86525
# 86537 , dep: punct head: concur 86502
# 86539 and dep: cc head: concur 86502
# 86543 joi dep: punct head: concur 86502
# 86546 ... dep: punct head: joi 86543
# 86549
#  dep: dep head: ... 86546
# 86550 We dep: nsubj head: join 86553
# 86553 join dep: ROOT head: join 86553
# 86558 the dep: det head: opinion 86573
# 86562 per dep: nmod head: opinion 86573
# 86566 curiam dep: compound head: opinion 86573
# 86573 opinion dep: dobj head: join 86553
# 86580 . dep: punct head: join 86553
# 86582 We dep: nsubj head: write 86585
# 86585 write dep: ROOT head: write 86585
# 86591 separ dep: dobj head: write 86585
# 86596 ... dep: punct head: separ 86591
# 86599
#  dep: dep head: ... 86596
# 86600 The dep: det head: Constitution 86604
# 86604 Constitution dep: nsubj head: assigns 86617
# 86617 assigns dep: ROOT head: assigns 86617
# 86625 to dep: prep head: assigns 86617
# 86628 the dep: det head: States 86632
# 86632 States dep: pobj head: to 86625
# 86639 the dep: det head: pri 86643
# 86643 pri dep: dobj head: assigns 86617
# 86646 ... dep: punct head: pri 86643
# 86649
#  dep: dep head: ... 86646
# 86650 The dep: det head: Court 86654
# 86654 Court dep: nsubj head: reviewed 86676
# 86660 should dep: aux head: reviewed 86676
# 86667 not dep: neg head: reviewed 86676
# 86671 have dep: aux head: reviewed 86676
# 86676 reviewed dep: ROOT head: reviewed 86676
# 86685 either dep: preconj head: Bush 86692
# 86692 Bush dep: dobj head: reviewed 86676
# 86696 ... dep: punct head: Bush 86692
# 86699
#  dep: dep head: ... 86696
# 86700 " dep: punct head: knock 86728
# 86701 Opportunity dep: nsubj head: knock 86728
# 86713 does dep: aux head: knock 86728
# 86717 n't dep: neg head: knock 86728
# 86721 always dep: advmod head: knock 86728
# 86728 knock dep: ROOT head: knock 86728
# 86734 . dep: punct head: knock 86728
# 86736 . dep: punct head: knock 86728
# 86738 . dep: punct head: knock 86728
# 86740 someti dep: ROOT head: someti 86740
# 86746 ... dep: punct head: someti 86740
# 86749
#  dep: dep head: ... 86746
# 86750 This dep: det head: case 86755
# 86755 case dep: nsubj head: concerns 86760
# 86760 concerns dep: ROOT head: concerns 86760
# 86769 what dep: nsubj head: come 86778
# 86774 has dep: aux head: come 86778
# 86778 come dep: ccomp head: concerns 86760
# 86783 to dep: aux head: known 86789
# 86786 be dep: auxpass head: known 86789
# 86789 known dep: advcl head: come 86778
# 86795 a dep: dobj head: known 86789
# 86796 ... dep: punct head: a 86795
# 86799
#  dep: dep head: ... 86796
# 86800 Rules dep: pobj head: a 86795
# 86806 of dep: prep head: Rules 86800
# 86809 the dep: det head: Bar 86821
# 86813 Florida dep: compound head: Bar 86821
# 86821 Bar dep: pobj head: of 86806
# 86825 prohibit dep: advcl head: come 86778
# 86834 personal dep: amod head: inj 86843
# 86843 inj dep: dobj head: prohibit 86825
# 86846 ... dep: punct head: inj 86843
# 86849
#  dep: dep head: ... 86846
# 86850 Attorneys dep: npadvmod head: come 86778
# 86860 who dep: nsubj head: communicate 86864
# 86864 communicate dep: relcl head: Attorneys 86850
# 86876 their dep: poss head: willingness 86882
# 86882 willingness dep: dobj head: communicate 86864
# 86894 to dep: prep head: communicate 86864
# 86896 ... dep: punct head: concerns 86760
# 86899
#  dep: dep head: ... 86896
# 86900 We dep: nsubj head: decide 86908
# 86903 must dep: aux head: decide 86908
# 86908 decide dep: ROOT head: decide 86908
# 86915 whether dep: mark head: be 86944
# 86923 punitive dep: amod head: damages 86932
# 86932 damages dep: nsubj head: be 86944
# 86940 may dep: aux head: be 86944
# 86944 be dep: ccomp head: decide 86908
# 86946 ... dep: punct head: decide 86908
# 86949
#  dep: dep head: ... 86946
# 86950 I dep: nsubj head: join 86952
# 86952 join dep: ROOT head: join 86952
# 86957 the dep: det head: Court 86961
# 86961 Court dep: poss head: opinion 86969
# 86966 's dep: case head: Court 86961
# 86969 opinion dep: dobj head: join 86952
# 86977 because dep: mark head: agree 86987
# 86985 I dep: nsubj head: agree 86987
# 86987 agree dep: advcl head: join 86952
# 86993 tha dep: dobj head: agree 86987
# 86996 ... dep: punct head: join 86952

# %% [markdown]
# ## N-grams (using code template from Sooji)

# %% [markdown]
# ### Preprocessing and Cleaning:

# %%
# clean and extract tokens
from nltk.tokenize import word_tokenize

def sent_transform(sent_string):
    selected_words = word_tokenize(sent_string)
    selected_words = [word.lower() for word in selected_words]
    return ['<s>'] + selected_words + ['</s>']

# sent_transform(selected_opinions_string)

# %% [markdown]
# ### Find N-grams:

# %%
# returns sequence of n-grams in the form (context, word)
# context = preceding n-1 word for each word
# <s> = symbol placeholders for missing context (number of preceding words < n-1)

def make_ngram_tuples(words, n):
    words = ['<s>'] * (n - 1) + words + ['</s>']
    ngrams = []
    
    for i in range(n - 1, len(words)):
        context = tuple(words[i - (n - 1):i])
        word = words[i]
        ngrams.append((context, word))
    return ngrams

# %% [markdown]
# ### Build N-gram language model:

# %%
# process training file
# MAKE SURE BUSH V. GORE IS NOT IN THE TRAINING FILE!!!! because it's our target file

from nltk.tokenize import sent_tokenize

def sent_transform(sentence):
    tokens = word_tokenize(sentence.lower())
    return ['<s>'] + tokens + ['</s>']

def process_text(text):
    sentences = sent_tokenize(text)
    processed_sentences = [sent_transform(s) for s in sentences]
    return processed_sentences

processed_sents = process_text(selected_opinions_string)
print(processed_sents[10])
# Out:
# ['<s>', 'the', 'court', 'today', 'finds', 'no', 'first', 'amendment', 'right', '...', 'i\\ni', 'join', 'justice', 'souter', "'s", 'dissent', ',', 'with', 'the', 'e', '...', '</s>']

# %%
# handle vocabulary not seen in training data (accounting for any unknown stuff
# in the Bush v. Gore opinion)
# replace words that appear only once with <UNK>

from collections import defaultdict 

def get_vocab(tokenized_sents):
    word_counts = defaultdict(int)
    
    # Count occurrences of each word in the tokenized sentences
    for sentence in tokenized_sents:
        for word in sentence:
            if word in word_counts:
                word_counts[word] += 1
            else:
                word_counts[word] = 1
    
    # Collect all words that appear more than once
    vocab = {word for word, count in word_counts.items() if count > 1}
    vocab.update({'<s>', '</s>', '<UNK>'})
    return vocab

vocab = get_vocab(processed_sents)
print(len(vocab))
# Out:
# 1064

# %%
# process unknown words
# replaces words appearing only one with <UNK>

def process_unk(tokenized_sents, vocab):
    processed_unk_sentences = []
    for sentence in tokenized_sents:
        processed_sentence = [word if word in vocab else '<UNK>' for word in sentence]
        processed_unk_sentences.append(processed_sentence)
    
    return processed_unk_sentences

# examples before and after processing
print(processed_sents[3])
processed_unk = process_unk(processed_sents, vocab)
print(processed_unk[3])
# Out:
# ['<s>', 'the', 'administrative', 'procedure', 'act', '(', 'apa', ')', 'sets', 'fo', '...', '</s>']
# ['<s>', 'the', 'administrative', 'procedure', 'act', '(', '<UNK>', ')', 'sets', 'fo', '...', '</s>']

# %%
# N-gram frequencies
# obtain word frequency counts

from collections import Counter
def get_freq_dict(tokenized_sents, n):
    frequency_dict = {}
    for sentence in tokenized_sents:
        ngram = make_ngram_tuples(sentence, n)
        for context, word in ngram:
            if context not in frequency_dict:
                frequency_dict[context] = Counter()
            frequency_dict[context][word] += 1
    return frequency_dict

freqdict = get_freq_dict(processed_unk, 2)
print(freqdict[('of',)])
# Out:
# Counter({'the': 167, '<UNK>': 62, 'a': 32, '...': 30, 'appeals': 14, 'this': 11, 'justice': 6, '1990': 5, 'our': 5, 'th': 5, '19': 4, 'criminal': 4, 't': 4, 'law': 4, '1': 4, 'washington': 3, 'habeas': 3, 'an': 3, '1995': 3, 'state': 3, 'title': 3, 'california': 3, '§': 3, 'his': 2, 'wa': 2, 'what': 2, '1938': 2, 'chicago': 2, 'congress': 2, '1978': 2, 'so': 2, '``': 2, '28': 2, 'death': 2, 'today': 2, 'two': 2, 'us': 2, '1996': 2, 'new': 2, 'cases': 2, 'ohio': 2, '1976': 2, '1993': 2, 'south': 1, 'michigan': 1, 'kansas': 1, 'florida': 1, 'agreement': 1, 'first': 1, 'all': 1, 'at': 1, 'sentencing': 1, 'prisoners': 1, 'jurisdiction': 1, 'certiorari': 1, 'respondents': 1, 'action': 1, 'cou': 1, 'venue': 1, '1965': 1, 'cuyahoga': 1, 'parents': 1, 'fact': 1, 'virginia': 1, 'alaska': 1, 'administrative': 1, 'social': 1, 'texas': 1, 'life': 1, 'fe': 1, 'important': 1, 'illinois': 1, 'georgia': 1, '11': 1, 'act': 1, 's': 1, 'co': 1, '1979': 1, '1985': 1, 'los': 1, '8': 1, '1964': 1, '1994': 1, 'evidence': 1, 'con': 1, 'petitioner': 1, 'federal': 1, 'opinions': 1, 'internal': 1, 'pennsylvania': 1, 'capital': 1, 'due': 1, 'those': 1, 'respect': 1, 'one': 1, '1984': 1, 'decision': 1, 'beneficiaries': 1, '18': 1, 'p': 1, 'public': 1, '1988': 1, 'c': 1, 'several': 1})

# %%
# make language model

from collections import namedtuple

def build_ngram_model(textfile, n):
    LanguageModel = namedtuple('LanguageModel', ['n', 'fd', 'vocab'])
    psents = process_text(textfile)
    vocab = get_vocab(psents)
    psentsunk = process_unk(psents, vocab)
    fd = get_freq_dict(psentsunk, n)
    return LanguageModel(n, fd, vocab)

toy_lm = build_ngram_model(selected_opinions_string, 3)

# %%
# log conditional probabilities
# uses add-1 laplacian smoothed conditional probability values

import math

def log_prob(lm, context, word):
    # Get frequency dictionary for the given context, or an empty one if unseen
    freqdict = lm.fd.get(context, {})

    # Compute total count of all words following this context
    total_count = sum(freqdict.values())

    # Get count of the target word (0 if unseen)
    word_count = freqdict.get(word, 0)

    # Get vocabulary size for smoothing
    vocab_size = len(lm.vocab)

    # Apply Laplace (add-1) smoothing
    prob = (word_count + 1) / (total_count + vocab_size)

# %%
# perplexity

import math

def get_ppl(model, text, n, vocab_size):
    tokens = text.split()
    N = len(tokens)
    
    if N - n + 1 <= 0:
        return float('inf')  # prevent division by zero for too short texts
    
    log_prob_sum = 0.0
    for i in range(N - n + 1):
        ngram = tuple(tokens[i:i+n-1])
        word = tokens[i+n-1]
        total_ngram_count = sum(model[ngram].values()) if ngram in model else 0
        prob = (model.get(ngram, {}).get(word, 0) + 1) / (total_ngram_count + vocab_size)
        log_prob_sum += math.log(prob)
    
    ppl = math.exp(-log_prob_sum / (N - n + 1))
    return ppl

# %% [markdown]
# ## Authorship Attribution

# %% [markdown]
# Using Sooji's authorship attribution 2 as reference,
# 1) find the opinions written by each justice (9 total) and do training for each justice (see below)
# 2) apply them to the test file (which would be the Bush v. Gore file that we took out)
# 3) compare results to get the most likely author

# %%
def build_ngram_model_from_text(text, n):
    LanguageModel = namedtuple('LanguageModel', ['n', 'fd', 'vocab'])
    psents = process_text(text)  # process_text should split into sentences/tokens
    vocab = get_vocab(psents)
    psentsunk = process_unk(psents, vocab)
    fd = get_freq_dict(psentsunk, n)
    return LanguageModel(n, fd, vocab)

# %%
import math

def get_ppl(model, text, n, vocab_size):
    tokens = text.split()
    N = len(tokens)
    
    if N - n + 1 <= 0:
        return float('inf')
    
    log_prob_sum = 0.0
    for i in range(N - n + 1):
        ngram = tuple(tokens[i:i+n-1])
        word = tokens[i+n-1]
        total_ngram_count = sum(model[ngram].values()) if ngram in model else 0
        prob = (model.get(ngram, {}).get(word, 0) + 1) / (total_ngram_count + vocab_size)
        log_prob_sum += math.log(prob)
    
    ppl = math.exp(-log_prob_sum / (N - n + 1))
    return ppl

# Get the actual text from the dataframe
opinion_text = selected_opinions_string

justices = [
    "Justice Rehnquist", "Justice Stevens", "Justice O'Connor",
    "Justice Scalia", "Justice Kennedy", "Justice Souter",
    "Justice Thomas", "Justice Ginsburg", "Justice Breyer"
]

df = temp 
n = 2

justice_models = {}
for justice in justices:
    text = ' '.join(df[df['author_name'] == justice]['text'].tolist())
    model = build_ngram_model_from_text(text, n)
    justice_models[justice] = model
    
selected_opinions_text = temp["text"]

# convert selected_opinions_text to string format
selected_opinions_string = selected_opinions_text.to_string()

# remove unneeded number headers
selected_opinions_string = re.sub(r'^\d+\s+', '', selected_opinions_string, flags=re.MULTILINE)

# compute perplexity for each justice
perplexities = {}
for justice, model in justice_models.items():
    perplexities[justice] = get_ppl(model.fd, opinion_text, model.n, len(model.vocab))

# find the most likely author 
most_likely_author = min(perplexities, key=perplexities.get)

print(f"Most likely author: {most_likely_author}")

# print all perplexities scores
print("\nPerplexities for each justice:")
for justice, ppl in sorted(perplexities.items(), key=lambda item: item[1]):
    print(f"{justice}: {ppl:.2f}")
# Out:
# Most likely author: Justice Rehnquist
#
# Perplexities for each justice:
# Justice Rehnquist: 5043.72
# Justice Thomas: 5297.45
# Justice O'Connor: 5386.73
# Justice Stevens: 5391.20
# Justice Kennedy: 5466.39
# Justice Breyer: 5498.13
# Justice Ginsburg: 5558.36
# Justice Scalia: 5771.09
# Justice Souter: 6080.96

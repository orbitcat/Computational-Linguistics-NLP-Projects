"Napaisip ako kung bakit kahit simpleng kampana ay nakakalikha ng masayang sandali.",
"Nasa hardin ako kasama sina Lila at Marco habang inaabot ng hapon ang bakuran.",
"Si Lila ang unang kumilos at inayos ang mesa para sa merienda.",
"Inilapit niya ang isa pang upuan sa tabi ko upang mas maging komportable ako.",
"Napangiti ako sa simpleng atensyon na iyon.",
"Si Marco ay nagbukas ng lumang radyo at naghanap ng musika.",
"Tumunog ang malumanay na awitin at nagbigay ng payapang himig.",
"Sinabi ko kay Lila na nagpapasalamat ako sa pag-aalaga niya.",
"Masiglang sumagot si Lila na wala iyon at gusto lang niyang maging maayos ang lahat.",
"Nagpatuloy siyang magsilbi at naglagay ng bagong inihaw na tinapay sa mesa.",
"Nakaupo ako sa lilim ng puno kasama sina Jonas at Tessa, pinapanood ang mga tao.",
"Si Jonas ang unang gumalaw at nagbukas ng malamig na inumin.",
"Inabot niya sa akin ang isa, bahagyang binuksan na upang hindi ako mahirapan.",
"Napabuntong-hininga ako sa pag-aalaga niya.",
"Si Tessa ay naglabas ng maliit na notebook at nagsimulang gumuhit.",
"Kumalaw ang kamay niya nang mabilis at maingat, parang sumasayaw ang lapis.",
"Sinabi ko kay Jonas na mukhang magiging maganda ang araw namin.",
"Sumagot si Jonas na magiging mas maganda pa kung magtatagal kami roon.",
"Kumuha siya ng ilang meryenda at inayos ito sa kumot."""

long_tag_tr = """"Walked slowly along the riverbank while taking in the cool, damp air brushing against my skin.",
"Arvin stood nearby, holding a small container of stones as if contemplating something unusual.",
"Moved gently as he chose the smoothest stone and rolled it between his fingers.",
"Let out a startled laugh because a stone was tossed at me, though it wasn’t painful.",
"Shook my head while plotting how to get back at him and then noticed the shimmering ripple near my foot.",
"Sparkled in the sunlight, swaying gently as though it were breathing.",
"Arvin then bent down and seemed to spot a tiny piece of folded paper on the ground.",
"Reached for it and carefully unfolded the long-hidden scrap of paper.",
"Its writing lifted slightly as the wind tugged at the thin page.",
"Gave a soft laugh while thinking about how I would face the mystery chance had dropped in front of us.",
"Walked through the narrow alleyway while holding my bag close so it wouldn’t be bumped by passersby.",
"Jessa hurried behind me, carrying a large umbrella like a weapon ready to be used.",
"Rushed as she reached for the zipper of the umbrella and opened it into the air.",
"Reeled back slightly because it opened right into my face.",
"Laughed while rubbing my nose and then noticed the old sign above the shop.",
"Its faded light flickered, as if struggling to keep working after a long day.",
"Jessa grimaced, clearly annoyed by the buzzing sound of the sign.",
"Tapped its post while slowly spinning the umbrella in her hand.",
"The sign buzzed louder, almost like it was interrupting our conversation.",
"Sighed while thinking about why something strange always happens when we're together.",
"Paused outside the café while looking at the fogged glass of the door.",
"Marco sat at a table near the entrance, tightly holding his hat as though it hid a secret.",
"Looked around while spinning the hat between his hands.",
"Was startled because I was pushed when he suddenly bumped into me while standing up.",
"Blinking, adjusted my shoulder and then noticed the small cup of coffee beside the door.",
"It steamed gently, releasing a strong aroma.",
"Marco lowered his head slightly, looking embarrassed.",
"He played with the cup lid between his fingers while subtly scanning the area.",
"It hummed softly as it rolled on the table.",
"Smiled while thinking about how complicated my simple café visit had become.",
"Walked through the park while avoiding kids who were running around.",
"Talia sat on the swing, holding a shiny necklace that seemed precious to her.",
"Swayed slightly as she played with the necklace between her fingers.",
"Stepped back because I was caught when the swing suddenly lurched downward.",
"Grimaced while brushing off the dust and then noticed the green ball on the grass.",
"It rolled toward me, spinning as if it had a mind of its own.",
"Talia immediately ran toward the ball, clearly amused by its movement.",
"Tapped it while bending down to follow its direction.",
"It spun even faster, as though trying to escape.",
"Laughed loudly while wondering why even the ball seemed to have its own plan.",
"Stood at the side of the road watching the slow crawl of traffic.",
"Ruel was on the opposite side, carrying a large cardboard box that looked heavy and difficult to hold.",
"Stepped carefully as he adjusted his grip on the box.",
"Stopped because I was splashed with a bit of water from the box that tilted.",
"Scratched my head while thinking about the cold water and then noticed the crooked manhole cover on the street.",
"Its metal glimmered as sunlight hit it.",
"Ruel muttered softly and tried to lift the box again.",
"He steadied it while avoiding the opening manhole cover.",
"The metal hummed as it rattled slightly.",
"Sighed while thinking about how a simple walk always turns into a strange scene.",
"Walking through the quiet park with Lila and Mr. Roberto, while thinking about how beautiful the afternoon was.",
"Lila acted first and called out to Mr. Roberto to show him a strange mark on the tree.",
"Mr. Roberto was startled and stepped back slightly as he stared at it.",
"I couldn’t help but wonder why Lila seemed to know something about the mark before showing it to us.",
"I approached to examine the tree more closely, trying to understand what it meant.",
"Lila then picked up a small stone to show a shape similar to the mark and pressed it into the ground for us to see.",
"The shape formed by the stone appeared like a symbol from an old village tale.",
"Lila continued telling a story she once heard, giving context to the mark.",
"I stepped closer to Mr. Roberto to ask if he remembered any stories about it.",
"Mr. Roberto shook his head, chuckling softly as he considered how seriously we reacted.",
"Walking through the busy market with Jessa and Ramon, while absorbing the noise and smells of fresh food.",
"Jessa was the first to spot a fruit stall and called Ramon over to ask if the items were fake.",
"Ramon frowned and inspected the fruit closely.",
"I felt that something unpleasant might happen because Jessa always overthinks purchases.",
"I handed money to the vendor to buy one piece, just to end the discussion.",
"Jessa then grabbed a plastic bag and gave it to the vendor to fill with fruit while asking about discounts.",
"The plastic bag appeared almost ready to tear from the weight.",
"Jessa continued inspecting the rest of the items, like a detective.",
"I handed another fruit to Ramon to ask what he thought of it.",
"Ramon smiled, clearly amused at how meticulous Jessa was being.",
"Sitting in a small café with Mira and Sonia, while watching the people passing outside.",
"Mira spoke first and asked Sonia why she looked so serious.",
"Sonia sighed and stared at her cooling coffee.",
"I thought she might be going through something heavy but was trying to hide it.",
"I drank the rest of my coffee, hoping to break the awkward silence.",
"Mira then took out an old notebook and placed it on the table, saying she had something to show.",
"The notebook appeared full of doodles and old handwriting.",
"Mira flipped through the pages, adding some suspense.",
"I invited Sonia to look at what was written to lighten the mood.",
"Sonia smiled when she saw the old drawing she had made when Mira was a child.",
"Walking along the shore with Paolo and Captain Ernesto, hearing the waves crash and the birds glide overhead.",
"Paolo first asked Captain Ernesto if a storm was coming because the air smelled strange.",
"Captain Ernesto looked up and examined the gloomy sky.",
"I thought Paolo was just getting nervous because he wasn’t used to the sea.",
"I walked toward the shoreline to check if the water level was rising, trying to confirm their suspicions.",
"Paolo then pulled an old compass from his pocket and held it up, saying he felt something odd.",
"The compass needle twitched as if losing direction.",
"It kept spinning in Paolo’s hand, like it had a life of its own.",
"I then asked Captain Ernesto if this was normal.",
"Captain Ernesto grinned, saying Paolo was just being dramatic as always.",
"Walking through an old museum with Rina and Mr. Alvarez, admiring the quiet and the smell of aged wood.",
"Rina approached Mr. Alvarez first and asked if it was true that the second floor was haunted.",
"Mr. Alvarez stopped and stared at the staircase as if he heard something strange.",
"I felt a chill run down my neck, like a cold breeze had passed.",
"I held the railing and peeked upward, trying to see if anything was moving.",
"Rina then took out a small flashlight and pointed it into a dark corner near a statue.",
"The flashlight beam brightened but seemed to waver through the dust.",
"She moved it even closer, searching for any trace of a presence.",
"I stepped toward Mr. Alvarez to ask if he had seen anything unusual.",
"Mr. Alvarez smiled, saying our imaginations were just playing tricks on us.",
"Sitting in the garden, taking in the dim light of dusk that settled over everything.",
"I felt the cold breeze as an old lamp on the table shifted.",
"The lamp glimmered under the setting sun, playing with the shadows of the plants.",
"Carlo stood by the door, unsure whether to approach.",
"He held a small box, as if it contained something special.",
"The box rattled slightly as he turned it, hinting at metal inside.",
"I looked back at him again, trying to understand his hesitation.",
"Carlo approached slowly, forcing a smile as though hiding something.",
"He continued to approach, until a box was handed to me, offered as a quiet surprise.",
"Walking beside the lake, amused by the way the light bounced off the water.",
"My attention drifted to a small sketchbook in my hand, which I used to draw.",
"Its pages fluttered wildly in the wind, as if eager to tell a story.",
"Hana walked ahead, holding her hat so it wouldn’t blow away.",
"She unfolded an old map, trying to recall the right direction.",
"The map crinkled as the wind tugged at it, nearly tearing from age.",
"I looked at her, wondering why she seemed so absorbed in navigation.",
"Hana paused to fix the folds of the map, looking more serious than usual.",
"The pause was followed by a small gesture toward me, until I was approached for help reading the map.",
"Standing under the mango tree, enjoying the cool relief of its shade.",
"My attention fell on an old camera I was holding, hoping to capture the scenery.",
"Its lens glimmered under the sunlight, as if ready to collect stories.",
"Loris was busy fixing the picnic blanket, smoothing every corner.",
"He adjusted a small basket, filled with the snacks we brought.",
"The basket’s lid bounced as he tried closing it, as if resisting.",
"I sighed softly, amused by how meticulous he was.",
"Loris looked at me and waved, calling me over.",
"The waving continued, until I was invited to sit beside him to help arrange things.",
"Walking through the old library, feeling the heavy silence that filled the dusty shelves.",
"I paused while looking at the antique watch on my wrist, wondering how long I had been reading.",
"The watch ticked with an odd sound, matching the heaviness of the air.",
"Mateo stood at the far end, carefully opening a thick book.",
"He lifted an old document from its pages, seemingly finding what he needed.",
"The paper hummed faintly as he adjusted it, revealing its age.",
"I stopped, wondering what kind of information he had uncovered.",
"Mateo waved and called me over, clearly wanting me to see it.",
"The waving continued, until the discovered document was shown to me",
"On the veranda, embracing the cool breeze drifting from the open fields.",
"A small journal was taken out from my bag, ready for new notes.",
"The journal displayed old doodles and entries, like living memories.",
"Bea leaned against a post, watching clouds race across the sky.",
"She held a small wind chime, bought from her last trip.",
"The wind chime rang as the breeze hit it, playing a tiny melody.",
"I turned toward Bea, noticing something thoughtful in her expression.",
"Bea smiled and waved, inviting me over.",
"The smile lingered, until a gentle tap was given to my shoulder, signaling her invitation.",
"Standing in the plaza with Marco and Lila, taking in the growing crowd gathering for the festival.",
"I stepped closer to the center, trying to get a clearer view of the stage decorations.",
"Marco was the first to react and raised the flag he was holding, as if signaling the performers that they were about to begin.",
"The flag floated in the air, twitching lightly as the people followed it with their eyes.",
"He lowered it slightly, glancing around as though confirming something.",
"I nudged Lila gently, trying to get her attention before the music started.",
"Lila looked at me, the confusion clear on her face.",
"Marco smiled and called out to Lila, as if letting her know he needed her beside him before the program began.",
"Lila tightened her grip on her bag, seeming unsure whether to follow immediately.",
"I wondered why all three of us seemed nervous at the same time, even though nothing alarming was happening.",
"Sitting under the large narra tree with Jessa and Ramon, listening to the rustling leaves carried by the wind.",
"I picked up the bag of peanuts and shook it lightly to offer some to them.",
"Jessa was the first to stand and pointed to an old map she found wedged between the tree’s roots.",
"The edges of the map rippled, almost seeming alive as the wind hit it.",
"She opened it slowly, as if examining how old and damp it had become.",
"I tapped Ramon on the shoulder, hinting that we might need his help to read it.",
"Ramon blinked rapidly, surprised at my sudden request.",
"Jessa sat closer to us and pushed the map toward Ramon, as though ordering him to be the one to examine it.",
"Ramon held his forehead, trying to remember where he had seen such a document before.",
"I sighed, thinking we might be heading into another strange adventure again.",
"Walking along the roadside with Bianca and Leo, watching the thick clouds over the setting sun.",
"I tapped the bridge railing, checking how sturdy it was while we chatted.",
"Bianca was the first to look down and pointed at a glimmering bottle drifting beneath the bridge.",
"A bit of water spurted from the bottle’s opening, moving along with the current.",
"It spun slowly, as if hiding some mysterious content not ready to be revealed.",
"I warned Leo, telling him it might be dangerous to try reaching for the bottle.",
"Leo paused for a moment, unsure whether to listen or insist on his idea.",
"Bianca tiptoed and bent even lower, still determined to retrieve the bottle.",
"She finally let go of the rope she was holding, as if surrendering her sudden plan.",
"I smiled to myself, wondering why we always end up in situations like this.",
"In the yard with Tino and Carla, listening to the neighbor’s dog barking.",
"I walked closer to the edge of the garden, checking why something seemed to have moved there.",
"Tino was the first to crouch and pick up a strange stone with an unusual shape.",
"The stone warmed slightly in his palm, as though absorbing energy from his hand.",
"It twisted a bit, as if trying to escape his grip.",
"I motioned to Carla, telling her she might want to see the stone too.",
"Carla let out a small gasp, clearly not expecting it to move.",
"Tino stepped toward her and held out the stone, testing if she would react the same way he did.",
"Carla stepped back, seemingly scared to touch it.",
"I wondered whether the stone truly held some strange energy or if we were just imagining it.",
"Walking through the market with Dan and Mira, smelling fresh fruit and newly cooked delicacies.",
"I stopped in front of a stall, examining the hanging items.",
"Dan was the first to notice and pointed at a small bell shimmering in the light.",
"The bell rang softly, sounding like it had its own rhythm.",
"I walked along the old museum hallway while following the glow of the spotlights on the floor. I moved closer to an antique painting, wondering what stories were hidden behind each brushstroke. Tomas came around from the opposite direction and asked if I also liked art. He nodded slightly and smiled while inviting me to join him at the other exhibit. I replied lightly, “Tomas, yes—show me your favorite.”",
"I sat in the quiet café while warming my hands around a cup of freshly brewed coffee. I looked outside and watched the rainfall that seemed to have no intention of stopping. Mia waved from the doorway and hurried over as if she had something important to tell me. She sat across from me and pushed an extra pastry toward my side of the table. I laughed and said, “Mia, you really never fail to shower me with food.”",
"I walked along the shoreline while following the slow movement of the waves brushing against the sand. I bent down to pick up a shiny stone and examine the lines running across it. Leo ran up from behind and joked about me searching for some lost treasure. He stopped beside me and together we looked out at the sea that seemed to sparkle under the sunlight. I laughed and said, “Leo, if there really is treasure here, you’d be the first to find it.”",
"I arrived at the fragrant garden as the cool wind brushed against the leaves and the light of dusk slowly faded.",
"I moved closer to the center of the garden to more clearly observe the old post standing beside the narrow path.",
"The post had thick carvings in its wood, as if telling stories of the many years and people that had passed through the place.",
"It swayed slightly whenever the wind touched it, releasing a woody scent that added to the chill in the air.",
"I wondered how many memories that old object may have witnessed as I stood quietly before it.",
"I stood in the middle of the old yard while watching the growth of grass that once looked lifeless.",
"I walked toward an old pail leaning by the wall and checked what was inside.",
"The pail had dried mud along its edges, proof that it was once used for watering plants.",
"It produced a soft rattle when touched, as if complaining about being unused for so long.",
"I picked it up and thought that maybe it was time to give it a purpose again.",
"I sat under the shade of a mango tree while brushing dust off my shoes and listening to the birds.",
"I looked toward the old wooden fence in front of me.",
"The fence had cracks that clearly showed it had been standing for decades.",
"Some parts had darkened, signs of long exposure to rain and sun.",
"I wondered whether I should repair it or let it remain as part of the yard’s history.",
"I walked along the cemented road while following my long shadow ahead formed by the setting sun.",
"I stopped when I reached the old lamppost that I had long noticed whenever I passed by.",
"The lamppost had faded paint marks where its original color was barely visible.",
"The light at the top flickered persistently, still trying to function despite obviously needing replacement long ago.",
"I placed my hand on the cold metal and smiled, wondering how much longer it would last.",
"I arrived at the quiet library as the sunlight softened against the dusty windows. I stepped toward the old table and opened the thick book, which immediately released the scent of aged paper. Lila suddenly approached from another row of shelves and asked if she could sit beside me. She pulled another chair closer and gently pushed it toward me as if inviting me not to read alone. I smiled at her and calmly adjusted the book so we could read comfortably together.",
"I walked inside the cold hall while listening to the faint echo of each step I made.",
"I stopped in the middle to take out from my bag an old map that I needed to examine.",
"Mara quickly approached from behind and asked if I needed help.",
"She leaned closer to the map and pointed to the part where she said my sense of direction was wrong, gently pushing my hand aside to correct what I was looking at.",
"I laughed and adjusted the paper again, saying that I probably did need her guidance.",
"I walked through the crowded market while avoiding the vendors and customers brushing past each other. I stopped at a stall to look more closely at a basket of fresh vegetables. Lando called from the other side and smiled as if he didn’t expect to see me there. He hurried over and grabbed the basket from my hand, saying he would help me choose the best ones. I shook my head while laughing, letting him return the basket after he picked some.",
"I sat under the shade of a large acacia tree while organizing the papers I needed to read that afternoon. I moved closer to the table so the documents wouldn’t be blown away by the wind. Reina walked toward me and asked if she could sit beside me while waiting for her schedule. She placed the cold drink she brought in front of me, saying I looked too overheated with what I was doing. I smiled and accepted it, grateful for her unexpected kindness.",
"I walked along the old alley while following the smell of bread from the bakery at the far end. I went inside and picked a piece of bread I had long wanted to try. Ariel suddenly appeared behind me and laughed because we apparently came for the exact same bread. He handed me an extra piece, saying it was his treat since it was rare for us to visit the place at the same time. I accepted it and said I’d make it up to him next time.",
"I walked by the lakeshore while feeling the cold breeze brushing against my arm.",
"I looked at the shimmering water and thought about how peaceful the place was compared to my busy day.",
"The old boat was docked nearby, one of its sides slightly raised against the rocks.",
"Its ropes rubbed against the post as it gently swayed with the waves.",
"It produced a faint creaking sound as if reminding me how long it had gone unused.",
"I sat under the shade of a narra tree while listening to the rustling leaves above.",
"I rested for a moment and reflected on my plans for the afternoon.",
"The old pocket watch suddenly released a soft ticking sound.",
"Its glass seemed to glimmer when struck by sunlight as the second hand slowly turned.",
"It gave off a feeling as though it was reminding me to get moving and not stay too long on my break.",
"I walked inside the old library while taking in the scent of aged paper.",
"I sat at a table and opened the diary I found in an old chest.",
"The diary had faded pages that were almost falling apart with age.",
"Its writing was partly erased but the story remained alive in every line.",
"It brought a strange sadness and nostalgia as I slowly read what was written.",
"I walked on the sand while following the shallow prints of my own footsteps.",
"I stopped near the water to watch the slow descent of the sun.",
"The abandoned umbrella stood farther away, almost being carried off by the wind.",
"Its fabric moved like waves struggling to break free from the post.",
"It looked exhausted yet continued to stand against the strengthening wind.",
"I sat on the old veranda while watching the sky darken before the rain began.",
"I sipped hot tea and thought about how quickly the week had passed.",
"The wind chime on the side rang softly, moving with the first gust of wind.",
"It swayed rhythmically, creating a melody that felt like music from nature itself.",
"It brought an unusual calm, as if balancing the harshness of the approaching weather.",
"I walked toward the old bridge as the air by the river slowly cooled.",
"Mara followed from behind and carefully asked if it was safe to cross.",
"She held the rusted rope and showed me how to keep balance.",
"We discovered that there were strands nearly snapping beneath her fingers.",
"Mara stepped back a little and suggested that it might be better for us to return.",
"I felt she was probably right and that it was wiser to prioritize safety than force the crossing.",
"I walked through the overgrown garden while following the smell of damp earth.",
"Lino emerged from behind the plants and asked whether I had seen his lost wallet.",
"He lifted an old flowerpot and gently shook it to check if his things had fallen there.",
"Dried leaves spilled out onto the ground from inside it.",
"Lino shook his head and continued rummaging around.",
"I felt that I should probably help him so we could find what he was looking for more quickly."""

# %%
# @title Tagalog Control - Translation
tag_control_prompt = "Translate the following Tagalog text into English. Do not put line breaks in between sentences. Respond with your only English translation.\n"

# %%
from together import Together
client = Together(api_key=os.environ["LIN353D"])
model = "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo"

short_tag_tr_control_candidates = []

for story in short_tag.splitlines():
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_control_prompt + story}
      ],
      max_tokens=400,
      random_state=42
  )
  # Ensure no newlines in the candidate string, as per prompt instruction, and strip leading/trailing whitespace.
  candidate_text = response.choices[0].message.content.replace('\n', ' ').strip()
  short_tag_tr_control_candidates.append(candidate_text)

# %%
for story in short_tag_tr_control_candidates:
  print(story)
# Out:
# Walking on the quiet street as the cold rain slowly fell and the lights of the closed shops twinkled on both sides.
# Marco approached from the other end of the road and waved, carrying a blue umbrella and a bright smile that was firmly set on his face.
# An umbrella was handed to me and was pulled close quickly so I wouldn't get soaked under the increasingly heavy rain.
# I gazed at the mouth and looked up at the dark cloud in the sky, as if I was thinking of something heavy that I didn't fully understand yet.
# He spoke with great fervor, "Marco, don't worry, I'm here and together we'll face whatever comes our way."
# ...

# %%
from together import Together

client = Together(api_key=os.environ["LIN353D"])

long_tag_tr_control_candidates = []

for story in long_tag.splitlines():
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_control_prompt + story}
      ],
      max_tokens=400,
      random_state=42
  )

  long_tag_tr_control_candidates.append(response.choices[0].message.content)

# %%
for story in long_tag_tr_control_candidates:
  print(story)
# Out:
# He walked slowly along the side of the river while inhaling the cool and damp air that caressed the skin.
# Arvin stood nearby, tightly holding the small container of stones as if he was deeply thinking about them.
# He moved quickly while choosing the coldest stone from the container and continued to rotate it between his fingers.
# I was suddenly given a sharp laugh because one of the smooth stones was thrown at me, even though it wasn't painful.
# I was pondering how I would approach her and then noticed the unique charm of the small wave beside my feet.
# Glittering in the light of the sun, its gentle movement seems to breathe in sync with the current.
# Arvin suddenly bent down and seemed to have noticed a small thing between the stones by the riverbank.
# That was carefully handed over and looked at the small folded paper that seemed to be worn out from being folded many times.
# ...

# %%
# Install BLEURT
# !pip install --upgrade pip
# !pip install git+https://github.com/google-research/bleurt.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-ih6h8l78
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-ih6h8l78
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for BLEURT: filename=bleurt-0.0.2-py3-none-any.whl size=16456842 sha256=a112c6b4b1298afe48d3ec92509be07b8e0a1ec10fb9529691fc7dd7d2238dcd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dwbk0jbe/wheels/7d/7d/6a/b06f2c763c081f3de412125c1e0bcbc941dc14da222f7c4273
# ...

# %%
from bleurt import score

checkpoint = "/content/drive/My Drive/BLEURT-20"

short_tag_tr_references = short_tag_tr.splitlines()
scorer = score.BleurtScorer(checkpoint)
control_short_scores = scorer.score(references=short_tag_tr_references, candidates=short_tag_tr_control_candidates)
print(control_short_scores)
print(sum(control_short_scores)/len(control_short_scores))
# Out:
# [0.7204068303108215, 0.6702743768692017, 0.7344534397125244, 0.6257691979408264, 0.7112346291542053, 0.6954972147941589, 0.7850057482719421, 0.6243218183517456, 0.7796077132225037, 0.5956536531448364, 0.6979264616966248, 0.574669599533081, 0.6883822083473206, 0.7676737308502197, 0.650011420249939, 0.5244752764701843, 0.7072758078575134, 0.6588665843009949, 0.777785062789917, 0.7162520289421082, 0.8078472018241882, 0.7708505988121033, 0.6558799147605896, 0.7516205310821533, 0.6593000292778015, 0.6001649498939514, 0.6518884897232056, 0.6668050289154053, 0.7579004764556885, 0.7402158975601196, 0.7769857048988342, 0.8602836728096008, 0.8906553387641907, 0.7067133188247681, 0.5554752349853516, 0.7213532328605652, 0.7672881484031677, 0.679986298084259, 0.6983516812324524, 0.69633549451828, 0.6587579846382141, 0.674027144908905, 0.4522293210029602, 0.7397708296775818, 0.76558518409729, 0.6794084906578064, 0.5324901938438416, 0.7179706692695618, 0.7432566285133362, 0.46786683797836304, 0.573
# ...

# %%
from bleurt import score

checkpoint = "/content/drive/My Drive/BLEURT-20"

long_tag_tr_references = long_tag_tr.splitlines()
scorer = score.BleurtScorer(checkpoint)
control_long_scores = scorer.score(references=long_tag_tr_references, candidates=long_tag_tr_control_candidates)
print(control_long_scores)
print(sum(control_long_scores)/len(control_long_scores))
# Out:
# [0.6768701672554016, 0.7297868132591248, 0.5952016115188599, 0.6653265357017517, 0.5398216843605042, 0.5581187605857849, 0.6449268460273743, 0.492060124874115, 0.4767623543739319, 0.672116219997406, 0.6812099814414978, 0.6805382966995239, 0.4562700390815735, 0.5342963933944702, 0.6724177598953247, 0.5118117928504944, 0.6334449648857117, 0.5566632151603699, 0.7120489478111267, 0.7785091996192932, 0.7862833142280579, 0.7745380997657776, 0.719959557056427, 0.6402387022972107, 0.5680321455001831, 0.580402672290802, 0.35584557056427, 0.6646260619163513, 0.5606442093849182, 0.7120761275291443, 0.6459445953369141, 0.6902024149894714, 0.5238274335861206, 0.47423309087753296, 0.5550750494003296, 0.6927458643913269, 0.8233997225761414, 0.5644854307174683, 0.6291776299476624, 0.7004217505455017, 0.7731905579566956, 0.8110432028770447, 0.7896755933761597, 0.6442666053771973, 0.6039668321609497, 0.6845017075538635, 0.48083406686782837, 0.5452053546905518, 0.45514482259750366, 0.718105137348175, 0
# ...

# %%
# @title Tagalog Test - CT Analysis
tag_cta_prompt_start = """Generate a centering theory analysis based on the provided Tagalog text.

When writing a centering theory analysis, you must keep track of four features in each sentence:
    1. Cb (Backward-looking Center)
       The discourse entity that the current sentence is most centrally about, carried over from the previous sentence.
       It represents continuity with prior discourse.

    2. Cf (Forward-looking Centers)
       A ranked list of entities mentioned in the current sentence, ordered by their prominence (usually subject > object > others).
       These are potential candidates to become the center in the next sentence.

    3. Cp (Preferred Center)
       The highest-ranked element on the Cf list.
       It is the entity most likely to be continued as the focus of the next sentence.

    4. Transition
       Describes how the discourse focus shifts from one sentence to the next, based on Cb and Cp:
            1. Continue: Cb stays the same and equals Cp
            2. Retain: Cb stays the same but Cp differs
            3. Shift: Cb changes

Here is an example of a Tagalog story and its corresponding centering theory analysis:
Lumapit ako sa lumang tulay habang unti-unting lumalamig ang hangin sa ilog.
Si Mara ay sumunod mula sa likuran at maingat na tinanong kung ligtas bang tumawid doon.
Humawak siya sa may kalawang na lubid habang ipinapakita sa akin kung paano manatiling balanse.
Natuklasan nitong may mga hiblang halos mapigtas sa ilalim ng kanyang mga daliri.
Si Mara ay napaatras nang kaunti at nagmungkahi na baka mas mabuting bumalik na lamang kami.
Naisip kong baka tama siya at mas maiging unahin ang kaligtasan kaysa pilitin ang pagtawid.


Sentence 1
  Cb: N/A
  Cf: [Narrator, bridge, air]
  Cp: Narrator
  Transition: N/A
Sentence 2
  Cb: Narrator
  Cf: [Mara, narrator, safety]
  Cp: Mara
  Transition: Shift
Sentence 3
  Cb: Mara
  Cf: [Mara, rope, balance, narrator]
  Cp: Mara
  Transition: Retain
Sentence 4
  Cb: Mara
  Cf: [rope, strands, fingers]
  Cp: rope
  Transition: Shift
Sentence 5
  Cb: rope
  Cf: [Mara, narrator, suggestion]
  Cp: Mara
  Transition: Shift
Sentence 6
  Cb: Mara
  Cf: [narrator, safety, crossing]
  Cp: narrator
  Transition: Shift


Here is another example:
Nasa hardin ako kasama sina Lila at Marco habang inaabot ng hapon ang buong bakuran.
Si Lila ang unang kumilos at maingat niyang inayos ang mesa para sa maliit naming merienda.
Inilapit niya ang isa pang upuan sa tabi ko upang mas maging komportable ang puwesto ko.
Napangiti ako dahil sa simpleng atensyon na ipinakita niyang iyon.
Si Marco naman ay nagbukas ng lumang radyo at naghanap ng musika upang mas maging masaya ang aming pagtitipon.
Tumunog ang malumanay na awitin at nagbigay ito ng payapang himig sa paligid.
Sinabi ko kay Lila na nagpapasalamat ako sa pag-aasikaso niya sa amin.
Si Lila naman ay sumagot nang masigla at sinabing wala iyon at gusto lang niyang maging maayos ang lahat.
Nagpatuloy siyang naghahain ng pagkain at naglagay ng bagong inihaw na tinapay sa gitna ng mesa.

Sentence 1
  Cb: N/A
  Cf: [Narrator, Lila, Marco]
  Cp: Narrator
  Transition: N/A
Sentence 2
  Cb: Narrator
  Cf: [Lila, Marco, Narrator, Table]
  Cp: Lila
  Transition: Shift
Sentence 3
  Cb: Lila
  Cf: [Lila, Narrator, Chair]
  Cp: Lila
  Transition: Continue
Sentence 4
  Cb: Lila
  Cf: [Narrator, Lila]
  Cp: Narrator
  Transition: Retain
Sentence 5
  Cb: Narrator
  Cf: [Marco, Narrator, Lila, Radio]
  Cp: Marco
  Transition: Shift
Sentence 6
  Cb: Marco
  Cf: [Song, Air]
  Cp: Song
  Transition: Shift
Sentence 7
  Cb: Song
  Cf: [Narrator, Lila]
  Cp: Narrator
  Transition: Shift
Sentence 8
  Cb: Narrator
  Cf: [Lila, Narrator]
  Cp: Lila
  Transition: Shift
Sentence 9
  Cb: Lila
  Cf: [Lila, Food, Table]
  Cp: Lila
  Transition: Continue

Now, you will write a centering theory analysis like the examples above based on the following text:\n"""

tag_cta_prompt_end = "\n\nPlease respond only with your centering theory analysis."

# %%
from together import Together

client = Together(api_key=os.environ["LIN353D"])

short_tag_ctas = []

for story in short_tag.splitlines():
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_cta_prompt_start + story + tag_cta_prompt_end}
      ],
      max_tokens=400,
      random_state=42
  )

  short_tag_ctas.append(response.choices[0].message.content)

# %%
for ct in short_tag_ctas:
  print(ct)
  print()
# Out:
# Sentence 1
#   Cb: N/A
#   Cf: [Narrator, street, rain, lights]
#   Cp: Narrator
#   Transition: N/A
#
# Sentence 2
#   Cb: Narrator
#   Cf: [street, rain, lights, narrator]
#   Cp: street
#   Transition: Shift
#
# Sentence 3
#   Cb: street
#   Cf: [street, rain, lights, narrator]
#   Cp: street
#   Transition: Continue
#
# Note: Since there are only two sentences, the analysis is limited. However, it can be observed that the center shifts from the narrator to the street in the second sentence, and then continues to focus on the street in the third sentence.
#
# Sentence 1
#   Cb: N/A
#   Cf: [Marco, payong, smile]
#   Cp: Marco
#   Transition: N/A
#
# Sentence 2
#   Cb: Marco
#   Cf: [Marco, payong, smile]
#   Cp: Marco
#   Transition: Continue
#
# Note: Since there's only one sentence, the transition is N/A. However, if we were to continue with the next sentence, we would analyze it based on the Cb and Cf of the first sentence.
#
# Sentence 1
#   Cb: N/A
# ...

# %%
from together import Together

client = Together(api_key=os.environ["LIN353D"])

long_tag_ctas = []

for story in long_tag.splitlines():
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_cta_prompt_start + story + tag_cta_prompt_end}
      ],
      max_tokens=400,
      random_state=42
  )

  long_tag_ctas.append(response.choices[0].message.content)

# %%
for ct in long_tag_ctas:
  print(ct)
  print()
# Out:
# Sentence 1
#   Cb: N/A
#   Cf: [Narrator, river, wind]
#   Cp: Narrator
#   Transition: N/A
#
# Sentence 2
#   Cb: Narrator
#   Cf: [Narrator, river, wind]
#   Cp: Narrator
#   Transition: Continue
#
# Note: Since there are only two sentences, the analysis is quite straightforward. The first sentence has no backward-looking center, and the second sentence continues the focus on the narrator.
#
# Sentence 1
#   Cb: N/A
#   Cf: [Arvin, container, thoughts]
#   Cp: Arvin
#   Transition: N/A
#
# Sentence 1
#   Cb: N/A
#   Cf: [Person, rock, fingers]
#   Cp: Person
#   Transition: N/A
#
# Sentence 2
#   Cb: Person
#   Cf: [rock, fingers, Person]
#   Cp: rock
#   Transition: Shift
#
# Sentence 3
#   Cb: rock
#   Cf: [rock, fingers, Person]
#   Cp: rock
#   Transition: Continue
#
# Sentence 1
#   Cb: N/A
#   Cf: [Narrator, stone, pain]
#   Cp: Narrator
#   Transition: N/A
#
# Sentence 2
#   Cb: Narrator
#   Cf: [stone, narrator, pain]
#   Cp: stone
#   Transition: Shift
#
# Sentence 3
# ...

# %%
# @title Tagalog Test - Translation
tag_test_prompt_start = """Translate the Tagalog text into English while referencing the provided centering theory analysis.

A centering analysis keeps track of four features in each sentence:
    1. Cb (Backward-looking Center)
       The discourse entity that the current sentence is most centrally about, carried over from the previous sentence.
       It represents continuity with prior discourse.

    2. Cf (Forward-looking Centers)
       A ranked list of entities mentioned in the current sentence, ordered by their prominence (usually subject > object > others).
       These are potential candidates to become the center in the next sentence.

    3. Cp (Preferred Center)
       The highest-ranked element on the Cf list.
       It is the entity most likely to be continued as the focus of the next sentence.

    4. Transition
       Describes how the discourse focus shifts from one sentence to the next, based on Cb and Cp:
            1. Continue: Cb stays the same and equals Cp
            2. Retain: Cb stays the same but Cp differs
            3. Shift: Cb changes

Here is an example of a Tagalog story, its corresponding centering theory analysis, and what the final English translation would be:
Naglakad ako sa masukal na hardin habang sinusundan ang amoy ng basang lupa.
Si Lino ay sumulpot mula sa likod ng mga halaman at nagtanong kung nakita ko ba ang nawawala niyang pitaka.
Tinaas niya ang isang lumang paso habang maingat na inaalog ito upang tingnan kung nahulog doon ang gamit niya.
Lumabas na may mga tuyong dahong kumalat sa sahig mula sa loob nito.
Si Lino ay napa-iling at nagpatuloy sa paghahalukay sa paligid.
Naramdaman kong baka kailangan ko na siyang tulungan para mas mabilis naming mahanap ang hinahanap niya.


Sentence 1
  Cb: N/A
  Cf: [Narrator, garden, earth smell]
  Cp: Narrator
  Transition: N/A
Sentence 2
  Cb: Narrator
  Cf: [Lino, narrator, wallet]
  Cp: Lino
  Transition: Shift
Sentence 3
  Cb: Lino
  Cf: [Lino, pot, wallet, things]
  Cp: Lino
  Transition: Retain
Sentence 4
  Cb: Lino
  Cf: [pot, leaves, ground]
  Cp: pot
  Transition: Shift
Sentence 5
  Cb: pot
  Cf: [Lino, surroundings]
  Cp: Lino
  Transition: Shift
Sentence 6
  Cb: Lino
  Cf: [narrator, task, search]
  Cp: narrator
  Transition: Shift

I walked through the overgrown garden while following the smell of damp earth.
Lino appeared from behind the plants and asked whether I had seen his lost wallet.
He lifted an old flowerpot and gently shook it to check if his things had fallen there.
It turned out that dried leaves spilled onto the ground from inside it.
Lino shook his head and continued rummaging around.
I felt that I should probably help him so we could find what he was looking for more quickly.


Here is another example:
Nakaupo ako sa lilim ng puno kasama sina Jonas at Tessa habang pinapanood namin ang mga dumadaang tao.
Si Jonas ang unang gumalaw at nagbukas siya ng malamig na inumin para sa aming tatlo.
Inabot niya sa akin ang isa, bahagyang binuksan pa para hindi ako mahirapan.
Napabuntong-hininga ako dahil sa pag-aalaga niyang ipinakita.
Si Tessa naman ay kumuha ng maliit na notebook at nagsimulang gumuhit ng tanawin sa paligid.
Gumalaw ang kaniyang kamay nang mabilis at maingat, na para bang sinasayaw ng isip niya ang lapis sa papel.
Sinabi ko kay Jonas na mukhang maganda ang araw naming tatlo.
Si Jonas naman ay tumingin sa akin at sinabing mas magiging maganda pa kung magtatagal kami roon.
Naglabas pa siya ng ilang meryenda mula sa kaniyang bag at inayos ito sa kumot na nakalatag.


Sentence 1
  Cb: N/A
  Cf: [Narrator, Jonas, Tessa, Tree]
  Cp: Narrator
  Transition: N/A
Sentence 2
  Cb: Narrator
  Cf: [Jonas, Narrator, Tessa, Drinks]
  Cp: Jonas
  Transition: Shift
Sentence 3
  Cb: Jonas
  Cf: [Jonas, Narrator, Drink]
  Cp: Jonas
  Transition: Continue
Sentence 4
  Cb: Jonas
  Cf: [Narrator, Jonas]
  Cp: Narrator
  Transition: Retain
Sentence 5
  Cb: Narrator
  Cf: [Tessa, Notebook, Children, Narrator]
  Cp: Tessa
  Transition: Shift
Sentence 6
  Cb: Tessa
  Cf: [Tessa, Hand, Pencil, Scene]
  Cp: Tessa
  Transition: Continue
Sentence 7
  Cb: Tessa
  Cf: [Narrator, Jonas]
  Cp: Narrator
  Transition: Shift
Sentence 8
  Cb: Narrator
  Cf: [Jonas, Narrator]
  Cp: Jonas
  Transition: Shift
Sentence 9
  Cb: Jonas
  Cf: [Jonas, Snacks, Bag]
  Cp: Jonas
  Transition: Continue

I was sitting under the shade of a tree with Jonas and Tessa as we watched people pass by.
Jonas acted first and opened cold drinks for the three of us.
He handed me one, slightly opened already so I wouldn’t struggle.
I sighed softly at the care he showed.
Tessa then took out a small notebook and began sketching the scenery.
Her hand moved quickly and precisely, as if her mind was dancing with the pencil.
I told Jonas that it seemed like the three of us would have a great day.
Jonas looked at me and said it would be even better if we stayed longer.
He then took out some snacks from his bag and arranged them on the blanket.


Now, you will be provided a Tagalog text and centering theory analysis. Use both to generate an English translation like the examples above:\n\n
"""

tag_test_prompt_end = "\n\nDo not put line breaks in between sentences. Respond with only your English translation."

# %%
from together import Together

client = Together(api_key=os.environ["LIN353D"])

short_tag_tr_test_candidates = []

for i, story in enumerate(short_tag.splitlines()):
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_test_prompt_start + story + "\n\n" + short_tag_ctas[i] + tag_test_prompt_end}
      ],
      max_tokens=400,
      random_state=42
  )

  short_tag_tr_test_candidates.append(response.choices[0].message.content)

# %%
for story in short_tag_tr_test_candidates:
  print(story)
# Out:
# I walked through the quiet street as the cool rain started to fall and the lights of the closed shops sparkled on both sides. The street was already wet and glistening, and I could hear the sound of raindrops hitting the pavement.
# Marco approached from the other end of the street, waving with a blue umbrella and a bright smile that seemed to be forcing its way out.
# An umbrella was handed to me and I quickly pulled it close so it wouldn't get blown away by the increasingly heavy rain.
# I gazed at the dark clouds in the sky, as if I was pondering something heavy that I still didn't fully understand.
# He spoke rapidly, "Marco, don't worry, I'm here with you and together we'll face whatever comes our way."
# ...

# %%
from together import Together

client = Together(api_key=os.environ["LIN353D"])

long_tag_tr_test_candidates = []

for i, story in enumerate(long_tag.splitlines()):
  response = client.chat.completions.create(
      model=model,
      messages=[
          {"role": "user", "content": tag_test_prompt_start + story + "\n\n" + long_tag_ctas[i] + tag_test_prompt_end}
      ],
      max_tokens=400,
      random_state=42
  )

  long_tag_tr_test_candidates.append(response.choices[0].message.content)

# %%
for story in long_tag_tr_test_candidates:
  print(story)
  print()
# Out:
# I walked slowly along the riverbank while inhaling the cool and damp air that caressed my skin.
#
# Arvin stood nearby, holding a small container of stones as if he was deeply thinking about them.
#
# He moved quickly as he picked the coldest stone from the container and continued to rotate it between his fingers.
#
# I was given a sudden, involuntary laugh because one of the smooth stones was thrown at me, even though it wasn't painful.
#
# I was lost in thought, wondering how I would comfort him, and then I noticed the unique shape of the small wave beside his foot.
#
# Shining in the light of the sun, the gentle movement vibrates like breathing in sync with the flow.
#
# Arvin suddenly bent down and seemed to have noticed something small between the stones by the river.
#
# It was handed to me carefully and I looked at the small folded paper that seemed to be exhausted from being folded over and over again.
#
# ...

# %%
# @title Tagalog Test - Results
from bleurt import score

checkpoint = "/content/drive/My Drive/BLEURT-20"

short_tag_tr_references = short_tag_tr.splitlines()
scorer = score.BleurtScorer(checkpoint)
test_short_scores = scorer.score(references=short_tag_tr_references, candidates=short_tag_tr_test_candidates)
print(test_short_scores)
print(sum(test_short_scores)/len(test_short_scores))
# Out:
# [0.7064464688301086, 0.6056290864944458, 0.7108979821205139, 0.6918752789497375, 0.7196757197380066, 0.7561262249946594, 0.7494018077850342, 0.6786313652992249, 0.8103873133659363, 0.6587806344032288, 0.6975502371788025, 0.6365606188774109, 0.7047989368438721, 0.750518262386322, 0.6890626549720764, 0.6167728304862976, 0.7369866967201233, 0.6593347191810608, 0.7943825125694275, 0.7833907008171082, 0.8078472018241882, 0.7300655245780945, 0.703332781791687, 0.792449414730072, 0.720761239528656, 0.6824403405189514, 0.7584134340286255, 0.6115124225616455, 0.8001745343208313, 0.7596235871315002, 0.8067371249198914, 0.8418402075767517, 0.8295077681541443, 0.6922853589057922, 0.5512329339981079, 0.7453611493110657, 0.7727115750312805, 0.749595046043396, 0.7823767066001892, 0.7638986706733704, 0.6770908236503601, 0.7165351510047913, 0.6189423203468323, 0.862531304359436, 0.8009210824966431, 0.730678141117096, 0.6039815545082092, 0.684032142162323, 0.7672471404075623, 0.6882323622703552, 0.695
# ...

# %%
from bleurt import score

checkpoint = "/content/drive/My Drive/BLEURT-20"

long_tag_tr_references = long_tag_tr.splitlines()
scorer = score.BleurtScorer(checkpoint)
test_long_scores = scorer.score(references=long_tag_tr_references, candidates=long_tag_tr_test_candidates)
print(test_long_scores)
print(sum(test_long_scores)/len(test_long_scores))
# Out:
# [0.7456731200218201, 0.753993809223175, 0.6040564179420471, 0.6467418670654297, 0.5337640643119812, 0.5620796084403992, 0.6090692281723022, 0.5246113538742065, 0.5181697607040405, 0.6667395234107971, 0.745219886302948, 0.7211453914642334, 0.5843347311019897, 0.4859195351600647, 0.7261853814125061, 0.5906381011009216, 0.7070229649543762, 0.5446805953979492, 0.8423929214477539, 0.7357537150382996, 0.7726441025733948, 0.7950274348258972, 0.6403249502182007, 0.6519338488578796, 0.566136360168457, 0.5134547352790833, 0.4269360899925232, 0.6086775660514832, 0.5948916077613831, 0.691648542881012, 0.6517903208732605, 0.6816411018371582, 0.5238274335861206, 0.4235764741897583, 0.5488994121551514, 0.6820533871650696, 0.8233997225761414, 0.5062866806983948, 0.7396799921989441, 0.8082273602485657, 0.7657960057258606, 0.8005102276802063, 0.7206369042396545, 0.6173883080482483, 0.6377084851264954, 0.7108700275421143, 0.5259501934051514, 0.49055105447769165, 0.6649462580680847, 0.7409032583236694, 
# ...
